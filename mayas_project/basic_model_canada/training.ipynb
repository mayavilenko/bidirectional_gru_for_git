# %% [markdown]
# # Imports

# %%
import torch
import pandas as pd
import numpy as np
import statistics
import torch
import random
import time
import numpy as np
#from transformers import AdamW
from torch.utils.tensorboard import SummaryWriter
import pickle
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import shutil
import itertools

from GRU_model import *
from config import *

# %% [markdown]
# # Seeds for Comparisons:

# %%
torch.manual_seed(1)
np.random.seed(2)
random.seed(3)

# %%
Lr
# Out:
# 0.09782661222201432

# %% [markdown]
# # Read Data

# %%
train_dataset_dict = pd.read_pickle(train_dataset_dict_path)
test_dataset_dict = pd.read_pickle(test_dataset_dict_path)
category_id_to_name_dict = pd.read_pickle(category_id_to_category_name_path)

# %% [markdown]
# # Create Dataloader

# %%
def create_dataloader(category_train_df, category_test_df):
    x_train = category_train_df.iloc[:,:-1].to_numpy()
    y_train = category_train_df.iloc[:,-1].to_numpy()
    x_test = category_test_df.iloc[:,:-1].to_numpy()
    y_test= category_test_df.iloc[:,-1].to_numpy()

    x_train= torch.from_numpy(x_train).to(torch.float32)
    y_train = torch.from_numpy(y_train).to(torch.float32)
    x_test = torch.from_numpy(x_test).to(torch.float32)
    y_test = torch.from_numpy(y_test).to(torch.float32)

    train_dataset = TensorDataset(x_train, y_train)
    test_dataset = TensorDataset(x_test, y_test)
    train_dataloader =  DataLoader(train_dataset, batch_size=BatchSize, shuffle=False)
    test_dataloader =  DataLoader(test_dataset, batch_size=BatchSize, shuffle=False)
    return train_dataloader, test_dataloader

# %% [markdown]
# # Model Configurations

# %%
#Define our device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Training Loop

# %%
def training_loop(model, train_dataloader, optimizer):
    running_loss = 0
    model.train()
    predictions_list = []
    for inputs, labels in train_dataloader:
        # initialize calculated gradients (from prev step)
        optimizer.zero_grad()
        inputs, labels = inputs.to(device), labels.to(device)
        #Changing input shape - last batch size can change so we define it as input.shape[0]
        inputs = inputs.view(inputs.shape[0], SequenceLength, Features) 
        #model prediction
        pred = model(inputs)
        #append batch predictions to predictions list
        predictions_list.append(pred.view(1,-1))
        # calculate loss
        loss = Criterion(pred, labels.view(-1,1))
        # calculate the gradient
        loss.backward()
        # update parameters
        optimizer.step()
        #Add to loss of batch to epoch train loss
        running_loss+=loss.item()
    # Calculte the epoch train loss
    epoch_train_loss = running_loss/len(train_dataloader.dataset)
    return epoch_train_loss

# %%
def evaluation_loop(model, test_dataloader):
     # Evaluation
    # Initiate test loss, accuracy and f1 score to zero
    test_loss = 0
    # Change model to eval mode
    model.eval()
    # we dont need to update weights, so we define no_grad() to save memory

    predictions_list = []
    with torch.no_grad():
        for inputs, labels in test_dataloader:
            inputs = inputs.view(inputs.shape[0], SequenceLength, Features)
            inputs, labels = inputs.to(device), labels.to(device)
            out = model(inputs)
            predictions_list.append(out.view(1,-1))
            test_batch_loss = Criterion(out, labels.view(-1,1))
            test_loss += test_batch_loss.item()
    # Calculate epoch loss
    epoch_predictions = torch.cat(predictions_list, dim=1)
    epoch_test_loss = test_loss/len(test_dataloader.dataset)
        
    return epoch_test_loss, epoch_predictions

# %%
def save_checkpoint(checkpoint, is_best, checkpoint_path, best_model_path):
    """
    checkpoint: checkpoint we want to save
    is_best: is this the best checkpoint; min validation loss
    checkpoint_path: path to save checkpoint
    best_model_path: path to save best model
    """
    # save checkpoint data to the path given, checkpoint_path
    torch.save(checkpoint, checkpoint_path)
    # if it is a best model, min validation loss
    if is_best:
        # copy that checkpoint file to best path given, best_model_path
        shutil.copyfile(checkpoint_path, best_model_path)

# %%
def load_checkpoint(checkpoint_path, model, optimizer):
    """
    checkpoint_path: path to save checkpoint
    model: model that we want to load checkpoint parameters into       
    optimizer: optimizer we defined in previous training
    """
    # load check point
    checkpoint = torch.load(checkpoint_path)
    # initialize state_dict from checkpoint to model
    model.load_state_dict(checkpoint['state_dict'])
    # initialize optimizer from checkpoint to optimizer
    optimizer.load_state_dict(checkpoint['optimizer'])
    # initialize valid_loss_min from checkpoint to valid_loss_min
    valid_loss_min = checkpoint['valid_loss_min']
    # return model, optimizer, epoch value, min validation loss 
    return model, optimizer, checkpoint['epoch'], valid_loss_min

# %%
def unify_model_weights(model):
    param_dict ={}
    for name, param in model.named_parameters():
        param_dict[name] = param

    param_dict['gru.bias_hh_l0'] = param_dict['gru.bias_hh_l0'].view(-1,1)
    param_dict['gru.bias_ih_l0'] = param_dict['gru.bias_ih_l0'].view(-1,1)
    unified_weights = torch.hstack((
            param_dict['gru.weight_ih_l0'],
            param_dict['gru.weight_hh_l0'],
            param_dict['gru.bias_ih_l0'],
            param_dict['gru.bias_hh_l0']))

    return unified_weights

# %%
def training_and_evaluation(model, train_dataloader, test_dataloader, optim, category, checkpoint_path, best_checkpoint_path):
   #results list
   train_loss_list = []
   test_loss_list = []

   ##Create writer for using tesndorboard
   #writer = SummaryWriter(log_dir=f'{TbDirectory}_{category}')

   min_test_loss = np.inf

   for epoch in range(Epochs):
      #initiate train epoch loss
      epoch_train_loss = training_loop(model, train_dataloader, optim)
      epoch_test_loss, epoch_test_predictions = evaluation_loop(model, test_dataloader)

      checkpoint = {
         'epoch': epoch + 1,
         'valid_loss_min': epoch_test_loss,
         'state_dict': model.state_dict(),
         'optimizer': optim.state_dict(),
        }
      
      # save checkpoint
      save_checkpoint(checkpoint, False, checkpoint_path, best_checkpoint_path)

      if epoch_test_loss <= min_test_loss:
         save_checkpoint(checkpoint, True, checkpoint_path, best_checkpoint_path)
         min_test_loss = epoch_test_loss

      train_loss_list.append(epoch_train_loss)
      test_loss_list.append(epoch_test_loss)

      ## Display those measures on tensorboard
      #writer.add_scalar(tag='loss/train', scalar_value=epoch_train_loss, global_step=epoch)
      #writer.add_scalar(tag='loss/test', scalar_value=epoch_test_loss, global_step=epoch)
    
   results = {'train_loss': train_loss_list, 'test_loss': test_loss_list} 
   return results

# %%
categories = list(category_id_to_name_dict.values())

# %%
len(categories)
# Out:
# 293

# %%
categories
# Out:
# ['Air transportation',
#  'Alcoholic beverages',
#  'Alcoholic beverages purchased from stores',
#  'Alcoholic beverages served in licensed establishments',
#  'Alcoholic beverages, tobacco products and recreational cannabis',
#  'All other food preparations',
#  'All other miscellaneous food preparations',
#  'All other passenger vehicle operating expenses',
#  'All-items',
#  "All-items excluding alcoholic beverages, tobacco products and smokers' supplies and recreational cannabis",
#  'All-items excluding energy',
#  'All-items excluding food',
#  'All-items excluding food and energy',
#  'All-items excluding gasoline',
#  'All-items excluding mortgage interest cost',
#  'All-items excluding shelter',
#  'Apples',
#  'Athletic footwear',
#  'Audio equipment',
#  'Baby foods',
#  'Bacon',
#  'Bakery and cereal products (excluding baby food',
#  'Bakery products',
#  'Bananas',
#  'Bedding and other household textiles',
#  'Beer purchased from stores',
#  'Beer served in licensed establishments',
#  'Bleach and other household chemical products',
#  'Books and reading material (excluding textbooks',
#  'Bread, rolls and buns',
#  'Breakfast cereal and other cereal products (excluding baby food',
#  'Butter',
#  'Canned and other preserved fish',
#  'Canned fruit',
#  'Canned infant or junior foods',
#  'Canned salmon',
#  'Canned tuna',
#  'Canned vegetables and other vegetable preparations',
#  'Cellular services',
#  'Cereal products (excluding baby food',
#  'Cheddar cheese',
#  'Cheese',
#  'Child care and housekeeping services',
#  'Child care services',
#  "Children's clothing",
#  "Children's footwear (excluding athletic",
#  'Cigarettes',
#  'City bus and subway transportation',
#  'Clothing',
#  'Clothing accessories',
#  'Clothing accessories, watches and jewellery',
#  'Clothing and footwear',
#  'Clothing material, notions and services',
#  'Coffee',
#  'Coffee and tea',
#  'Communications',
#  'Computer equipment, software and supplies',
#  'Condiments, spices and vinegars',
#  'Confectionery',
#  'Cookies and crackers',
#  'Cooking appliances',
#  'Dairy products',
#  'Dairy products and eggs',
#  'Dental care services',
#  'Detergents and rinse agents for dish washing',
#  'Detergents and soaps (other than personal care',
#  'Digital computing equipment and devices',
#  'Dried and dehydrated fruit',
#  "Drivers' licences",
#  'Dry or fresh pasta',
#  'Edible fats and oils',
#  'Education',
#  'Education and reading',
#  'Eggs',
#  'Electricity',
#  'Energy',
#  'Eye care goods',
#  'Eye care services',
#  'Fabric softener',
#  'Financial services',
#  'Fish',
#  'Fish, seafood and other marine products',
#  'Flour and flour-based mixes',
#  'Food',
#  'Food and energy',
#  'Food purchased from cafeterias and other restaurants',
#  'Food purchased from fast food and take-out restaurants',
#  'Food purchased from restaurants',
#  'Food purchased from stores',
#  'Food purchased from table-service restaurants',
#  'Footwear',
#  'Fresh fruit',
#  'Fresh fruit and vegetables',
#  'Fresh milk',
#  'Fresh or frozen beef',
#  'Fresh or frozen chicken',
#  'Fresh or frozen fish (including portions and fish sticks',
#  'Fresh or frozen meat (excluding poultry',
#  'Fresh or frozen pork',
#  'Fresh or frozen poultry',
#  'Fresh vegetables',
#  'Frozen and dried vegetables',
#  'Frozen food preparations',
#  'Frozen fruit',
#  'Fruit juices',
#  'Fruit, fruit preparations and nuts',
#  'Fuel oil and other fuels',
#  'Fuel, parts and accessories for recreational vehicles',
#  'Furniture',
#  'Furniture and household textiles',
#  'Gasoline',
#  'Ham and bacon',
#  'Ham excluding deli ham',
#  'Health and personal care',
#  'Health care',
#  'Health care goods',
#  'Health care services',
#  'Home entertainment equipment, parts and services',
#  "Homeowners' home and mortgage insurance",
#  "Homeowners' maintenance and repairs",
#  "Homeowners' replacement cost",
#  'Household appliances',
#  'Household cleaning and polishing products',
#  'Household cleaning products',
#  'Household equipment',
#  'Household furnishings and equipment',
#  'Household operations',
#  'Household operations, furnishings and equipment',
#  'Household paper supplies',
#  'Household textiles',
#  'Household tools (including lawn, garden and snow removal equipment',
#  'Housekeeping services',
#  'Ice cream and related products',
#  'Infant formula',
#  'Instant and other coffee',
#  'Insurance, licences and other services for recreational vehicles',
#  'Inter-city transportation',
#  'Internet access services',
#  'Jam, jelly and other preserves',
#  'Jewellery',
#  'Laundry and dishwashing appliances',
#  'Laundry detergents and soaps',
#  'Leasing of passenger vehicles',
#  'Lettuce',
#  'Liquor purchased from stores',
#  'Liquor served in licensed establishments',
#  'Local and commuter transportation',
#  'Low-fat milk',
#  'Magazines and periodicals',
#  'Margarine',
#  'Meat',
#  'Medicinal and pharmaceutical products',
#  'Medicinal cannabis',
#  "Men's clothing",
#  "Men's footwear (excluding athletic",
#  'Mortgage interest cost',
#  'Mozzarella cheese',
#  'Multipurpose digital devices',
#  'Natural gas',
#  'Newspapers',
#  'Non-alcoholic beverages',
#  'Non-electric kitchen utensils, tableware and cookware',
#  'Non-prescribed medicines',
#  'Nut butter',
#  'Nuts and seeds',
#  'Operation of passenger vehicles',
#  'Operation of recreational vehicles',
#  'Oral-hygiene products',
#  'Oranges',
#  'Other bakery products',
#  'Other cultural and recreational services',
#  'Other dairy products',
#  'Other edible fats and oils',
#  'Other food preparations',
#  'Other food products and non-alcoholic beverages',
#  'Other fresh fruit',
#  'Other fresh or frozen meat (excluding poultry',
#  'Other fresh or frozen poultry',
#  'Other fresh vegetables',
#  'Other furniture',
#  'Other health care goods',
#  'Other health care services',
#  'Other horticultural goods',
#  'Other household appliances',
#  'Other household cleaning products',
#  'Other household equipment',
#  'Other household goods and services',
#  'Other household services',
#  'Other household supplies',
#  'Other lessons, courses and education services',
#  'Other owned accommodation expenses',
#  'Other passenger vehicle operating expenses',
#  'Other personal care supplies and equipment',
#  'Other preserved fruit and fruit preparations',
#  'Other processed meat',
#  'Other recreational equipment',
#  'Other shellfish',
#  "Other tobacco products and smokers' supplies",
#  'Owned accommodation',
#  'Paper supplies',
#  'Paper, plastic and aluminum foil supplies',
#  'Parking fees',
#  'Passenger vehicle insurance premiums',
#  'Passenger vehicle maintenance and repair services',
#  'Passenger vehicle parts, accessories and supplies',
#  'Passenger vehicle parts, maintenance and repairs',
#  'Passenger vehicle registration fees',
#  'Pasta mixes',
#  'Pasta products',
#  'Personal care',
#  'Personal care services',
#  'Personal care supplies and equipment',
#  'Personal soap',
#  'Pet food and supplies',
#  'Photographic equipment and supplies',
#  'Plastic and aluminum foil supplies',
#  'Postal and other communications services',
#  'Potato chips and other snack products n.e.c',
#  'Potatoes',
#  'Prescribed medicines (excluding medicinal cannabis',
#  'Preserved fruit and fruit preparations',
#  'Preserved vegetables and vegetable preparations',
#  'Private transportation',
#  'Private transportation excluding gasoline',
#  'Processed cheese',
#  'Processed meat',
#  'Property taxes and other special charges',
#  'Public transportation',
#  'Purchase and leasing of passenger vehicles',
#  'Purchase and operation of recreational vehicles',
#  'Purchase of digital media',
#  'Purchase of new passenger vehicles',
#  'Purchase of passenger vehicles',
#  'Purchase of recreational vehicles and outboard motors',
#  'Purchase of used passenger vehicles',
#  'Purchase, leasing and rental of passenger vehicles',
#  'Rail, highway bus and other inter-city transportation',
#  'Reading material (excluding textbooks',
#  'Recreation',
#  'Recreation, education and reading',
#  'Recreational cannabis',
#  'Recreational equipment and services (excluding recreational vehicles',
#  'Recreational services',
#  'Refrigerators and freezers',
#  'Rent',
#  'Rental of passenger vehicles',
#  'Rented accommodation',
#  'Rice and rice-based mixes',
#  'Roasted or ground coffee',
#  'School textbooks and supplies',
#  'Seafood and other marine products',
#  'Seeds, plants and cut flowers',
#  'Services related to household furnishings and equipment',
#  'Shelter',
#  'Shrimps and prawns',
#  'Soup',
#  'Spectator entertainment (excluding video and audio subscription services',
#  'Sporting and exercise equipment',
#  'Stationery',
#  'Sugar and confectionery',
#  'Sugar and syrup',
#  'Taxi and other local and commuter transportation services',
#  'Tea',
#  'Telephone equipment',
#  'Telephone services',
#  "Tenants' insurance premiums",
#  "Tenants' maintenance, repairs and other expenses",
#  "Tobacco products and smokers' supplies",
#  'Toiletry items and cosmetics',
#  'Tomatoes',
#  'Tools and other household equipment',
#  'Toys, games (excluding video games) and hobby supplies',
#  'Transportation',
#  'Travel services',
#  'Travel tours',
#  'Traveller accommodation',
#  'Tuition fees',
#  'Unripened or fresh cheese',
#  'Upholstered furniture',
#  'Use of recreational facilities and services',
#  'Vegetables and vegetable preparations',
#  'Video and audio subscription services',
#  'Video equipment',
#  'Watches',
#  'Water',
#  'Water, fuel and electricity',
#  'Whole milk',
#  'Window coverings',
#  'Wine purchased from stores',
#  'Wine served in licensed establishments',
#  "Women's clothing",
#  "Women's footwear (excluding athletic",
#  'Wooden furniture']

# %%
def pipline(train_dataset_dict, test_dataset_dict):
    results = {}
    num_categories = 0
    for category_id in list(category_id_to_name_dict.keys()):
        num_categories +=1
        print(f'num categories: {num_categories}')
        category = category_id_to_name_dict[category_id]
        print(f'category id|name: {category_id}|{category}')

        train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category], test_dataset_dict[category])

        model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
        model.to(device)
        
        optimizer = torch.optim.AdamW(model.parameters(), lr=Lr)

        parameters_file_name = category+'.pt'
        
        results[category] = training_and_evaluation(
                                model=model,
                                optim=optimizer,
                                train_dataloader=train_dataloader,
                                test_dataloader=test_dataloader,
                                category=category,
                                checkpoint_path=CheckpointPath+parameters_file_name,
                                best_checkpoint_path=BestcheckpointPath+parameters_file_name,
                            )
    
    return results

# %%
results = pipline(train_dataset_dict, test_dataset_dict)
# Out:
# num categories: 1
# category id|name: 199|Air transportation
# num categories: 2
# category id|name: 257|Alcoholic beverages
# num categories: 3
# category id|name: 262|Alcoholic beverages purchased from stores
# num categories: 4
# category id|name: 258|Alcoholic beverages served in licensed establishments
# num categories: 5
# category id|name: 256|Alcoholic beverages, tobacco products and recreational cannabis
# num categories: 6
# category id|name: 73|All other food preparations
# num categories: 7
# category id|name: 345|All other miscellaneous food preparations
# num categories: 8
# category id|name: 193|All other passenger vehicle operating expenses
# num categories: 9
# category id|name: 2|All-items
# num categories: 10
# category id|name: 290|All-items excluding alcoholic beverages, tobacco products and smokers' supplies and recreational cannabis
# num categories: 11
# category id|name: 287|All-items excluding energy
# num categories: 12
# category id|name: 284|All-items excluding food
# num categories: 13
# category id|name: 285|All-items excluding food and energy
# num categories: 14
# category id|name: 302|All-items excluding gasoline
# num categories: 15
# category id|name: 289|All-items excluding mortgage interest cost
# num categories: 16
# category id|name: 293|All-items excluding shelter
# num categories: 17
# category id|name: 41|Apples
# num categories: 18
# category id|name: 165|Athletic footwear
# num categories: 19
# category id|name: 234|Audio equipment
# num categories: 20
# category id|name: 71|Baby foods
# num categories: 21
# category id|name: 316|Bacon
# num categories: 22
# category id|name: 29|Bakery and cereal products (excluding baby food
# num categories: 23
# category id|name: 30|Bakery products
# num categories: 24
# category id|name: 43|Bananas
# num categories: 25
# category id|name: 124|Bedding and other household textiles
# num categories: 26
# category id|name: 263|Beer purchased from stores
# num categories: 27
# category id|name: 259|Beer served in licensed establishments
# num categories: 28
# category id|name: 349|Bleach and other household chemical products
# num categories: 29
# category id|name: 255|Books and reading material (excluding textbooks
# num categories: 30
# category id|name: 31|Bread, rolls and buns
# num categories: 31
# category id|name: 36|Breakfast cereal and other cereal products (excluding baby food
# num categories: 32
# category id|name: 24|Butter
# num categories: 33
# category id|name: 19|Canned and other preserved fish
# num categories: 34
# category id|name: 332|Canned fruit
# num categories: 35
# category id|name: 341|Canned infant or junior foods
# num categories: 36
# category id|name: 318|Canned salmon
# num categories: 37
# category id|name: 319|Canned tuna
# num categories: 38
# category id|name: 57|Canned vegetables and other vegetable preparations
# num categories: 39
# category id|name: 368|Cellular services
# num categories: 40
# category id|name: 34|Cereal products (excluding baby food
# num categories: 41
# category id|name: 324|Cheddar cheese
# num categories: 42
# category id|name: 25|Cheese
# num categories: 43
# category id|name: 101|Child care and housekeeping services
# num categories: 44
# category id|name: 102|Child care services
# num categories: 45
# category id|name: 155|Children's clothing
# num categories: 46
# category id|name: 164|Children's footwear (excluding athletic
# num categories: 47
# category id|name: 267|Cigarettes
# num categories: 48
# category id|name: 196|City bus and subway transportation
# num categories: 49
# category id|name: 140|Clothing
# num categories: 50
# category id|name: 369|Clothing accessories
# num categories: 51
# category id|name: 166|Clothing accessories, watches and jewellery
# num categories: 52
# category id|name: 139|Clothing and footwear
# num categories: 53
# category id|name: 171|Clothing material, notions and services
# num categories: 54
# category id|name: 66|Coffee
# num categories: 55
# category id|name: 65|Coffee and tea
# num categories: 56
# category id|name: 98|Communications
# num categories: 57
# category id|name: 314|Computer equipment, software and supplies
# num categories: 58
# category id|name: 68|Condiments, spices and vinegars
# num categories: 59
# category id|name: 61|Confectionery
# num categories: 60
# category id|name: 32|Cookies and crackers
# num categories: 61
# category id|name: 128|Cooking appliances
# num categories: 62
# category id|name: 22|Dairy products
# num categories: 63
# category id|name: 21|Dairy products and eggs
# num categories: 64
# category id|name: 210|Dental care services
# num categories: 65
# category id|name: 347|Detergents and rinse agents for dish washing
# num categories: 66
# category id|name: 105|Detergents and soaps (other than personal care
# num categories: 67
# category id|name: 224|Digital computing equipment and devices
# num categories: 68
# category id|name: 334|Dried and dehydrated fruit
# num categories: 69
# category id|name: 191|Drivers' licences
# num categories: 70
# category id|name: 330|Dry or fresh pasta
# num categories: 71
# category id|name: 62|Edible fats and oils
# num categories: 72
# category id|name: 248|Education
# num categories: 73
# category id|name: 247|Education and reading
# num categories: 74
# category id|name: 28|Eggs
# num categories: 75
# category id|name: 92|Electricity
# num categories: 76
# category id|name: 288|Energy
# num categories: 77
# category id|name: 209|Eye care goods
# num categories: 78
# category id|name: 301|Eye care services
# num categories: 79
# category id|name: 350|Fabric softener
# num categories: 80
# category id|name: 298|Financial services
# num categories: 81
# category id|name: 17|Fish
# num categories: 82
# category id|name: 16|Fish, seafood and other marine products
# num categories: 83
# category id|name: 38|Flour and flour-based mixes
# num categories: 84
# category id|name: 3|Food
# num categories: 85
# category id|name: 286|Food and energy
# num categories: 86
# category id|name: 78|Food purchased from cafeterias and other restaurants
# num categories: 87
# category id|name: 77|Food purchased from fast food and take-out restaurants
# num categories: 88
# category id|name: 75|Food purchased from restaurants
# num categories: 89
# category id|name: 4|Food purchased from stores
# num categories: 90
# category id|name: 76|Food purchased from table-service restaurants
# num categories: 91
# category id|name: 161|Footwear
# num categories: 92
# category id|name: 40|Fresh fruit
# num categories: 93
# category id|name: 294|Fresh fruit and vegetables
# num categories: 94
# category id|name: 23|Fresh milk
# num categories: 95
# category id|name: 7|Fresh or frozen beef
# num categories: 96
# category id|name: 11|Fresh or frozen chicken
# num categories: 97
# category id|name: 18|Fresh or frozen fish (including portions and fish sticks
# num categories: 98
# category id|name: 6|Fresh or frozen meat (excluding poultry
# num categories: 99
# category id|name: 8|Fresh or frozen pork
# num categories: 100
# category id|name: 10|Fresh or frozen poultry
# num categories: 101
# category id|name: 50|Fresh vegetables
# num categories: 102
# category id|name: 56|Frozen and dried vegetables
# num categories: 103
# category id|name: 72|Frozen food preparations
# num categories: 104
# category id|name: 335|Frozen fruit
# num categories: 105
# category id|name: 46|Fruit juices
# num categories: 106
# category id|name: 39|Fruit, fruit preparations and nuts
# num categories: 107
# category id|name: 95|Fuel oil and other fuels
# num categories: 108
# category id|name: 231|Fuel, parts and accessories for recreational vehicles
# num categories: 109
# category id|name: 118|Furniture
# num categories: 110
# category id|name: 117|Furniture and household textiles
# num categories: 111
# category id|name: 184|Gasoline
# num categories: 112
# category id|name: 14|Ham and bacon
# num categories: 113
# category id|name: 317|Ham excluding deli ham
# num categories: 114
# category id|name: 201|Health and personal care
# num categories: 115
# category id|name: 202|Health care
# num categories: 116
# category id|name: 310|Health care goods
# num categories: 117
# category id|name: 311|Health care services
# num categories: 118
# category id|name: 233|Home entertainment equipment, parts and services
# num categories: 119
# category id|name: 88|Homeowners' home and mortgage insurance
# num categories: 120
# category id|name: 89|Homeowners' maintenance and repairs
# num categories: 121
# category id|name: 86|Homeowners' replacement cost
# num categories: 122
# category id|name: 127|Household appliances
# num categories: 123
# category id|name: 348|Household cleaning and polishing products
# num categories: 124
# category id|name: 104|Household cleaning products
# num categories: 125
# category id|name: 126|Household equipment
# num categories: 126
# category id|name: 116|Household furnishings and equipment
# num categories: 127
# category id|name: 97|Household operations
# num categories: 128
# category id|name: 96|Household operations, furnishings and equipment
# num categories: 129
# category id|name: 351|Household paper supplies
# num categories: 130
# category id|name: 122|Household textiles
# num categories: 131
# category id|name: 136|Household tools (including lawn, garden and snow removal equipment
# num categories: 132
# category id|name: 103|Housekeeping services
# num categories: 133
# category id|name: 26|Ice cream and related products
# num categories: 134
# category id|name: 342|Infant formula
# num categories: 135
# category id|name: 337|Instant and other coffee
# num categories: 136
# category id|name: 232|Insurance, licences and other services for recreational vehicles
# num categories: 137
# category id|name: 198|Inter-city transportation
# num categories: 138
# category id|name: 297|Internet access services
# num categories: 139
# category id|name: 333|Jam, jelly and other preserves
# num categories: 140
# category id|name: 169|Jewellery
# num categories: 141
# category id|name: 130|Laundry and dishwashing appliances
# num categories: 142
# category id|name: 346|Laundry detergents and soaps
# num categories: 143
# category id|name: 181|Leasing of passenger vehicles
# num categories: 144
# category id|name: 53|Lettuce
# num categories: 145
# category id|name: 265|Liquor purchased from stores
# num categories: 146
# category id|name: 261|Liquor served in licensed establishments
# num categories: 147
# category id|name: 195|Local and commuter transportation
# num categories: 148
# category id|name: 323|Low-fat milk
# num categories: 149
# category id|name: 254|Magazines and periodicals
# num categories: 150
# category id|name: 63|Margarine
# num categories: 151
# category id|name: 5|Meat
# num categories: 152
# category id|name: 204|Medicinal and pharmaceutical products
# num categories: 153
# category id|name: 366|Medicinal cannabis
# num categories: 154
# category id|name: 148|Men's clothing
# num categories: 155
# category id|name: 163|Men's footwear (excluding athletic
# num categories: 156
# category id|name: 85|Mortgage interest cost
# num categories: 157
# category id|name: 327|Mozzarella cheese
# num categories: 158
# category id|name: 315|Multipurpose digital devices
# num categories: 159
# category id|name: 94|Natural gas
# num categories: 160
# category id|name: 253|Newspapers
# num categories: 161
# category id|name: 74|Non-alcoholic beverages
# num categories: 162
# category id|name: 132|Non-electric kitchen utensils, tableware and cookware
# num categories: 163
# category id|name: 206|Non-prescribed medicines
# num categories: 164
# category id|name: 343|Nut butter
# num categories: 165
# category id|name: 48|Nuts and seeds
# num categories: 166
# category id|name: 183|Operation of passenger vehicles
# num categories: 167
# category id|name: 230|Operation of recreational vehicles
# num categories: 168
# category id|name: 216|Oral-hygiene products
# num categories: 169
# category id|name: 42|Oranges
# num categories: 170
# category id|name: 33|Other bakery products
# num categories: 171
# category id|name: 243|Other cultural and recreational services
# num categories: 172
# category id|name: 27|Other dairy products
# num categories: 173
# category id|name: 64|Other edible fats and oils
# num categories: 174
# category id|name: 69|Other food preparations
# num categories: 175
# category id|name: 58|Other food products and non-alcoholic beverages
# num categories: 176
# category id|name: 44|Other fresh fruit
# num categories: 177
# category id|name: 9|Other fresh or frozen meat (excluding poultry
# num categories: 178
# category id|name: 12|Other fresh or frozen poultry
# num categories: 179
# category id|name: 54|Other fresh vegetables
# num categories: 180
# category id|name: 121|Other furniture
# num categories: 181
# category id|name: 207|Other health care goods
# num categories: 182
# category id|name: 211|Other health care services
# num categories: 183
# category id|name: 113|Other horticultural goods
# num categories: 184
# category id|name: 131|Other household appliances
# num categories: 185
# category id|name: 106|Other household cleaning products
# num categories: 186
# category id|name: 137|Other household equipment
# num categories: 187
# category id|name: 110|Other household goods and services
# num categories: 188
# category id|name: 115|Other household services
# num categories: 189
# category id|name: 114|Other household supplies
# num categories: 190
# category id|name: 251|Other lessons, courses and education services
# num categories: 191
# category id|name: 90|Other owned accommodation expenses
# num categories: 192
# category id|name: 188|Other passenger vehicle operating expenses
# num categories: 193
# category id|name: 217|Other personal care supplies and equipment
# num categories: 194
# category id|name: 47|Other preserved fruit and fruit preparations
# num categories: 195
# category id|name: 15|Other processed meat
# num categories: 196
# category id|name: 227|Other recreational equipment
# num categories: 197
# category id|name: 321|Other shellfish
# num categories: 198
# category id|name: 268|Other tobacco products and smokers' supplies
# num categories: 199
# category id|name: 84|Owned accommodation
# num categories: 200
# category id|name: 108|Paper supplies
# num categories: 201
# category id|name: 107|Paper, plastic and aluminum foil supplies
# num categories: 202
# category id|name: 192|Parking fees
# num categories: 203
# category id|name: 189|Passenger vehicle insurance premiums
# num categories: 204
# category id|name: 187|Passenger vehicle maintenance and repair services
# num categories: 205
# category id|name: 186|Passenger vehicle parts, accessories and supplies
# num categories: 206
# category id|name: 185|Passenger vehicle parts, maintenance and repairs
# num categories: 207
# category id|name: 190|Passenger vehicle registration fees
# num categories: 208
# category id|name: 331|Pasta mixes
# num categories: 209
# category id|name: 37|Pasta products
# num categories: 210
# category id|name: 212|Personal care
# num categories: 211
# category id|name: 218|Personal care services
# num categories: 212
# category id|name: 213|Personal care supplies and equipment
# num categories: 213
# category id|name: 214|Personal soap
# num categories: 214
# category id|name: 111|Pet food and supplies
# num categories: 215
# category id|name: 305|Photographic equipment and supplies
# num categories: 216
# category id|name: 109|Plastic and aluminum foil supplies
# num categories: 217
# category id|name: 100|Postal and other communications services
# num categories: 218
# category id|name: 344|Potato chips and other snack products n.e.c
# num categories: 219
# category id|name: 51|Potatoes
# num categories: 220
# category id|name: 205|Prescribed medicines (excluding medicinal cannabis
# num categories: 221
# category id|name: 45|Preserved fruit and fruit preparations
# num categories: 222
# category id|name: 55|Preserved vegetables and vegetable preparations
# num categories: 223
# category id|name: 177|Private transportation
# num categories: 224
# category id|name: 312|Private transportation excluding gasoline
# num categories: 225
# category id|name: 325|Processed cheese
# num categories: 226
# category id|name: 13|Processed meat
# num categories: 227
# category id|name: 87|Property taxes and other special charges
# num categories: 228
# category id|name: 194|Public transportation
# num categories: 229
# category id|name: 179|Purchase and leasing of passenger vehicles
# num categories: 230
# category id|name: 228|Purchase and operation of recreational vehicles
# num categories: 231
# category id|name: 308|Purchase of digital media
# num categories: 232
# category id|name: 371|Purchase of new passenger vehicles
# num categories: 233
# category id|name: 180|Purchase of passenger vehicles
# num categories: 234
# category id|name: 229|Purchase of recreational vehicles and outboard motors
# num categories: 235
# category id|name: 372|Purchase of used passenger vehicles
# num categories: 236
# category id|name: 178|Purchase, leasing and rental of passenger vehicles
# num categories: 237
# category id|name: 200|Rail, highway bus and other inter-city transportation
# num categories: 238
# category id|name: 252|Reading material (excluding textbooks
# num categories: 239
# category id|name: 220|Recreation
# num categories: 240
# category id|name: 219|Recreation, education and reading
# num categories: 241
# category id|name: 367|Recreational cannabis
# num categories: 242
# category id|name: 221|Recreational equipment and services (excluding recreational vehicles
# num categories: 243
# category id|name: 306|Recreational services
# num categories: 244
# category id|name: 129|Refrigerators and freezers
# num categories: 245
# category id|name: 81|Rent
# num categories: 246
# category id|name: 182|Rental of passenger vehicles
# num categories: 247
# category id|name: 80|Rented accommodation
# num categories: 248
# category id|name: 35|Rice and rice-based mixes
# num categories: 249
# category id|name: 336|Roasted or ground coffee
# num categories: 250
# category id|name: 250|School textbooks and supplies
# num categories: 251
# category id|name: 20|Seafood and other marine products
# num categories: 252
# category id|name: 112|Seeds, plants and cut flowers
# num categories: 253
# category id|name: 138|Services related to household furnishings and equipment
# num categories: 254
# category id|name: 79|Shelter
# num categories: 255
# category id|name: 320|Shrimps and prawns
# num categories: 256
# category id|name: 70|Soup
# num categories: 257
# category id|name: 244|Spectator entertainment (excluding video and audio subscription services
# num categories: 258
# category id|name: 222|Sporting and exercise equipment
# num categories: 259
# category id|name: 352|Stationery
# num categories: 260
# category id|name: 59|Sugar and confectionery
# num categories: 261
# category id|name: 60|Sugar and syrup
# num categories: 262
# category id|name: 197|Taxi and other local and commuter transportation services
# num categories: 263
# category id|name: 67|Tea
# num categories: 264
# category id|name: 313|Telephone equipment
# num categories: 265
# category id|name: 99|Telephone services
# num categories: 266
# category id|name: 82|Tenants' insurance premiums
# num categories: 267
# category id|name: 83|Tenants' maintenance, repairs and other expenses
# num categories: 268
# category id|name: 266|Tobacco products and smokers' supplies
# num categories: 269
# category id|name: 215|Toiletry items and cosmetics
# num categories: 270
# category id|name: 52|Tomatoes
# num categories: 271
# category id|name: 135|Tools and other household equipment
# num categories: 272
# category id|name: 304|Toys, games (excluding video games) and hobby supplies
# num categories: 273
# category id|name: 176|Transportation
# num categories: 274
# category id|name: 240|Travel services
# num categories: 275
# category id|name: 242|Travel tours
# num categories: 276
# category id|name: 241|Traveller accommodation
# num categories: 277
# category id|name: 249|Tuition fees
# num categories: 278
# category id|name: 326|Unripened or fresh cheese
# num categories: 279
# category id|name: 119|Upholstered furniture
# num categories: 280
# category id|name: 246|Use of recreational facilities and services
# num categories: 281
# category id|name: 49|Vegetables and vegetable preparations
# num categories: 282
# category id|name: 245|Video and audio subscription services
# num categories: 283
# category id|name: 236|Video equipment
# num categories: 284
# category id|name: 168|Watches
# num categories: 285
# category id|name: 93|Water
# num categories: 286
# category id|name: 91|Water, fuel and electricity
# num categories: 287
# category id|name: 322|Whole milk
# num categories: 288
# category id|name: 123|Window coverings
# num categories: 289
# category id|name: 264|Wine purchased from stores
# num categories: 290
# category id|name: 260|Wine served in licensed establishments
# num categories: 291
# category id|name: 141|Women's clothing
# num categories: 292
# category id|name: 162|Women's footwear (excluding athletic
# num categories: 293
# category id|name: 120|Wooden furniture

# %%
with open('data/model_results.pickle', 'wb') as handle:
    pickle.dump(results, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Create Best Model Per Category Dictionary

# %%
def create_dict_of_best_model_per_category(categories_list, dir_path):
    basic_model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
    basic_optimizer = torch.optim.AdamW(basic_model.parameters(), lr=Lr)
    basic_model.to(device)

    best_models_dict = {}

    for category in categories_list:
        ckp_path = dir_path+category+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        best_models_dict[category] = model
        
    return best_models_dict

# %%
categories_list = categories
dir_path = "checkpoints/best_checkpoints/"

best_models_dict = create_dict_of_best_model_per_category(categories_list, dir_path)

# %%
best_models_dict
# Out:
# {'Air transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Alcoholic beverages': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Alcoholic beverages purchased from stores': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Alcoholic beverages served in licensed establishments': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Alcoholic beverages, tobacco products and recreational cannabis': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All other food preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All other miscellaneous food preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All other passenger vehicle operating expenses': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "All-items excluding alcoholic beverages, tobacco products and smokers' supplies and recreational cannabis": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding energy': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding food': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding food and energy': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding gasoline': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding mortgage interest cost': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'All-items excluding shelter': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Apples': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Athletic footwear': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Audio equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Baby foods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bacon': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bakery and cereal products (excluding baby food': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bakery products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bananas': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bedding and other household textiles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Beer purchased from stores': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Beer served in licensed establishments': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bleach and other household chemical products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Books and reading material (excluding textbooks': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Bread, rolls and buns': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Breakfast cereal and other cereal products (excluding baby food': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Butter': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned and other preserved fish': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned fruit': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned infant or junior foods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned salmon': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned tuna': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Canned vegetables and other vegetable preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cellular services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cereal products (excluding baby food': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cheddar cheese': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cheese': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Child care and housekeeping services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Child care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Children's clothing": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Children's footwear (excluding athletic": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cigarettes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'City bus and subway transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Clothing': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Clothing accessories': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Clothing accessories, watches and jewellery': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Clothing and footwear': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Clothing material, notions and services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Coffee': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Coffee and tea': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Communications': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Computer equipment, software and supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Condiments, spices and vinegars': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Confectionery': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cookies and crackers': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Cooking appliances': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Dairy products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Dairy products and eggs': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Dental care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Detergents and rinse agents for dish washing': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Detergents and soaps (other than personal care': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Digital computing equipment and devices': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Dried and dehydrated fruit': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Drivers' licences": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Dry or fresh pasta': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Edible fats and oils': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Education': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Education and reading': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Eggs': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Electricity': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Energy': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Eye care goods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Eye care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fabric softener': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Financial services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fish': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fish, seafood and other marine products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Flour and flour-based mixes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food and energy': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food purchased from cafeterias and other restaurants': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food purchased from fast food and take-out restaurants': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food purchased from restaurants': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food purchased from stores': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Food purchased from table-service restaurants': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Footwear': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh fruit': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh fruit and vegetables': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh milk': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen beef': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen chicken': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen fish (including portions and fish sticks': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen meat (excluding poultry': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen pork': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh or frozen poultry': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fresh vegetables': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Frozen and dried vegetables': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Frozen food preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Frozen fruit': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fruit juices': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fruit, fruit preparations and nuts': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fuel oil and other fuels': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Fuel, parts and accessories for recreational vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Furniture': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Furniture and household textiles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Gasoline': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Ham and bacon': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Ham excluding deli ham': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Health and personal care': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Health care': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Health care goods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Health care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Home entertainment equipment, parts and services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Homeowners' home and mortgage insurance": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Homeowners' maintenance and repairs": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Homeowners' replacement cost": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household appliances': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household cleaning and polishing products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household cleaning products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household furnishings and equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household operations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household operations, furnishings and equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household paper supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household textiles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Household tools (including lawn, garden and snow removal equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Housekeeping services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Ice cream and related products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Infant formula': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Instant and other coffee': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Insurance, licences and other services for recreational vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Inter-city transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Internet access services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Jam, jelly and other preserves': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Jewellery': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Laundry and dishwashing appliances': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Laundry detergents and soaps': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Leasing of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Lettuce': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Liquor purchased from stores': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Liquor served in licensed establishments': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Local and commuter transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Low-fat milk': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Magazines and periodicals': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Margarine': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Meat': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Medicinal and pharmaceutical products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Medicinal cannabis': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Men's clothing": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Men's footwear (excluding athletic": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Mortgage interest cost': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Mozzarella cheese': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Multipurpose digital devices': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Natural gas': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Newspapers': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Non-alcoholic beverages': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Non-electric kitchen utensils, tableware and cookware': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Non-prescribed medicines': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Nut butter': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Nuts and seeds': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Operation of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Operation of recreational vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Oral-hygiene products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Oranges': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other bakery products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other cultural and recreational services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other dairy products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other edible fats and oils': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other food preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other food products and non-alcoholic beverages': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other fresh fruit': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other fresh or frozen meat (excluding poultry': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other fresh or frozen poultry': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other fresh vegetables': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other furniture': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other health care goods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other health care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other horticultural goods': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household appliances': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household cleaning products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household goods and services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other household supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other lessons, courses and education services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other owned accommodation expenses': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other passenger vehicle operating expenses': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other personal care supplies and equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other preserved fruit and fruit preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other processed meat': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other recreational equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Other shellfish': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Other tobacco products and smokers' supplies": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Owned accommodation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Paper supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Paper, plastic and aluminum foil supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Parking fees': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Passenger vehicle insurance premiums': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Passenger vehicle maintenance and repair services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Passenger vehicle parts, accessories and supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Passenger vehicle parts, maintenance and repairs': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Passenger vehicle registration fees': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Pasta mixes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Pasta products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Personal care': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Personal care services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Personal care supplies and equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Personal soap': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Pet food and supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Photographic equipment and supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Plastic and aluminum foil supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Postal and other communications services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Potato chips and other snack products n.e.c': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Potatoes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Prescribed medicines (excluding medicinal cannabis': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Preserved fruit and fruit preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Preserved vegetables and vegetable preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Private transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Private transportation excluding gasoline': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Processed cheese': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Processed meat': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Property taxes and other special charges': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Public transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase and leasing of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase and operation of recreational vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase of digital media': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase of new passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase of recreational vehicles and outboard motors': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase of used passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Purchase, leasing and rental of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Rail, highway bus and other inter-city transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Reading material (excluding textbooks': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Recreation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Recreation, education and reading': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Recreational cannabis': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Recreational equipment and services (excluding recreational vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Recreational services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Refrigerators and freezers': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Rent': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Rental of passenger vehicles': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Rented accommodation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Rice and rice-based mixes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Roasted or ground coffee': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'School textbooks and supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Seafood and other marine products': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Seeds, plants and cut flowers': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Services related to household furnishings and equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Shelter': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Shrimps and prawns': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Soup': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Spectator entertainment (excluding video and audio subscription services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Sporting and exercise equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Stationery': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Sugar and confectionery': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Sugar and syrup': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Taxi and other local and commuter transportation services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Tea': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Telephone equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Telephone services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Tenants' insurance premiums": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Tenants' maintenance, repairs and other expenses": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Tobacco products and smokers' supplies": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Toiletry items and cosmetics': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Tomatoes': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Tools and other household equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Toys, games (excluding video games) and hobby supplies': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Transportation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Travel services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Travel tours': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Traveller accommodation': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Tuition fees': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Unripened or fresh cheese': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Upholstered furniture': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Use of recreational facilities and services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Vegetables and vegetable preparations': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Video and audio subscription services': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Video equipment': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Watches': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Water': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Water, fuel and electricity': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Whole milk': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Window coverings': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Wine purchased from stores': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Wine served in licensed establishments': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Women's clothing": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  "Women's footwear (excluding athletic": GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  ),
#  'Wooden furniture': GRUModel(
#    (gru): GRU(1, 64, batch_first=True)
#    (fc): Linear(in_features=64, out_features=1, bias=True)
#  )}

# %% [markdown]
# # Get Best Predictions for Each Category

# %%
def get_best_predictions_for_each_category(best_models_dict):
    best_predictions_dict = {}

    for category in list(best_models_dict.keys()):
        model = best_models_dict[category]
        train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category], test_dataset_dict[category])
        epoch_test_loss, epoch_predictions = evaluation_loop(model, test_dataloader)
        best_predictions_dict[category] = epoch_predictions

    return best_predictions_dict

# %%
best_predictions_dict = get_best_predictions_for_each_category(best_models_dict)

# %%
with open('data/predictions_dict.pickle', 'wb') as handle:
    pickle.dump(best_predictions_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Get Best Model Weights:

# %%
def get_weights_per_category(category_list, dir_path):
    weights = {}
    for category in category_list:
        model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
        model.to(device)
        optimizer = torch.optim.AdamW(model.parameters(), lr=Lr)
        
        best_checkpoint_path = dir_path + category + '.pt'

        category_model, optimizer, checkpoint, valid_loss_min = load_checkpoint(best_checkpoint_path, model, optimizer)
        category_model_weights = unify_model_weights(category_model)

        weights[category] = category_model_weights
    
    return weights

# %%
def get_weights_per_category(category_id_list, dir_path):
    basic_model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
    basic_optimizer = torch.optim.AdamW(basic_model.parameters(), lr=Lr)
    basic_model.to(device)

    best_models_weights_dict = {}

    for category_id in category_id_list:
        category_name = category_id_to_name_dict[category_id]
        ckp_path = dir_path+category_name+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        category_model_weights = unify_model_weights(model)
        best_models_weights_dict[category_id] = category_model_weights
        
    return best_models_weights_dict

# %%
dir_path = '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/CPI_HRNN - version 2.0/mayas_project/basic_model_canada/checkpoints/best_checkpoints/'

# %%
category_id_list = []
 
# list out keys and values separately
key_list = list(category_id_to_name_dict.keys())
val_list = list(category_id_to_name_dict.values())

for cat_name in categories:
    position = val_list.index(cat_name)
    category_id_list.append(key_list[position])

# %%
weights_dict = get_weights_per_category(category_id_list, dir_path)

# %%
with open('/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/CPI_HRNN - version 2.0/pickle files/canada_sgru_model_weights.pickle', 'wb') as handle:
    pickle.dump(weights_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
weights_dict
# Out:
# {199: tensor([[-4.3598e-01, -5.1649e-01,  1.9278e+00,  ..., -7.4752e-01,
#           -1.5561e+00, -1.4276e+00],
#          [-1.6957e+00,  6.8592e-01,  2.5763e+00,  ...,  8.6405e-01,
#           -1.5082e+00, -1.4065e+00],
#          [-7.3825e-01, -1.7128e+00,  4.4863e-01,  ..., -6.8204e-01,
#           -7.9637e-01, -7.6095e-01],
#          ...,
#          [-1.2029e+00,  9.9669e-01,  2.3412e+00,  ..., -3.4928e+00,
#            2.0597e+00,  2.9967e+00],
#          [ 2.2098e+00,  9.1175e-01, -1.1350e+00,  ...,  7.2854e-01,
#            1.1073e+00, -1.1667e-03],
#          [-1.1837e+00, -8.5766e-01, -2.5519e+00,  ...,  2.4984e-01,
#           -4.7139e-02, -3.4983e-01]], grad_fn=<CatBackward0>),
#  257: tensor([[-0.0228, -0.2639,  0.0242,  ...,  0.0088,  0.2369,  0.2643],
#          [-0.0677, -0.2751, -0.3077,  ...,  0.2869,  0.1103,  0.1057],
#          [-0.4250,  0.2204,  0.0278,  ..., -0.0290,  0.1426,  0.1284],
#          ...,
#          [-0.6318,  0.1910,  0.1535,  ..., -0.1426,  0.3861,  0.6160],
#          [ 0.0354,  0.2189,  0.2775,  ..., -0.2120,  0.2156,  0.1682],
#          [-0.0032,  0.2121,  0.2310,  ..., -0.2357,  0.2051,  0.1531]],
#         grad_fn=<CatBackward0>),
#  262: tensor([[-0.5666, -0.4132,  0.3645,  ..., -0.4511, -0.4292, -0.4781],
#          [-0.2549,  0.0339, -0.2555,  ..., -0.0774, -0.4553, -0.3659],
#          [ 0.4130, -0.6492,  0.5952,  ..., -0.5891, -0.4903, -0.5032],
#          ...,
#          [-0.9865,  0.4083, -0.4386,  ...,  0.6133, -0.4450,  0.0359],
#          [-0.9760,  0.3023, -0.5188,  ...,  0.3653, -0.0134, -0.3028],
#          [ 0.4179, -0.4560,  0.4330,  ..., -0.5411,  0.2861,  0.0998]],
#         grad_fn=<CatBackward0>),
#  258: tensor([[-0.1168, -0.1975, -0.1823,  ...,  0.1990, -0.2006, -0.2198],
#          [-0.2627,  0.2193,  0.1305,  ..., -0.2168, -0.3003, -0.2768],
#          [-0.2806,  0.1683,  0.2059,  ..., -0.1326, -0.2466, -0.2482],
#          ...,
#          [ 0.2831, -0.0224, -0.1216,  ...,  0.1112,  0.1078,  0.1131],
#          [-0.0929,  0.0364,  0.0980,  ..., -0.1059, -0.1247, -0.0960],
#          [ 0.4295,  0.0352, -0.1107,  ...,  0.1981,  0.1493,  0.2073]],
#         grad_fn=<CatBackward0>),
#  256: tensor([[-0.3468, -0.5429, -0.5634,  ..., -0.7340, -0.5878, -0.5258],
#          [ 0.8545,  0.1573,  0.0559,  ...,  0.2151, -0.4485, -0.5199],
#          [-0.5077, -0.5212, -0.5393,  ..., -0.7045, -0.5223, -0.5724],
#          ...,
#          [-0.2948, -0.5221, -0.5367,  ..., -0.6000, -0.0420, -0.5920],
#          [-0.3554,  0.0609,  0.3928,  ...,  0.3959, -0.3591, -0.0995],
#          [ 0.3423,  0.5083,  0.5853,  ...,  0.5043,  0.3817,  0.3908]],
#         grad_fn=<CatBackward0>),
#  73: tensor([[ 0.4243,  0.4197,  0.3816,  ..., -0.6368,  1.4173,  1.4387],
#          [-1.0049,  0.2324,  0.5424,  ..., -0.5744,  0.2875,  0.3129],
#          [-0.1437,  0.3085, -0.0739,  ..., -0.0889,  0.3940,  0.4283],
#          ...,
#          [-0.5443,  0.6609, -1.2456,  ...,  0.5699,  0.5586,  1.0039],
#          [-1.2230,  0.2906,  0.9959,  ..., -0.1108,  1.7624,  0.8224],
#          [-1.0022,  0.6102,  0.3364,  ..., -0.0518, -0.2463, -0.3357]],
#         grad_fn=<CatBackward0>),
#  345: tensor([[ 0.1494, -0.6712, -0.4827,  ...,  0.5462, -0.7934, -0.7967],
#          [-0.3415, -0.4472, -0.3715,  ...,  0.5558, -0.6757, -0.4576],
#          [-0.5007,  0.4623,  0.7694,  ..., -0.4900,  0.1551,  0.2243],
#          ...,
#          [ 0.2888,  0.4783,  0.4513,  ..., -0.4766,  0.0567,  0.0645],
#          [-0.1499,  0.6458,  0.5065,  ..., -0.5857,  0.6821,  0.8006],
#          [ 0.4756,  0.4443,  0.2163,  ..., -0.3761,  0.2132,  0.3081]],
#         grad_fn=<CatBackward0>),
#  193: tensor([[ 0.1825,  0.1429,  0.2940,  ...,  0.0058, -0.4781, -0.4519],
#          [-0.1760, -0.2557,  0.1912,  ..., -0.2318, -0.2386, -0.1797],
#          [ 0.0991,  0.1615,  0.2835,  ..., -0.0781, -0.3290, -0.3595],
#          ...,
#          [-0.0298,  0.0963,  0.1989,  ...,  0.0344, -0.0812, -0.1473],
#          [ 0.1265,  0.0821,  0.2371,  ...,  0.0782, -0.0934, -0.1464],
#          [-0.4202, -0.1588,  0.0142,  ...,  0.1698, -0.0068, -0.0489]],
#         grad_fn=<CatBackward0>),
#  2: tensor([[-0.4216,  0.0780,  0.1747,  ..., -0.0969, -0.2337, -0.2835],
#          [ 0.1161,  0.0409, -0.1412,  ...,  0.0284,  0.0683,  0.0599],
#          [-0.1215,  0.0222,  0.0058,  ...,  0.0467,  0.0750,  0.0734],
#          ...,
#          [ 0.2333,  0.0858,  0.0107,  ..., -0.0052,  0.1308,  0.1566],
#          [ 0.2528,  0.2318,  0.1241,  ..., -0.1292,  0.1246,  0.1217],
#          [-0.3264, -0.0738,  0.1394,  ..., -0.3610, -0.0306,  0.0168]],
#         grad_fn=<CatBackward0>),
#  290: tensor([[-3.5532, -0.0337, -0.1611,  ..., -0.4234, -0.4612, -0.4731],
#          [-0.6344, -0.6124, -0.8496,  ...,  0.7939, -0.8457, -0.9452],
#          [-0.8037, -0.6160, -0.6507,  ...,  0.6538, -0.7351, -0.8445],
#          ...,
#          [ 0.9267,  0.4893,  0.4157,  ..., -0.1931, -0.2913, -0.0768],
#          [-0.0577, -0.7209,  0.1111,  ..., -0.0537,  0.4859,  0.3182],
#          [ 0.6337,  0.3053, -0.3039,  ...,  0.3310, -0.4637, -0.0477]],
#         grad_fn=<CatBackward0>),
#  287: tensor([[ 0.4092,  0.5339, -0.4496,  ..., -0.4777,  0.7548,  0.6667],
#          [-0.4465, -0.8797,  0.7243,  ...,  0.6168, -0.2478, -0.3574],
#          [-0.0456,  0.4652, -0.0013,  ...,  0.2418,  0.4611,  0.4042],
#          ...,
#          [ 0.6662, -0.2663, -0.0492,  ..., -0.3002,  0.6728,  0.6378],
#          [ 1.0200,  0.8215, -0.4581,  ..., -0.0390,  0.3043,  0.4778],
#          [-0.3640,  0.0654, -0.0933,  ...,  0.3431, -0.4898, -0.2011]],
#         grad_fn=<CatBackward0>),
#  284: tensor([[-0.0553, -0.1052,  0.1998,  ...,  0.1092,  0.0459,  0.0686],
#          [-0.2215,  0.0970, -0.1114,  ..., -0.1575, -0.2234, -0.2378],
#          [-0.1371,  0.1111, -0.2092,  ..., -0.1528, -0.2570, -0.2615],
#          ...,
#          [-1.1686,  0.1254, -0.1801,  ..., -0.1211, -0.2603, -0.3468],
#          [ 0.6654, -0.1960,  0.1413,  ...,  0.2223,  0.2495,  0.4182],
#          [-0.0214, -0.0890,  0.1706,  ...,  0.0675,  0.1328,  0.1049]],
#         grad_fn=<CatBackward0>),
#  285: tensor([[ 0.1719,  0.0915, -0.2782,  ..., -0.2809, -0.1208, -0.1040],
#          [-0.3190,  0.2168, -0.2546,  ..., -0.3242, -0.3938, -0.2300],
#          [ 0.3667, -0.1122,  0.1387,  ...,  0.1497,  0.0772,  0.0809],
#          ...,
#          [ 0.0409, -0.1330,  0.3309,  ...,  0.1346,  0.2397,  0.4550],
#          [ 0.0979,  0.4318, -0.2630,  ..., -0.5417, -0.2679, -0.2729],
#          [-0.3209,  0.2959, -0.4008,  ..., -0.1967, -0.2599, -0.2015]],
#         grad_fn=<CatBackward0>),
#  302: tensor([[ 0.7431,  0.6086, -0.0181,  ...,  0.8905,  0.7199,  0.8612],
#          [-0.7690, -0.5428,  0.1214,  ..., -0.5048, -0.8991, -0.8763],
#          [-0.5399, -0.8313, -0.1825,  ..., -0.8044, -0.4243, -0.4129],
#          ...,
#          [-0.9372, -0.6388,  0.1794,  ..., -0.7516, -0.7095, -0.8008],
#          [ 0.4647, -0.2481,  0.0433,  ..., -0.3247,  0.6344,  0.5274],
#          [ 0.6782,  0.6402,  0.0626,  ...,  0.7820,  0.6550,  0.7689]],
#         grad_fn=<CatBackward0>),
#  289: tensor([[-0.7395, -0.8207, -0.8096,  ..., -0.8945, -0.8425, -0.8328],
#          [-0.8899, -0.7616, -0.8980,  ..., -0.7798, -0.8274, -0.7306],
#          [-0.7366, -0.6043, -0.6041,  ..., -0.5166, -0.6435, -0.5264],
#          ...,
#          [-0.8105, -0.5568, -0.3726,  ..., -0.3395, -0.0493, -0.2826],
#          [-0.7606,  0.1887,  0.2304,  ...,  0.2704,  0.2592,  0.1108],
#          [ 0.0504, -0.0895, -0.1980,  ..., -0.2980,  0.0784, -0.1503]],
#         grad_fn=<CatBackward0>),
#  293: tensor([[ 0.2996, -0.2978, -0.5979,  ..., -0.4248,  0.3790,  0.2366],
#          [-0.0895,  0.2778,  0.5739,  ...,  0.3629, -0.5381, -0.5213],
#          [ 0.1727, -0.4556, -0.5992,  ..., -0.7433,  0.1177,  0.1458],
#          ...,
#          [-0.3890,  0.5464,  0.6918,  ...,  0.5309, -0.2803, -0.2644],
#          [ 0.7298, -0.5780, -0.2818,  ..., -0.0243,  0.3719,  0.3627],
#          [ 0.5115, -0.4133, -0.1338,  ..., -0.0082,  0.7384,  0.7596]],
#         grad_fn=<CatBackward0>),
#  41: tensor([[-2.0693,  1.0547, -1.0603,  ...,  0.6479, -2.4679, -2.4942],
#          [ 0.4264, -0.2817,  2.0068,  ...,  1.8756, -3.1334, -3.1103],
#          [-1.7518, -2.3729,  0.6053,  ...,  1.8922, -1.8755, -1.9076],
#          ...,
#          [-0.8911, -3.7769,  3.1048,  ...,  2.0356,  0.9628,  0.0604],
#          [ 0.3182,  0.1700, -0.9876,  ...,  0.3108,  3.3692,  1.0971],
#          [ 0.7855, -1.9452,  0.0215,  ...,  0.4599, -0.4120, -0.8844]],
#         grad_fn=<CatBackward0>),
#  165: tensor([[ 0.8058,  0.2621,  0.2275,  ..., -0.0867, -0.4712, -0.3855],
#          [ 0.7261, -0.6937,  0.5926,  ..., -0.1193, -0.5314, -0.6485],
#          [-0.1192,  1.2290,  0.3781,  ..., -0.1459,  0.7612,  0.7391],
#          ...,
#          [-0.6073, -0.4057,  0.0417,  ...,  0.5231, -0.2332, -0.1283],
#          [ 0.1961,  0.0052, -0.3255,  ...,  0.5233, -0.5232, -0.2978],
#          [ 0.2890,  0.2543, -0.2332,  ...,  0.1684, -0.1222, -0.0051]],
#         grad_fn=<CatBackward0>),
#  234: tensor([[ 0.0387, -0.0400,  0.3610,  ...,  0.0515,  0.0808,  0.0443],
#          [ 0.0783, -0.2331, -0.1571,  ..., -0.1953, -0.5076, -0.3114],
#          [-0.2114, -0.4916,  0.2761,  ..., -0.0701, -0.1524, -0.1272],
#          ...,
#          [-0.1433,  0.0402,  0.2559,  ...,  0.4222, -0.0386,  0.1066],
#          [-0.2317,  0.2769,  0.2328,  ...,  0.1772,  0.0229,  0.0889],
#          [-0.2427,  0.0067,  0.1455,  ..., -0.1995,  0.3386,  0.2652]],
#         grad_fn=<CatBackward0>),
#  71: tensor([[ 0.4300,  0.2601, -0.9723,  ..., -0.0395,  0.3101,  0.3469],
#          [-0.4048,  0.2136,  0.6105,  ...,  0.1490,  0.4637,  0.5927],
#          [ 0.4411,  0.5454, -1.8769,  ..., -1.2473,  0.4262,  0.2914],
#          ...,
#          [-0.0905,  0.4583,  0.6609,  ...,  1.4480, -0.5063, -0.6002],
#          [-0.1357,  0.0519,  0.8745,  ...,  0.0548,  0.7275,  0.7660],
#          [-0.0494, -0.7020, -0.2810,  ..., -0.6697,  0.9779,  0.7416]],
#         grad_fn=<CatBackward0>),
#  316: tensor([[-1.2787, -0.5394,  0.6415,  ..., -0.2375, -0.9276, -0.9152],
#          [-0.2878, -0.5848,  0.7590,  ..., -1.6481, -0.7396, -0.5998],
#          [-1.0405,  0.2794, -0.8036,  ...,  0.4192,  0.3344,  0.4967],
#          ...,
#          [ 0.0124, -0.4025, -1.4923,  ...,  0.2476,  0.8867,  0.8828],
#          [ 0.8825,  0.2177, -1.2878,  ...,  0.4084,  0.8143,  0.8100],
#          [ 0.5582,  0.1139, -0.9366,  ...,  0.4097,  1.0186,  0.8287]],
#         grad_fn=<CatBackward0>),
#  29: tensor([[-4.4356,  3.0207, -4.5683,  ..., -1.2223,  2.4956,  2.4870],
#          [-0.6987, -0.5115,  1.0575,  ...,  0.8667, -0.9202, -0.9409],
#          [-1.9283, -0.3160,  0.6375,  ..., -0.1866, -0.7673, -0.7613],
#          ...,
#          [-1.1203, -0.6137,  0.4222,  ...,  0.2284,  0.0511, -0.0123],
#          [ 2.2577,  0.3229, -0.2680,  ...,  0.2174,  0.1753,  0.2903],
#          [ 0.6547, -1.4521,  1.2628,  ...,  0.2403, -0.3690, -0.5987]],
#         grad_fn=<CatBackward0>),
#  30: tensor([[-0.0287,  0.0673, -0.6003,  ..., -0.0754, -0.6656, -0.5410],
#          [-0.1104, -0.5037,  0.0588,  ...,  0.3749,  0.2703,  0.3443],
#          [-0.2033, -0.4425, -0.3616,  ...,  0.3965, -0.3511, -0.3992],
#          ...,
#          [-0.0927,  0.0495,  0.6003,  ..., -0.1445,  0.6932,  0.6393],
#          [-0.4183,  0.0945, -0.5890,  ..., -0.1388, -0.6019, -0.5952],
#          [-0.0647,  0.2171, -0.5427,  ..., -0.1190, -0.0145, -0.0473]],
#         grad_fn=<CatBackward0>),
#  43: tensor([[-0.2473,  0.2438,  0.3766,  ..., -0.0523, -0.4175, -0.5687],
#          [ 0.2474, -0.3938,  0.0865,  ...,  0.2945, -0.3891, -0.2411],
#          [ 0.7019,  0.4281,  0.1379,  ..., -0.4758, -0.4744, -0.5107],
#          ...,
#          [-0.2128,  0.3744,  0.1512,  ..., -0.1470, -0.3122, -0.3184],
#          [-0.3020,  0.2760,  0.2610,  ..., -0.2390, -0.0566, -0.1896],
#          [-0.0258,  0.4024,  0.0594,  ..., -0.1489, -0.3026, -0.2170]],
#         grad_fn=<CatBackward0>),
#  124: tensor([[-0.1184,  1.0116, -0.4847,  ...,  0.5376, -1.4030, -1.4432],
#          [-0.0783, -0.1771,  0.0684,  ...,  0.0154, -1.4958, -1.4683],
#          [ 0.1884,  0.0205,  0.0234,  ..., -0.0149,  1.1723,  1.1485],
#          ...,
#          [-2.0996,  0.9104,  0.2293,  ..., -0.7526,  1.2707,  0.0059],
#          [-0.7446, -0.9011, -0.0908,  ..., -0.0811, -1.1627, -0.6838],
#          [-1.5017,  0.3038, -0.5035,  ...,  0.3893, -0.2317, -0.2257]],
#         grad_fn=<CatBackward0>),
#  263: tensor([[-0.0263, -0.0821, -0.4986,  ...,  0.1468, -0.4321, -0.4437],
#          [-0.7014,  0.1677,  0.0422,  ..., -0.1867,  0.0419,  0.0612],
#          [-1.7755,  0.0115,  0.0993,  ..., -0.3133, -0.3737, -0.3208],
#          ...,
#          [-2.6527, -0.3477, -0.0419,  ...,  0.1342, -0.4647,  0.0500],
#          [ 0.8481,  0.1036,  0.3029,  ..., -0.1574, -0.2018, -0.0893],
#          [ 0.5228,  0.0721,  0.3383,  ..., -0.0734, -0.1742,  0.0327]],
#         grad_fn=<CatBackward0>),
#  259: tensor([[-0.0958,  0.1480,  0.1996,  ..., -0.2489, -0.1672, -0.1178],
#          [ 0.0482, -0.0346, -0.1138,  ...,  0.1243,  0.1451,  0.1320],
#          [-0.0111,  0.0179, -0.0705,  ...,  0.0777,  0.0249,  0.0154],
#          ...,
#          [ 0.3328, -0.0981, -0.0941,  ...,  0.0896, -0.0813, -0.0978],
#          [ 0.7979, -0.0644, -0.2301,  ...,  0.2443,  0.9159,  0.2943],
#          [-0.1557, -0.1615, -0.2151,  ...,  0.1995,  0.2775,  0.3276]],
#         grad_fn=<CatBackward0>),
#  349: tensor([[ 0.3362, -1.7067, -1.1364,  ...,  0.0800,  0.3650,  0.3694],
#          [ 1.0035, -0.3899, -0.2000,  ..., -0.5341,  0.4470,  0.2936],
#          [-0.7337, -0.6321,  0.1490,  ...,  1.5811, -1.3962, -1.3664],
#          ...,
#          [ 0.2660,  0.1893,  1.8632,  ..., -0.4012,  0.1459,  0.2210],
#          [ 0.2647, -0.1796, -0.4765,  ..., -1.0869, -0.7318, -0.8252],
#          [ 0.4169, -0.2551, -0.1512,  ...,  0.5090, -0.7694, -0.3277]],
#         grad_fn=<CatBackward0>),
#  255: tensor([[ 0.3669, -0.4597,  0.6628,  ..., -0.2465,  0.0700,  0.0361],
#          [-0.5392,  0.3190,  0.4639,  ...,  0.9902, -0.2846, -0.3496],
#          [-0.0681, -0.2737,  0.0366,  ..., -0.1641,  0.7231,  0.7588],
#          ...,
#          [ 0.7183,  0.3335,  0.6057,  ...,  0.5759,  0.3709,  0.2119],
#          [-0.5817,  0.7333, -0.3747,  ...,  0.0869,  1.2179,  0.4292],
#          [-0.1946,  0.1977, -0.1314,  ..., -0.1337,  0.1391,  0.0342]],
#         grad_fn=<CatBackward0>),
#  31: tensor([[ 0.2950, -0.2155,  0.4264,  ..., -0.8211, -0.8758, -0.9888],
#          [ 1.3856, -0.6027,  0.3207,  ...,  0.8935, -0.3176, -0.3717],
#          [-0.3116, -0.3183,  0.4224,  ..., -0.1754, -0.5945, -0.6489],
#          ...,
#          [-0.6553, -0.5216, -0.6102,  ...,  0.0995,  0.1046,  0.7112],
#          [-0.0335, -0.4522, -0.4805,  ...,  0.3746, -0.4811, -0.0327],
#          [-0.6922,  0.2692, -0.4147,  ...,  0.0545,  0.4184,  0.4565]],
#         grad_fn=<CatBackward0>),
#  36: tensor([[-1.7526,  0.2052, -0.0868,  ...,  0.0445, -1.8835, -1.9096],
#          [-0.0828,  0.1067,  0.3787,  ...,  0.6661, -0.3499, -0.3487],
#          [ 1.6443,  0.0723,  0.0193,  ...,  0.1117, -0.2699, -0.2856],
#          ...,
#          [-0.6094,  0.0631,  0.7790,  ..., -0.2283, -0.0932, -0.1060],
#          [-0.4857,  0.3360,  0.5319,  ...,  0.3590, -1.1763, -1.5699],
#          [-0.0932,  0.1526,  0.1667,  ...,  0.0668, -0.2045,  0.1096]],
#         grad_fn=<CatBackward0>),
#  24: tensor([[-0.0373, -1.2311,  1.1381,  ..., -1.6235,  0.4978,  0.4751],
#          [-3.0191,  0.8528, -1.1812,  ...,  5.2460,  0.5187,  0.5490],
#          [ 0.8222,  0.5330, -0.3213,  ..., -0.2144, -0.5009, -0.5956],
#          ...,
#          [ 0.3168,  0.2709, -0.5022,  ...,  0.4365, -0.0749,  0.7260],
#          [ 1.6470,  0.2341, -0.3376,  ...,  0.4383, -0.5268, -0.0563],
#          [ 2.7020, -0.3430,  0.4166,  ...,  0.3656, -1.5063, -1.1801]],
#         grad_fn=<CatBackward0>),
#  19: tensor([[-0.9228,  0.6434, -0.6197,  ..., -0.1932, -0.7393, -0.8469],
#          [ 0.1007,  0.7823, -0.1438,  ..., -0.6936,  0.1937,  0.2089],
#          [-1.2871,  2.1107, -0.6353,  ..., -0.3616, -0.8164, -0.6515],
#          ...,
#          [-0.4954, -0.7455, -0.1085,  ...,  0.2274, -0.0021, -0.3174],
#          [ 0.7297,  0.1673,  0.1873,  ...,  0.0847, -0.6568,  0.3334],
#          [ 0.5776, -0.0996, -0.0406,  ...,  0.3953, -0.1676,  0.4051]],
#         grad_fn=<CatBackward0>),
#  332: tensor([[-0.4097, -0.0869, -1.2515,  ...,  0.1269,  0.2432,  0.1313],
#          [-0.2510, -1.5094, -0.4841,  ..., -0.0223, -1.8432, -1.8819],
#          [-0.4257, -0.5745,  0.8443,  ..., -0.7721, -1.4258, -1.4356],
#          ...,
#          [-0.9608, -0.6947,  0.3749,  ...,  0.3915,  0.0231, -0.1964],
#          [-1.1198, -0.2580,  0.2417,  ...,  0.3389, -0.8270, -0.2875],
#          [ 0.7746,  0.6694,  0.3236,  ..., -0.0998,  1.2580,  2.6785]],
#         grad_fn=<CatBackward0>),
#  341: tensor([[-0.5649, -1.0001,  0.9199,  ..., -0.7134, -0.3598, -0.4032],
#          [-0.6108,  0.4804,  0.1957,  ..., -0.5056,  0.3470,  0.3736],
#          [-0.8323, -1.3398,  0.1971,  ...,  0.1677, -0.0484, -0.0271],
#          ...,
#          [-0.7815,  0.9837, -0.3817,  ..., -0.8992,  0.2566,  0.2490],
#          [-0.5081,  0.1000, -0.5429,  ..., -0.4810, -0.3204, -0.8513],
#          [ 0.6220, -0.3081,  0.8710,  ...,  0.5693,  0.1329,  0.2704]],
#         grad_fn=<CatBackward0>),
#  318: tensor([[ 1.2965,  2.4924,  0.2490,  ..., -1.0173, -0.9740, -0.9719],
#          [ 0.1626, -0.6931,  0.4758,  ..., -0.0527, -0.5657, -0.5792],
#          [-1.3494, -0.8145,  0.7459,  ..., -0.3651,  1.0118,  0.9642],
#          ...,
#          [-0.7037,  0.1140,  0.4986,  ...,  0.3199, -1.1737, -0.7276],
#          [-1.3409,  0.2909, -0.4374,  ...,  0.3375, -0.9716, -0.6307],
#          [-1.0018,  0.5098, -0.2020,  ..., -0.5495,  0.6669, -0.1166]],
#         grad_fn=<CatBackward0>),
#  319: tensor([[-0.8913, -0.6875, -1.0133,  ...,  0.2242, -1.5987, -1.6032],
#          [-1.4734, -1.5771,  1.2915,  ..., -0.4617,  0.5936,  0.5711],
#          [-0.9135, -3.7572, -2.9117,  ...,  0.4605, -2.1389, -2.1200],
#          ...,
#          [-1.2063,  1.1746,  0.6617,  ..., -0.0648, -2.1232,  0.4632],
#          [-1.1530,  0.4356,  0.6441,  ...,  0.2996, -0.1594,  0.1679],
#          [ 1.0016,  0.9834,  0.7625,  ..., -0.2502, -2.1720, -0.8839]],
#         grad_fn=<CatBackward0>),
#  57: tensor([[-0.3654,  0.4880, -0.4059,  ...,  0.1091, -2.0071, -2.0033],
#          [-0.6004, -0.3701, -0.0841,  ..., -0.2268, -0.8317, -0.8641],
#          [ 3.0042,  0.4019,  0.4933,  ...,  1.7762,  1.9216,  1.8935],
#          ...,
#          [ 0.0687, -1.0428, -0.7968,  ...,  0.3765, -1.1506, -0.5850],
#          [ 0.1033,  0.0248, -0.2477,  ..., -0.1459,  0.2584, -0.0506],
#          [ 0.8669, -0.0766, -0.0377,  ..., -0.3386,  0.0974, -0.0387]],
#         grad_fn=<CatBackward0>),
#  368: tensor([[-1.2751,  0.0246,  0.7373,  ..., -0.9007,  0.4305,  0.4020],
#          [-2.5747,  4.0040,  0.9306,  ...,  1.4474, -1.7015, -1.7046],
#          [ 0.2095, -0.4858, -0.0529,  ..., -0.1502,  0.9472,  0.8898],
#          ...,
#          [ 0.9942, -0.5491,  0.5268,  ...,  0.0089, -0.1109,  0.0830],
#          [-0.6839,  0.6294, -0.3366,  ...,  1.6449, -1.0722, -1.5131],
#          [-0.6380,  0.6707, -0.9444,  ...,  0.3165, -1.0518, -1.1142]],
#         grad_fn=<CatBackward0>),
#  34: tensor([[-0.0416,  0.2261, -0.3405,  ..., -0.3504, -0.5243, -0.4960],
#          [-0.5287, -0.3955,  0.5150,  ...,  0.4588, -0.4486, -0.3214],
#          [-0.4533, -0.6095,  0.3444,  ...,  0.5014, -0.4773, -0.4875],
#          ...,
#          [ 0.3995, -0.1218,  0.2286,  ..., -0.0669,  0.2048,  0.5356],
#          [-0.6618, -0.3496,  0.4213,  ...,  0.3253,  0.0741,  0.1262],
#          [ 1.1312,  0.2525, -0.2526,  ..., -0.2825,  0.1341, -0.1377]],
#         grad_fn=<CatBackward0>),
#  324: tensor([[ 0.1246, -0.1399,  0.6404,  ..., -0.3263,  0.2576,  0.3066],
#          [ 0.1821,  0.4701, -0.5057,  ..., -0.6193, -0.9768, -1.0055],
#          [-0.8127, -0.6460,  0.8190,  ...,  0.4155, -0.5760, -0.5353],
#          ...,
#          [ 0.9093, -0.3345,  0.3144,  ..., -0.3051,  0.1823,  0.1408],
#          [-0.1575, -0.2326,  0.0947,  ..., -0.2534,  0.3622,  0.4239],
#          [ 1.6153, -0.4504,  0.8796,  ..., -1.3029, -0.0239, -1.3487]],
#         grad_fn=<CatBackward0>),
#  25: tensor([[-0.8028,  0.1057,  1.9292,  ...,  0.1388,  2.2047,  2.1569],
#          [-0.0507,  0.7989, -2.0332,  ..., -2.0039, -2.1058, -2.1558],
#          [-0.4286,  0.8043,  0.0140,  ..., -0.4846,  0.6648,  0.6557],
#          ...,
#          [-1.0374, -0.3580,  0.6862,  ...,  0.1048,  0.7268,  0.5736],
#          [-0.8233,  0.3698,  0.0357,  ...,  0.7156,  0.4288,  0.0104],
#          [ 3.9434, -3.1748,  3.3307,  ..., -0.8441, -1.5855, -0.5684]],
#         grad_fn=<CatBackward0>),
#  101: tensor([[ 0.3089,  0.3707,  0.3217,  ...,  0.3268,  0.4660,  0.4412],
#          [-0.3479, -0.5817, -0.2157,  ..., -0.2618, -0.3618, -0.4201],
#          [-0.4821, -0.4655, -0.2945,  ..., -0.3709, -0.4843, -0.4566],
#          ...,
#          [ 0.3678, -0.1849, -0.2847,  ..., -0.2305,  0.2685,  0.2127],
#          [ 0.1928, -0.0547, -0.2858,  ..., -0.2782,  0.2667,  0.2817],
#          [ 0.3442, -0.2316, -0.2692,  ..., -0.1817,  0.2566,  0.2027]],
#         grad_fn=<CatBackward0>),
#  102: tensor([[-0.0823, -0.1473,  0.1772,  ...,  0.1668, -0.1099, -0.0878],
#          [ 0.0857,  0.1132, -0.2336,  ..., -0.0901,  0.3653,  0.3274],
#          [ 0.1461, -0.2552,  0.0136,  ...,  0.2383, -0.0978, -0.0957],
#          ...,
#          [ 0.0909,  0.2128, -0.2735,  ..., -0.2181,  0.0483,  0.0737],
#          [-0.3269,  0.0772, -0.2156,  ..., -0.1205, -0.0750,  0.0164],
#          [-0.1288,  0.1120, -0.2129,  ..., -0.1309, -0.0941, -0.0686]],
#         grad_fn=<CatBackward0>),
#  155: tensor([[-0.5894,  0.2593, -0.3222,  ...,  0.3161,  0.1955,  0.3027],
#          [-0.5340,  0.9639, -0.2665,  ...,  0.0370, -0.5491, -0.3477],
#          [-0.4463,  0.8942,  0.0345,  ..., -1.0208, -0.6866, -0.5978],
#          ...,
#          [ 0.3196,  0.5036, -0.3153,  ...,  0.4668, -0.2567, -0.5301],
#          [-0.0238,  0.2393, -0.7382,  ...,  0.5105, -0.3378,  0.1786],
#          [-0.1433,  0.6327, -1.0420,  ..., -0.2336,  0.5374,  0.4549]],
#         grad_fn=<CatBackward0>),
#  164: tensor([[ 0.7285,  0.0958, -0.3421,  ...,  0.6098, -0.2959, -0.3198],
#          [ 0.2829,  0.4966, -0.4417,  ...,  0.4277, -0.4377, -0.4747],
#          [-0.4545, -0.2661,  0.3976,  ..., -0.4856, -0.2453, -0.2457],
#          ...,
#          [ 0.4194,  0.2898, -0.0760,  ...,  0.2078, -0.1654, -0.1258],
#          [-0.2045,  0.3620, -0.2311,  ...,  0.3988,  0.0014, -0.0559],
#          [ 0.0703,  0.4797, -0.4952,  ...,  0.4315, -0.7116, -0.7229]],
#         grad_fn=<CatBackward0>),
#  267: tensor([[-0.1312,  0.3285,  0.3928,  ..., -0.4124, -0.2769, -0.2911],
#          [ 0.9750,  0.3111,  0.1142,  ..., -0.9941,  0.4136,  0.2230],
#          [-0.2184,  0.2173,  0.5183,  ..., -0.4823, -0.1595, -0.2254],
#          ...,
#          [-0.5364,  0.3534, -0.9018,  ..., -0.2567, -0.3632, -0.4281],
#          [-0.3284,  0.0343,  0.6699,  ..., -0.2824, -0.0626, -0.2753],
#          [ 0.8220,  0.3971,  1.3249,  ..., -0.4197,  0.0822,  0.4438]],
#         grad_fn=<CatBackward0>),
#  196: tensor([[ 0.7738, -0.2792, -0.1057,  ..., -0.1703,  0.2892,  0.3856],
#          [ 0.8988, -0.5630, -1.5208,  ..., -0.5165,  0.4361,  0.5358],
#          [ 0.2745, -0.3906, -0.6762,  ..., -0.2042, -0.4389, -0.4065],
#          ...,
#          [ 0.6288,  0.0614,  0.9507,  ...,  0.2463,  0.2632,  0.4793],
#          [-1.7699, -0.6656,  1.2483,  ...,  0.0256,  0.1466,  0.0568],
#          [-0.0268, -0.1454, -0.9726,  ...,  0.3354, -0.0817, -0.1514]],
#         grad_fn=<CatBackward0>),
#  140: tensor([[ 0.5797, -0.1826,  0.0032,  ...,  0.6445,  0.4800,  0.4643],
#          [ 0.2288, -0.2164, -0.0599,  ...,  0.0947, -0.1750, -0.0431],
#          [ 0.1696,  0.4239, -0.0068,  ..., -0.2941, -0.8317, -0.8449],
#          ...,
#          [ 0.2958,  0.4935,  0.1139,  ...,  0.0239, -0.4127, -0.3623],
#          [ 0.2929,  0.5516,  0.3244,  ..., -0.0578, -0.3601, -0.2858],
#          [-0.0584,  0.4374,  0.1814,  ...,  0.4094,  0.4905,  0.2331]],
#         grad_fn=<CatBackward0>),
#  369: tensor([[ 1.4223e-01, -4.4227e-01,  7.3274e-01,  ..., -3.6568e-01,
#           -1.3050e+00, -1.2877e+00],
#          [-4.1878e+00,  1.2738e-01,  2.3628e+00,  ..., -1.5570e+00,
#           -2.5163e-03,  9.6052e-02],
#          [-3.4374e+00, -3.7600e-01, -1.4602e+00,  ...,  3.4682e-01,
#           -1.0749e+00, -9.9105e-01],
#          ...,
#          [ 3.5271e-01,  3.2413e-01,  2.2591e-01,  ...,  5.2830e-01,
#           -1.1749e+00, -4.2440e-01],
#          [-1.6390e+00,  9.6774e-02,  4.3162e-01,  ...,  3.6230e-01,
#           -2.2865e+00, -2.2099e+00],
#          [-8.2230e-01, -9.5369e-02,  3.3086e+00,  ...,  3.8896e-02,
#           -1.6430e+00, -1.3469e+00]], grad_fn=<CatBackward0>),
#  166: tensor([[-0.0607, -0.1777, -0.5326,  ..., -0.3548,  0.2639,  0.2901],
#          [-0.4129,  0.2748, -0.2682,  ..., -0.3128,  0.8022,  0.8451],
#          [ 0.1596, -0.2441,  0.0231,  ..., -0.6726,  0.0726,  0.0409],
#          ...,
#          [ 1.0660,  0.0376, -0.3643,  ...,  0.6188,  1.7128,  0.8747],
#          [-0.1878,  0.0458,  0.0232,  ...,  0.1552,  0.2100,  0.1497],
#          [ 1.1402,  0.0595,  0.4380,  ...,  0.0405,  0.7393, -0.4312]],
#         grad_fn=<CatBackward0>),
#  139: tensor([[ 0.0511,  0.2703, -0.3637,  ..., -0.7171,  0.7781,  0.8678],
#          [-0.0388,  1.4193, -0.3437,  ...,  0.3813, -0.5384, -0.6523],
#          [ 0.1890,  0.2760,  0.0787,  ..., -0.2269,  0.0063,  0.1293],
#          ...,
#          [-0.3418,  0.2944,  0.0596,  ...,  0.3589, -0.4330, -0.6344],
#          [-0.2341, -1.0029, -0.4352,  ..., -0.8494, -0.3583, -0.1681],
#          [-0.0890,  1.0558, -0.0332,  ...,  1.3854, -0.9137, -0.7381]],
#         grad_fn=<CatBackward0>),
#  171: tensor([[ 7.7211e-02,  8.2377e-01,  4.2635e-01,  ..., -2.6128e-01,
#           -2.0737e-01, -1.9545e-01],
#          [-3.7398e-01,  3.1762e-01,  1.5322e-01,  ..., -1.6457e-01,
#           -4.3202e-01, -4.0609e-01],
#          [-2.5078e-01, -4.2653e-02, -8.4522e-02,  ...,  1.4077e-01,
#           -3.2112e-01, -3.4328e-01],
#          ...,
#          [ 2.2781e+00,  5.1167e-01, -1.6629e-01,  ...,  1.5157e-01,
#            3.3666e-01,  1.4193e+00],
#          [-7.0002e-01,  2.7384e-01,  1.1456e-01,  ...,  1.0575e-01,
#           -1.6659e-01,  1.5558e-02],
#          [ 5.0691e-02, -1.2917e-01, -1.0542e-01,  ...,  1.3064e-02,
#            1.2671e-03, -8.2971e-02]], grad_fn=<CatBackward0>),
#  66: tensor([[ 0.3349,  0.7181,  0.7241,  ..., -1.0860, -0.3826, -0.3933],
#          [ 0.2993,  0.6419,  0.2784,  ..., -0.7593, -0.2527, -0.1605],
#          [-0.7673, -0.7369, -0.9041,  ...,  0.1690, -0.7679, -0.7212],
#          ...,
#          [ 0.5979, -0.8477,  0.0898,  ...,  0.4310, -0.4281, -0.1257],
#          [ 0.4928,  0.7326,  0.0801,  ..., -0.8125, -0.6460, -0.1184],
#          [-0.6121,  0.1003,  0.1834,  ..., -0.8167, -0.4378, -0.3873]],
#         grad_fn=<CatBackward0>),
#  65: tensor([[-0.8019, -0.2891,  0.0041,  ..., -0.2187, -0.0224, -0.0167],
#          [ 0.9557, -0.2873, -0.1283,  ..., -0.0620, -0.1398, -0.1266],
#          [ 0.4344, -0.5134, -0.3056,  ...,  0.0499,  0.1835,  0.2251],
#          ...,
#          [-0.2975,  0.5564,  0.5631,  ..., -0.4585, -0.3715, -0.3593],
#          [-0.4619,  0.2370,  0.6283,  ..., -0.4960, -0.1736, -0.1652],
#          [ 0.2434, -0.6741, -0.6150,  ...,  0.6230,  0.7057,  0.7568]],
#         grad_fn=<CatBackward0>),
#  98: tensor([[ 0.0553, -0.4977, -0.4762,  ...,  0.3616, -0.5567, -0.6229],
#          [ 0.7069, -0.5519, -0.5954,  ...,  0.6221, -0.9536, -1.0068],
#          [ 0.1438,  0.3093,  0.6064,  ..., -0.5887, -0.0220, -0.0849],
#          ...,
#          [-0.2956,  0.4829,  0.3710,  ..., -0.5769,  0.3093,  0.3023],
#          [ 0.8774, -0.7162, -0.0556,  ...,  0.0344, -1.1398, -0.2565],
#          [-0.2238,  0.5460,  0.5330,  ..., -0.6281,  0.0285,  0.2654]],
#         grad_fn=<CatBackward0>),
#  314: tensor([[-0.0604,  0.5563, -0.9013,  ...,  0.8063, -0.5433, -0.5024],
#          [ 0.0289, -0.4712,  0.6041,  ..., -0.7842,  0.6219,  0.5341],
#          [ 0.6921,  0.5503, -0.3382,  ..., -0.2879, -0.6893, -0.8061],
#          ...,
#          [ 0.4562,  0.2367, -0.5407,  ...,  0.3438,  0.0647, -0.1205],
#          [ 0.5903,  0.0536, -0.1156,  ...,  0.3793, -0.0741, -0.1017],
#          [ 0.4152,  0.5104, -0.4230,  ...,  0.2467, -0.3384, -0.3673]],
#         grad_fn=<CatBackward0>),
#  68: tensor([[ 1.5694,  1.3020,  1.4168,  ..., -1.4668,  0.7603,  0.7732],
#          [ 0.8996, -1.2110, -0.6187,  ..., -0.6964, -1.0588, -1.1042],
#          [-6.8677,  1.3262, -0.7509,  ...,  0.5942, -0.2647, -0.2286],
#          ...,
#          [-1.9414,  0.7064,  0.2061,  ...,  0.2184, -1.2344,  0.4638],
#          [-0.0636, -1.3594,  0.1835,  ..., -0.8634, -3.1243, -1.8220],
#          [ 1.8331,  0.0092,  0.2955,  ..., -0.5896,  0.6274,  0.4639]],
#         grad_fn=<CatBackward0>),
#  61: tensor([[ 0.3294,  0.1037,  0.1324,  ..., -0.1541, -0.6916, -0.6619],
#          [-0.2659,  0.8789, -0.0759,  ..., -0.2602, -0.6160, -0.6506],
#          [-0.1248,  0.0585,  0.4350,  ..., -0.1110, -0.0465, -0.0800],
#          ...,
#          [-1.1299,  0.6541,  0.3910,  ...,  0.0632,  0.2727,  0.1698],
#          [ 0.3244, -0.1070, -0.2051,  ...,  0.1189, -0.1893, -0.0899],
#          [ 0.1299, -0.4981,  0.1954,  ..., -0.3355,  0.5088,  0.7180]],
#         grad_fn=<CatBackward0>),
#  32: tensor([[-0.2006, -0.2810,  0.0873,  ..., -0.1735, -0.2531, -0.4617],
#          [-0.1768,  0.2748, -0.3097,  ...,  0.2219,  0.1194,  0.0663],
#          [ 0.0809,  0.1181, -0.3447,  ...,  0.4115,  0.0559,  0.0798],
#          ...,
#          [-0.0881, -0.0953,  0.3321,  ..., -0.3711, -0.1446, -0.0196],
#          [-0.2551, -0.3905,  0.0106,  ..., -0.0589, -0.2005, -0.1480],
#          [-0.2960,  0.2840, -0.2180,  ...,  0.1627,  0.3498,  0.4067]],
#         grad_fn=<CatBackward0>),
#  128: tensor([[-1.6795,  0.3856, -1.4986,  ..., -0.6693, -2.3588, -2.3638],
#          [-0.4564, -1.9109, -1.7742,  ..., -0.9646, -0.5148, -0.5594],
#          [ 0.1017,  0.3196,  0.8392,  ...,  0.9136, -0.4756, -0.5126],
#          ...,
#          [-0.5070, -2.3877,  0.9986,  ...,  0.0652, -0.5114, -0.9492],
#          [ 0.1582, -0.4050, -0.4364,  ..., -0.2826,  0.3578,  0.1512],
#          [-0.1998,  1.9471,  0.2970,  ..., -0.5623, -1.5628,  0.2987]],
#         grad_fn=<CatBackward0>),
#  22: tensor([[ 0.1041, -0.5788,  0.4083,  ...,  0.2416,  0.0851,  0.0838],
#          [-0.0220, -0.2299,  0.3180,  ...,  0.1647,  0.1459,  0.1795],
#          [ 0.5548, -0.4321,  0.4911,  ...,  0.1800,  0.0126,  0.0237],
#          ...,
#          [-1.3629, -0.2790,  0.3992,  ...,  0.2615, -0.1032, -0.0934],
#          [ 0.7846, -0.2052,  0.3669,  ...,  0.3086, -0.0919, -0.2738],
#          [-0.1995,  0.3206, -0.3515,  ..., -0.2761,  0.0156,  0.2060]],
#         grad_fn=<CatBackward0>),
#  21: tensor([[-0.2532, -0.4081, -0.6685,  ...,  0.6592, -0.4734, -0.3468],
#          [-0.2124,  0.2113,  0.5115,  ..., -0.7015,  0.3350,  0.3427],
#          [-0.3313, -0.4901, -0.8368,  ...,  0.8235, -0.5384, -0.7066],
#          ...,
#          [ 0.4064,  0.4389,  0.6123,  ..., -0.5608,  0.5366,  0.6073],
#          [-0.3549, -0.5697, -0.5734,  ...,  0.5716, -0.6744, -0.7367],
#          [-0.4047, -0.5159, -0.5439,  ...,  0.6644, -0.7241, -0.7938]],
#         grad_fn=<CatBackward0>),
#  210: tensor([[-3.2857e-01, -9.6903e-01,  5.8262e-01,  ..., -4.9549e-02,
#           -3.4931e-01, -3.9059e-01],
#          [-5.1185e-02, -4.1834e-01,  1.6417e-01,  ..., -3.7395e-01,
#           -1.0218e-01, -1.0004e-01],
#          [-4.8858e-02, -2.0802e-01, -4.3878e-02,  ..., -1.9136e-01,
#           -4.2532e-02, -4.3815e-02],
#          ...,
#          [ 1.9081e-02,  6.9469e-02,  1.1118e-01,  ...,  1.5744e-02,
#           -3.8945e-02, -1.3080e-01],
#          [ 7.8204e-04, -2.1794e-01, -1.3032e-01,  ..., -1.3088e-01,
#            2.0728e-01,  2.2662e-01],
#          [-1.4691e-02, -1.1808e-01, -1.5179e-01,  ..., -1.5750e-01,
#            5.4301e-02,  1.3679e-01]], grad_fn=<CatBackward0>),
#  347: tensor([[-0.6994, -0.4981,  0.1813,  ...,  0.5565,  0.2672,  0.2597],
#          [-0.3861,  0.1584, -0.7727,  ...,  0.0787,  0.9875,  0.9703],
#          [-0.0388, -0.4203,  0.0655,  ...,  0.6429,  0.3104,  0.3966],
#          ...,
#          [-0.7870, -0.7270, -0.5182,  ...,  1.0718, -0.5843, -0.1744],
#          [-0.7515, -0.6002, -0.1765,  ...,  0.6055, -0.6811, -0.5884],
#          [ 0.3696,  0.4370, -0.9144,  ..., -0.6927,  0.6744,  0.6238]],
#         grad_fn=<CatBackward0>),
#  105: tensor([[-0.5009, -0.7012, -1.0109,  ..., -0.8047,  0.6436,  0.7125],
#          [ 0.2990,  0.7434,  0.5331,  ...,  0.6416, -0.2053, -0.2980],
#          [ 0.0181,  0.3359,  0.3001,  ...,  0.3448, -0.6670, -0.6182],
#          ...,
#          [-0.1575,  0.6913, -0.0343,  ...,  0.6919,  0.4075,  0.3652],
#          [ 0.0982, -0.5329, -0.6367,  ..., -0.5748,  0.7908,  0.7516],
#          [-0.4972,  0.6234,  0.4523,  ...,  0.6072, -0.4722, -0.6917]],
#         grad_fn=<CatBackward0>),
#  224: tensor([[ 0.8881,  0.7529,  0.1185,  ..., -1.4544,  0.8169,  0.8761],
#          [ 0.8634, -0.6025, -0.2929,  ..., -1.3742,  0.3968,  0.4821],
#          [-0.4508, -0.3270, -0.8088,  ..., -0.4674,  0.2283,  0.3056],
#          ...,
#          [-0.5215, -0.6657, -0.2552,  ...,  0.2049, -1.7103, -1.3389],
#          [ 0.9393,  0.6854, -0.2046,  ..., -0.3065, -0.4245,  0.3103],
#          [ 0.2622, -0.8218,  0.0141,  ...,  0.1880, -0.6222, -0.7480]],
#         grad_fn=<CatBackward0>),
#  334: tensor([[ 0.0828,  1.3366,  1.2072,  ..., -0.2511,  0.3272,  0.3667],
#          [-0.3444,  0.3201,  0.4200,  ...,  0.6341,  0.9305,  0.8917],
#          [-0.6380, -0.0573, -0.0482,  ...,  0.7313, -0.7675, -0.7662],
#          ...,
#          [ 2.3929,  0.1044,  0.6337,  ..., -0.2994, -0.5577,  0.1872],
#          [ 0.9534, -0.2559,  0.5382,  ...,  0.5431,  2.4884,  2.5435],
#          [ 3.6201,  1.5460, -0.4388,  ..., -0.2186,  1.8535,  1.7946]],
#         grad_fn=<CatBackward0>),
#  191: tensor([[-0.4247, -0.5367,  0.6460,  ...,  0.4963, -0.8307, -1.0098],
#          [-0.2044,  0.7670, -0.2320,  ..., -0.7065,  0.4130,  0.3936],
#          [-0.9116, -0.1937,  0.8224,  ...,  0.5718, -1.1331, -1.0698],
#          ...,
#          [-0.3948, -0.1965,  0.6491,  ...,  0.1949,  0.4235,  0.2577],
#          [-0.6502, -0.0125,  0.9372,  ...,  0.0535, -0.6985, -0.8288],
#          [ 0.5987,  0.2307, -0.6332,  ..., -0.4280, -0.0598,  0.1901]],
#         grad_fn=<CatBackward0>),
#  330: tensor([[-1.7082, -0.5697, -1.3388,  ..., -0.7279,  0.0893,  0.0851],
#          [-1.2053, -1.2960,  0.3001,  ..., -0.4722, -1.5297, -1.5609],
#          [ 1.2874, -0.8501, -2.8188,  ...,  0.6568,  1.2119,  1.2210],
#          ...,
#          [-1.2785, -0.0462, -0.1813,  ...,  0.8387, -1.3285, -1.5828],
#          [ 1.7336, -0.0460, -0.1884,  ...,  0.1955, -0.4808,  0.7003],
#          [-0.8001,  0.6881,  0.9164,  ..., -1.1425, -0.6451,  0.7794]],
#         grad_fn=<CatBackward0>),
#  62: tensor([[-0.2970,  0.7239,  0.3187,  ...,  0.2686,  0.0240,  0.0415],
#          [ 0.0231, -0.4639,  0.3191,  ...,  0.4048,  0.2001,  0.1984],
#          [ 0.7279, -0.0719,  0.4058,  ...,  0.0614,  0.0852,  0.1528],
#          ...,
#          [-1.6278, -0.1405,  0.3550,  ...,  0.2500,  0.1080, -0.0583],
#          [ 0.0753,  0.7687,  0.1410,  ..., -1.1928,  0.6321,  0.6600],
#          [-1.0907,  0.2494, -0.2326,  ...,  0.0200,  0.7846,  0.2284]],
#         grad_fn=<CatBackward0>),
#  248: tensor([[-2.1402, -0.7479,  0.0068,  ..., -0.2737, -0.1991, -0.1744],
#          [ 0.0659,  0.0392, -0.0655,  ..., -0.0664,  0.1287,  0.1361],
#          [-1.8720,  0.1504,  0.0747,  ..., -0.1497, -0.3346, -0.3056],
#          ...,
#          [ 3.5297, -0.0278, -0.0378,  ..., -0.4067,  0.5741, -0.3205],
#          [-0.0099, -1.1903,  0.2125,  ..., -0.2008, -0.8869, -1.3085],
#          [-0.1527, -0.0085,  0.1298,  ..., -0.0825, -0.1114, -0.0400]],
#         grad_fn=<CatBackward0>),
#  247: tensor([[ 0.4295,  0.6290, -0.0292,  ...,  0.5517, -0.4633, -0.5010],
#          [ 0.8270,  0.4986,  0.0030,  ...,  0.9565, -0.2110, -0.2761],
#          [ 0.3341, -0.4697, -0.4287,  ..., -0.6863,  0.0781,  0.0263],
#          ...,
#          [ 0.4377, -0.0676, -0.0914,  ...,  0.6476,  0.1965, -0.0172],
#          [ 0.3059,  0.1163, -0.0613,  ...,  0.7045,  0.1187, -0.0842],
#          [-0.3943, -0.6480, -0.7951,  ...,  0.0127, -0.4914, -0.6655]],
#         grad_fn=<CatBackward0>),
#  28: tensor([[-0.9037, -0.8340,  0.2872,  ..., -1.1323, -1.3799, -1.3874],
#          [ 0.0987,  0.1596,  0.2266,  ..., -0.0703,  0.0089, -0.0017],
#          [-0.2716, -0.1030, -0.0685,  ..., -0.1269, -0.6153, -0.6367],
#          ...,
#          [ 1.3232, -0.0534, -0.4607,  ...,  1.1530, -0.0279,  0.1099],
#          [-1.5548,  0.0643,  0.6312,  ..., -0.6602, -0.2753, -0.3532],
#          [ 0.5947,  0.8435,  0.2664,  ...,  0.5714,  0.8453,  0.9278]],
#         grad_fn=<CatBackward0>),
#  92: tensor([[ 0.4162, -1.5201,  0.8732,  ...,  1.4386, -0.5979, -0.6903],
#          [-2.1521, -0.2305,  1.6776,  ...,  2.1494, -1.2828, -1.4454],
#          [-0.4947,  0.3754,  0.0893,  ..., -0.4040, -0.6786, -0.6000],
#          ...,
#          [-1.3006,  0.1045, -0.4637,  ..., -0.7537, -0.1056, -0.0918],
#          [-0.7001, -0.9626,  0.9242,  ..., -0.7944, -0.8024, -0.2927],
#          [-1.7748,  0.4775, -0.5699,  ..., -0.4709,  0.0853, -0.4135]],
#         grad_fn=<CatBackward0>),
#  288: tensor([[ 0.2120, -0.4093, -0.2777,  ..., -0.1639, -0.3860, -0.4981],
#          [-0.3384, -0.9964, -0.7921,  ..., -0.3359,  0.4674,  0.3974],
#          [-0.4270,  0.3448,  1.0051,  ...,  1.0386, -0.2967, -0.4420],
#          ...,
#          [-0.3529, -0.1360, -0.3175,  ..., -0.2248,  0.6864,  0.7411],
#          [-0.6443, -0.1738,  0.1301,  ...,  0.0444,  0.4683,  0.0899],
#          [ 0.1793,  0.6298,  0.9107,  ...,  0.3247, -0.3854, -0.1858]],
#         grad_fn=<CatBackward0>),
#  209: tensor([[ 0.2301,  0.4219, -0.4703,  ..., -0.6102, -0.1279, -0.2459],
#          [-0.1380,  0.5963, -0.6490,  ..., -0.5131, -0.5082, -0.4498],
#          [-0.5359,  0.3489, -0.4613,  ..., -0.6988, -0.2249, -0.2248],
#          ...,
#          [ 0.2271, -0.2760,  0.3272,  ...,  0.4401, -0.1456, -0.0533],
#          [-0.6067, -0.2094,  0.1921,  ...,  0.3534, -0.1140, -0.0038],
#          [-0.2116, -0.7105,  0.6620,  ...,  0.4319,  0.4405,  0.4785]],
#         grad_fn=<CatBackward0>),
#  301: tensor([[ 0.0113, -0.1929,  0.2470,  ..., -0.1900,  0.2669,  0.2399],
#          [-0.0932,  0.3761, -0.2421,  ...,  0.3535, -0.3417, -0.3288],
#          [-0.1728, -0.2469,  0.0524,  ..., -0.1256,  0.0272,  0.0487],
#          ...,
#          [-0.1572, -0.1154,  0.1749,  ..., -0.0645, -0.1759, -0.1966],
#          [-0.2774, -0.0551,  0.1663,  ..., -0.0192, -0.1106, -0.0263],
#          [-0.5986,  0.2857, -0.2979,  ...,  0.2997, -0.1260, -0.1608]],
#         grad_fn=<CatBackward0>),
#  350: tensor([[-0.3041, -0.2675, -0.8418,  ...,  0.5040, -0.9695, -0.9139],
#          [ 0.8230,  0.6363,  0.4465,  ..., -0.1568, -0.0692,  0.0313],
#          [-0.3003, -0.3969, -0.6496,  ...,  0.7499, -0.8035, -0.9060],
#          ...,
#          [ 0.4390, -0.0605,  0.3527,  ..., -0.6302,  0.8552,  0.7327],
#          [-0.7404, -0.2870, -0.4192,  ...,  0.5276,  0.1470, -0.0941],
#          [ 0.1412,  0.1951,  0.3128,  ...,  0.6125, -0.7180, -0.2391]],
#         grad_fn=<CatBackward0>),
#  298: tensor([[ 5.2849e-01,  4.0560e-01,  9.7359e-02,  ..., -2.3392e-02,
#            3.9383e-01,  3.8318e-01],
#          [-2.8950e-04,  2.6753e-01, -2.6191e-01,  ..., -5.8168e-02,
#            8.5580e-02,  1.1476e-01],
#          [ 3.2482e-01, -8.8466e-02, -1.7340e-01,  ...,  4.2415e-01,
#            1.6854e-01,  1.2291e-01],
#          ...,
#          [ 1.7307e-01, -2.1994e-01,  2.9762e-01,  ...,  1.2830e-01,
#           -3.3866e-01, -1.5849e-01],
#          [-8.6676e-01,  2.2638e-01, -1.3533e-01,  ..., -2.9672e-01,
#           -8.4433e-02, -3.1378e-01],
#          [-4.3417e-01, -1.1420e-01,  2.3124e-01,  ..., -1.4089e-02,
#           -1.4562e-01, -8.0078e-02]], grad_fn=<CatBackward0>),
#  17: tensor([[-6.2172e-02,  4.1639e-01, -3.2549e-04,  ..., -3.1023e-01,
#           -1.0641e-01, -1.3316e-01],
#          [ 1.0309e-01,  1.1520e-01,  1.6349e-01,  ..., -3.9659e-02,
#            4.9965e-02,  1.2680e-01],
#          [ 1.4599e-02, -5.2574e-01,  4.5824e-01,  ...,  2.2778e-01,
#           -2.5166e-01, -2.7949e-01],
#          ...,
#          [-6.6997e-02,  4.9259e-01, -5.1458e-01,  ..., -3.5886e-01,
#           -5.0906e-01, -4.0302e-01],
#          [ 6.4298e-02, -3.2321e-01,  3.6415e-01,  ...,  4.0835e-01,
#            6.1719e-01,  5.6305e-01],
#          [ 3.3497e-01,  4.7468e-01, -4.2892e-01,  ..., -4.4053e-01,
#           -2.7636e-01, -3.3616e-01]], grad_fn=<CatBackward0>),
#  16: tensor([[ 0.3736,  0.9776, -0.5731,  ...,  0.2748, -0.5957, -0.6183],
#          [ 0.4476,  1.0027, -0.9761,  ...,  0.1779, -0.5015, -0.4989],
#          [ 0.1915,  0.2552, -0.4887,  ..., -0.9835, -0.7944, -0.6699],
#          ...,
#          [ 0.4829,  0.8638, -0.8231,  ..., -0.0143, -0.6304, -0.4433],
#          [ 0.1526,  0.2896,  0.2510,  ...,  0.7076,  0.5403,  0.8324],
#          [-0.2068,  0.2800,  0.0868,  ...,  0.4982,  0.7903,  0.9516]],
#         grad_fn=<CatBackward0>),
#  38: tensor([[ 0.7187,  1.9316,  0.7586,  ...,  1.4459,  2.2645,  2.3487],
#          [-1.8771, -0.7365,  0.2103,  ..., -1.5012,  0.0889,  0.0542],
#          [-1.0358, -1.5760, -2.4932,  ..., -1.3114, -3.0474, -3.0023],
#          ...,
#          [ 3.0041, -1.8479, -1.6302,  ..., -2.0315,  0.1294, -1.1751],
#          [ 1.9020,  1.1191,  1.3276,  ...,  0.8867, -1.8814, -0.2506],
#          [ 2.2491,  1.1863,  2.1132,  ...,  0.0460, -0.3053,  0.5316]],
#         grad_fn=<CatBackward0>),
#  3: tensor([[-0.4528, -0.4757,  0.2001,  ..., -0.9619, -0.5505, -0.6778],
#          [-0.6193, -0.5350,  0.2627,  ..., -0.6545, -0.8122, -0.7729],
#          [-0.5601, -0.6006,  0.5395,  ..., -0.4639, -0.8386, -0.7345],
#          ...,
#          [ 0.3848, -0.2926,  0.2229,  ..., -0.0447, -0.1248, -0.3623],
#          [-0.4723,  0.2880, -0.2464,  ...,  0.0071,  0.2311,  0.2037],
#          [ 0.7572,  0.4826, -0.2607,  ...,  0.4235,  0.2939,  0.3211]],
#         grad_fn=<CatBackward0>),
#  286: tensor([[-2.3914, -0.0155,  0.0099,  ..., -0.0356, -1.2068, -1.2272],
#          [-0.1299, -0.4022, -0.0065,  ...,  0.4125, -0.5185, -0.4788],
#          [-0.3053,  0.4135, -0.2135,  ...,  0.2227,  0.2030,  0.1584],
#          ...,
#          [ 1.8665, -0.7111,  0.4193,  ...,  0.3929, -0.8294,  0.0659],
#          [ 0.5980,  0.2342, -0.3059,  ...,  0.3028, -0.7749, -0.3200],
#          [ 0.0799, -0.1278,  0.6700,  ..., -0.4601, -0.0502, -0.0628]],
#         grad_fn=<CatBackward0>),
#  78: tensor([[-0.1656,  0.0949, -0.1739,  ...,  0.1855, -0.1092, -0.0737],
#          [ 0.2719, -0.1714, -0.0093,  ...,  0.1603,  0.2321,  0.2352],
#          [ 0.1593, -0.0647,  0.1194,  ...,  0.0256,  0.1526,  0.1890],
#          ...,
#          [-0.0249,  0.1849,  0.1899,  ..., -0.1426, -0.1310, -0.1583],
#          [-1.0101,  0.1642,  0.1565,  ..., -0.0442, -0.0542,  0.0014],
#          [-1.2430,  0.2669,  0.1691,  ..., -0.1265,  0.1685, -0.0709]],
#         grad_fn=<CatBackward0>),
#  77: tensor([[ 0.6763,  0.2922,  0.0925,  ..., -0.5151,  0.0342,  0.0875],
#          [ 0.0149,  0.3795, -0.2152,  ..., -0.1892,  0.0699, -0.0780],
#          [-0.2481,  0.2361,  0.0447,  ..., -0.4382, -0.2889, -0.1633],
#          ...,
#          [ 0.2708,  0.5964, -0.0654,  ..., -0.8321,  0.5100,  0.5619],
#          [ 0.3083,  0.5917, -0.1392,  ..., -0.6996,  0.5358,  0.2832],
#          [ 0.3210,  0.5183, -0.0356,  ..., -0.6568,  0.6966,  0.4184]],
#         grad_fn=<CatBackward0>),
#  75: tensor([[-0.5840, -0.2061,  0.0291,  ..., -0.0697, -0.3039, -0.2267],
#          [-0.2000, -0.3580,  0.4117,  ...,  0.2349, -0.0764, -0.0649],
#          [-0.3264,  0.0230, -0.2177,  ..., -0.0859, -0.3277, -0.2869],
#          ...,
#          [-0.3746, -0.1730,  0.2136,  ...,  0.3140, -0.2983, -0.2069],
#          [ 0.0961, -0.0852, -0.0397,  ...,  0.2340,  0.0555, -0.2215],
#          [ 0.4539,  0.1369, -0.0048,  ..., -0.3014,  0.1407,  0.2454]],
#         grad_fn=<CatBackward0>),
#  4: tensor([[-1.0646,  0.4334,  0.2553,  ..., -0.5544, -0.1803, -0.0465],
#          [-0.7210,  0.2326,  0.1602,  ..., -0.5236, -0.0386, -0.1147],
#          [-0.5059,  0.4587,  0.4989,  ...,  0.3530,  1.2664,  1.1365],
#          ...,
#          [-1.3494,  0.3297,  0.4289,  ..., -0.2289, -0.1007,  0.6782],
#          [-0.2290, -0.3487, -0.4440,  ..., -0.0805, -0.2970, -0.4219],
#          [ 0.5913,  0.3559,  0.4212,  ..., -0.1000,  0.4648,  0.3799]],
#         grad_fn=<CatBackward0>),
#  76: tensor([[-0.1644,  0.3332,  0.3004,  ...,  0.6022, -0.0759, -0.1991],
#          [ 0.0173,  0.4823,  0.4336,  ...,  0.5480, -0.0303, -0.1198],
#          [-0.2315,  0.2751,  0.5299,  ...,  0.6668, -0.2454, -0.3505],
#          ...,
#          [-0.3262, -0.0101, -0.0437,  ..., -0.1166, -0.4646, -0.4871],
#          [ 0.3210,  0.0137, -0.1193,  ...,  0.1227,  0.4830,  0.5303],
#          [-0.3971,  0.5320,  0.6566,  ...,  0.4055, -0.3136, -0.5786]],
#         grad_fn=<CatBackward0>),
#  161: tensor([[-0.0655,  0.3644, -0.1228,  ..., -0.2832,  0.1506,  0.1814],
#          [ 0.2101,  0.0776,  0.3093,  ..., -0.1220, -0.0054, -0.0713],
#          [-0.2198,  0.2516, -0.2093,  ...,  0.1770, -0.1362,  0.0464],
#          ...,
#          [ 0.1482,  0.3913,  0.2133,  ..., -0.0491, -0.3840, -0.3482],
#          [ 0.1975, -0.0518, -0.2165,  ..., -0.2121, -0.1824,  0.1114],
#          [-0.0552, -0.0975, -0.2362,  ...,  0.2189,  0.3992,  0.4180]],
#         grad_fn=<CatBackward0>),
#  40: tensor([[ 0.2639, -0.5902, -1.3805,  ..., -1.6089, -1.9319, -1.9716],
#          [-1.1791,  1.1463,  0.3603,  ..., -0.2240,  0.8899,  0.9824],
#          [-2.2809,  0.4054, -0.1838,  ...,  1.4089,  0.1890,  0.3663],
#          ...,
#          [ 0.5966, -0.5286,  0.0686,  ..., -0.3466, -0.9568, -0.4933],
#          [-1.0799,  0.0622,  0.2527,  ...,  0.5186,  0.8335,  1.7648],
#          [-1.8191,  0.1016, -1.2403,  ..., -0.8017, -0.5093, -0.1128]],
#         grad_fn=<CatBackward0>),
#  294: tensor([[ 1.1893,  2.6010, -0.1215,  ...,  2.8446, -1.8092, -1.8411],
#          [-0.9980,  1.2434,  0.4243,  ...,  0.7837, -0.9358, -0.9061],
#          [ 0.9198,  0.1281, -0.4180,  ..., -1.0626,  1.0962,  1.1558],
#          ...,
#          [ 0.8900,  0.2072,  0.2949,  ..., -0.0044,  1.4668,  0.4954],
#          [ 0.6998,  1.0184, -1.4875,  ...,  1.3434, -0.8115, -3.0422],
#          [-0.9833, -0.0657, -0.4473,  ...,  0.0623, -0.7110,  0.4385]],
#         grad_fn=<CatBackward0>),
#  23: tensor([[ 0.0733,  0.3489, -0.4888,  ..., -0.5809,  0.0054,  0.0053],
#          [-0.4177, -0.0968, -0.3631,  ..., -0.4524, -0.1244, -0.2234],
#          [ 0.4675,  0.2939,  0.1340,  ...,  0.3038,  0.3472,  0.3162],
#          ...,
#          [ 0.3380,  0.4900,  0.2132,  ...,  0.3616,  0.0737,  0.1014],
#          [-0.3392, -0.0710, -0.3832,  ..., -0.2236,  0.0814, -0.1887],
#          [-0.0340, -0.7659, -0.1123,  ..., -0.1874,  0.0888, -0.1593]],
#         grad_fn=<CatBackward0>),
#  7: tensor([[-0.0887,  0.3600, -0.7580,  ..., -0.2206, -0.6507, -0.7399],
#          [-0.0535, -0.5003,  0.4554,  ...,  0.6743, -0.1317, -0.1396],
#          [-0.2379,  0.4287, -0.3036,  ..., -0.4269, -0.3202, -0.3197],
#          ...,
#          [ 0.5628,  0.3201, -0.2300,  ..., -0.3899,  0.0643, -0.5932],
#          [-0.5845, -0.3879,  0.3676,  ...,  0.5006,  0.1918,  0.1294],
#          [ 0.4925,  0.2607, -0.3730,  ..., -0.2969, -0.2399, -0.1427]],
#         grad_fn=<CatBackward0>),
#  11: tensor([[-0.5179,  1.0261,  1.0506,  ..., -0.0414, -1.1000, -1.0482],
#          [-0.9640, -0.1155, -1.6100,  ...,  0.4232,  0.8602,  0.8843],
#          [ 1.1570, -2.0424,  1.6610,  ...,  1.6464, -2.2053, -2.1615],
#          ...,
#          [ 1.4413, -2.4717, -1.6047,  ...,  0.4912, -3.6345, -0.4807],
#          [-0.2417,  1.3984, -0.9395,  ..., -0.6827,  2.2700,  2.8304],
#          [-0.1998,  1.4459,  1.9219,  ...,  0.5540, -1.0375, -1.5599]],
#         grad_fn=<CatBackward0>),
#  18: tensor([[-0.2500,  0.2740,  0.1631,  ...,  0.0082, -0.2571, -0.2492],
#          [-0.3334,  0.2456, -0.3987,  ...,  0.4547, -0.6878, -0.5021],
#          [-0.3218,  0.2106, -0.1852,  ...,  0.2389, -0.3969, -0.4180],
#          ...,
#          [-0.1097, -0.4411,  0.3932,  ..., -0.0446, -0.0929, -0.0503],
#          [-0.4148,  0.1765, -0.3419,  ...,  0.3626,  0.0424,  0.0302],
#          [-0.2675,  0.1480, -0.0701,  ...,  0.0424, -0.2422, -0.3327]],
#         grad_fn=<CatBackward0>),
#  6: tensor([[-0.1576,  0.3683, -0.6800,  ...,  0.0726,  1.0456,  0.9622],
#          [-0.3501, -0.4214,  0.4267,  ...,  0.2669, -0.3215, -0.4295],
#          [-0.6275, -0.3287, -0.4602,  ...,  0.3467, -0.5761, -0.5084],
#          ...,
#          [-0.4538,  0.9603,  0.2521,  ..., -0.4834,  0.2116,  0.9046],
#          [-0.2247, -0.3332,  0.5792,  ...,  0.4816, -0.9365, -1.4293],
# ...
#          ...,
#          [ 0.5838,  0.2010, -0.2553,  ..., -0.0779, -0.2532, -0.2261],
#          [ 0.1285,  0.1030, -0.5590,  ...,  0.3140,  0.1145,  0.0378],
#          [-0.2400, -0.5144, -0.2975,  ...,  0.0247, -0.1707, -0.2058]],
#         grad_fn=<CatBackward0>),
#  197: tensor([[-0.1521, -0.3513,  0.8003,  ...,  0.7287, -0.6113, -0.5344],
#          [ 0.6087,  0.4453, -0.6501,  ...,  0.0426, -0.3277, -0.3292],
#          [-0.0665, -0.3580,  0.5936,  ...,  0.6916, -0.5961, -0.5364],
#          ...,
#          [ 0.3937,  0.2025, -0.4190,  ..., -0.5805,  0.6242,  0.5695],
#          [ 0.4656,  0.2185, -0.3287,  ..., -0.5150,  0.6026,  0.7109],
#          [-0.2369, -0.4280,  0.6843,  ...,  0.7585, -0.6277, -0.7245]],
#         grad_fn=<CatBackward0>),
#  67: tensor([[ 0.0101,  0.1202, -0.1681,  ...,  0.0708,  0.2961,  0.2621],
#          [-0.1800, -0.2149, -0.2003,  ..., -0.3810,  0.5327,  0.5620],
#          [-0.5359,  0.3353, -0.3982,  ..., -0.4815,  0.4365,  0.4914],
#          ...,
#          [ 0.3165, -0.4481, -0.3050,  ..., -0.1074, -0.0391, -0.1678],
#          [-0.4254, -0.4204, -0.0682,  ..., -0.1598, -0.4330, -0.3912],
#          [-0.1788, -0.1733, -0.3369,  ...,  0.1453, -0.0916, -0.0625]],
#         grad_fn=<CatBackward0>),
#  313: tensor([[ 2.2080, -1.2470,  1.6138,  ..., -0.3430, -0.5114, -0.5377],
#          [-0.2070,  0.1774,  0.1398,  ...,  0.1547,  1.5459,  1.6128],
#          [-0.2060, -0.1015, -1.7763,  ..., -0.5583,  0.3356,  0.4176],
#          ...,
#          [-1.1761, -0.5275,  0.8174,  ...,  0.6966, -1.2095, -0.7870],
#          [-1.2698,  0.6043,  0.5543,  ...,  0.5306, -0.0579, -0.3406],
#          [ 2.5516, -0.3380,  1.4064,  ...,  0.3487,  0.4986,  0.8221]],
#         grad_fn=<CatBackward0>),
#  99: tensor([[-0.1672,  0.3457, -0.5937,  ...,  0.7686,  0.0973, -0.0421],
#          [-1.0952, -0.6404,  0.5740,  ...,  1.1084, -0.4509, -0.4690],
#          [ 0.7908, -0.1556, -0.4728,  ...,  0.1207,  0.1001,  0.3038],
#          ...,
#          [ 0.9431,  1.0385, -0.4233,  ..., -0.1067,  0.2660,  0.7791],
#          [ 1.1229,  0.8604, -0.5156,  ..., -0.1157,  0.6870,  0.9897],
#          [-0.1111, -0.8788,  0.8290,  ...,  0.4146, -0.3630, -0.5200]],
#         grad_fn=<CatBackward0>),
#  82: tensor([[-0.1940, -0.3240,  0.4359,  ..., -0.7434, -0.0572,  0.0350],
#          [-0.4600,  1.2543, -0.2071,  ...,  0.9350, -1.3694, -1.3954],
#          [ 0.1499, -0.2402,  0.5081,  ..., -0.6070, -0.1194,  0.0173],
#          ...,
#          [-0.1406, -0.0542,  0.1873,  ...,  0.2871,  0.4419,  0.4114],
#          [-0.0950,  0.0914, -0.1702,  ...,  0.5355,  0.5017,  0.6184],
#          [ 0.1364, -0.1991,  0.1846,  ..., -0.9685, -0.3805, -0.5015]],
#         grad_fn=<CatBackward0>),
#  83: tensor([[-0.2709,  0.2968,  0.2955,  ..., -0.4452, -0.1457, -0.2098],
#          [-1.0257,  0.1973,  1.1833,  ..., -0.4748, -0.1258, -0.1228],
#          [-1.1334,  0.1939,  0.4483,  ...,  0.8429,  0.6690,  0.6658],
#          ...,
#          [-0.6356, -0.2799,  0.5921,  ...,  0.1619, -0.2150,  0.1400],
#          [-0.3365, -0.2124,  0.2261,  ...,  0.1026, -0.2083, -0.2097],
#          [-0.2657, -0.3923,  0.0324,  ..., -0.1434, -0.3738,  0.2378]],
#         grad_fn=<CatBackward0>),
#  266: tensor([[-0.3647, -0.2846,  0.2836,  ..., -0.3302, -0.3613, -0.2890],
#          [-0.3389, -0.3144,  0.2080,  ..., -0.2535, -0.3183, -0.3892],
#          [ 0.2214,  0.0026,  0.0503,  ...,  0.2267,  0.2865,  0.2588],
#          ...,
#          [-0.1715,  0.0933, -0.0710,  ...,  0.2364, -0.0264,  0.0604],
#          [-0.3127, -0.0148, -0.0138,  ...,  0.2117,  0.0829,  0.4237],
#          [ 0.3541,  0.2170, -0.0449,  ...,  0.3244,  0.1294,  0.1211]],
#         grad_fn=<CatBackward0>),
#  215: tensor([[ 0.9860, -0.0206,  1.0146,  ..., -1.1285,  0.2431,  0.1403],
#          [ 0.0984,  0.1099,  0.1780,  ..., -0.4563, -0.4344, -0.3265],
#          [ 0.9598, -0.8534, -0.5731,  ...,  0.5523,  0.5905,  0.5252],
#          ...,
#          [-0.1618,  0.5181,  1.0911,  ..., -0.3429,  0.0991,  0.1744],
#          [-0.6788, -0.6021,  0.5844,  ..., -0.0067, -0.2183, -0.2391],
#          [ 0.1728, -0.1610, -0.5458,  ..., -0.2838,  0.6507,  0.4878]],
#         grad_fn=<CatBackward0>),
#  52: tensor([[ 1.8608e-01, -3.7958e-01, -3.9572e-01,  ..., -4.1872e-01,
#           -5.0147e-02, -1.2379e-01],
#          [-2.3713e-01,  4.1015e-01, -1.6378e-01,  ..., -2.3272e-01,
#           -3.4824e-01, -1.9883e-01],
#          [ 3.8897e-01,  5.5447e-01,  1.8773e-02,  ...,  8.6314e-03,
#           -1.7260e-01, -1.0234e-01],
#          ...,
#          [-2.4782e-01, -2.9015e-02, -3.9303e-04,  ...,  2.3988e-01,
#           -1.3783e-02,  7.6233e-02],
#          [ 3.7849e-01, -6.8465e-02, -2.5303e-02,  ...,  3.1729e-01,
#           -3.7346e-01, -3.2118e-02],
#          [ 1.4873e-01, -2.0328e-01,  4.6043e-01,  ..., -3.0830e-01,
#           -1.3269e-01,  9.7683e-02]], grad_fn=<CatBackward0>),
#  135: tensor([[ 1.8736, -1.9574, -1.6623,  ...,  1.1261,  1.1575,  1.1381],
#          [-0.7035,  0.3397,  0.7942,  ...,  0.4830, -0.6284, -0.6562],
#          [-0.5201,  1.5369, -0.1803,  ..., -0.1503, -1.1366, -1.1722],
#          ...,
#          [ 0.8366,  0.8054, -0.8473,  ...,  1.3735,  0.0713, -0.6033],
#          [ 0.7890,  0.3027, -0.1149,  ..., -0.2608, -0.6499,  0.0786],
#          [ 1.4497, -0.1329, -0.0822,  ..., -0.3632, -0.3046,  0.0813]],
#         grad_fn=<CatBackward0>),
#  304: tensor([[ 0.0999, -0.5738,  0.1484,  ..., -0.8909, -0.0485, -0.1883],
#          [-0.1832, -0.3967,  0.1736,  ..., -0.2425, -0.4615, -0.5479],
#          [-0.7777, -0.5650, -0.0429,  ..., -0.3103, -0.5461, -0.6235],
#          ...,
#          [ 1.1386, -0.5271,  1.0190,  ..., -0.5709, -0.0450,  0.0803],
#          [ 0.1783,  0.3655, -0.3880,  ...,  0.7525, -0.7263,  0.0045],
#          [-0.4101, -0.0834, -1.0941,  ...,  0.2235, -0.0842, -0.0902]],
#         grad_fn=<CatBackward0>),
#  176: tensor([[ 0.3040, -0.3207,  0.2933,  ..., -0.3341, -0.9827, -1.0488],
#          [-1.1379,  0.5925,  0.3415,  ...,  0.1305, -0.5641, -0.5594],
#          [-2.2732,  0.3780,  0.4596,  ..., -0.2810,  0.2505,  0.2239],
#          ...,
#          [-0.9732,  0.1519,  0.8152,  ..., -0.3041, -0.2543, -0.6632],
#          [ 1.0506, -0.3108, -0.4398,  ..., -0.4647,  0.9726,  0.1457],
#          [-0.8090,  0.0429,  0.0598,  ..., -0.3679, -0.0537,  0.2030]],
#         grad_fn=<CatBackward0>),
#  240: tensor([[ 0.3601,  0.2927,  0.4048,  ...,  0.3704, -0.5075, -0.4886],
#          [ 0.6311, -0.1450,  0.5455,  ...,  0.5502, -0.2442, -0.1422],
#          [ 0.0774, -0.7453, -0.3559,  ..., -0.3937, -0.1543, -0.3739],
#          ...,
#          [-0.5102, -0.2874, -0.0052,  ..., -0.4755,  0.0491,  0.0711],
#          [-0.3572, -0.0664,  0.4827,  ..., -0.0994, -0.2758, -0.5222],
#          [ 0.4169,  0.7816,  0.5443,  ..., -0.0611,  0.3158,  0.2272]],
#         grad_fn=<CatBackward0>),
#  242: tensor([[-0.2035, -0.1396, -0.1950,  ..., -0.0180,  0.0200,  0.1602],
#          [-0.1819, -0.0370,  0.0449,  ..., -0.2826, -0.0837,  0.0309],
#          [-0.3732,  0.1676,  0.0668,  ..., -0.1346,  0.1468,  0.1740],
#          ...,
#          [-0.1974,  0.2884,  0.0137,  ...,  0.3691,  0.0814, -0.0620],
#          [ 0.2473,  0.2611,  0.3412,  ..., -0.0273, -0.3299, -0.2073],
#          [ 0.0472,  0.0331,  0.1093,  ..., -0.2855,  0.0806, -0.0453]],
#         grad_fn=<CatBackward0>),
#  241: tensor([[ 4.0823,  2.8221, -0.7138,  ..., -6.9713, -3.2578, -3.2477],
#          [ 5.0566, -5.2856, -5.1945,  ...,  2.5508,  0.9514,  0.9185],
#          [-1.3237, -6.6216, -4.3385,  ...,  2.9957, -5.2944, -5.2651],
#          ...,
#          [ 5.7255, -3.3992, -5.9680,  ..., -1.1641, -2.5756, -3.6335],
#          [ 2.7450, -2.2779,  4.9055,  ...,  1.0569,  7.0116,  0.5506],
#          [-3.2949,  0.7198, -3.7580,  ..., -4.6111,  2.7320,  2.4392]],
#         grad_fn=<CatBackward0>),
#  249: tensor([[ 0.0343,  0.0976, -0.0289,  ..., -0.0075, -0.3291, -0.3499],
#          [-0.1991,  0.1115, -0.2944,  ..., -0.1419, -0.2400, -0.2474],
#          [-0.1647,  0.1410, -0.1418,  ..., -0.0799, -0.1821, -0.1631],
#          ...,
#          [-0.2425,  0.0919, -0.0558,  ...,  0.0697, -0.1343, -0.0990],
#          [ 0.2504, -0.0921,  0.1594,  ...,  0.0395,  0.1517,  0.0944],
#          [ 0.5166,  0.1863, -0.4105,  ..., -0.0560, -0.1412,  0.2032]],
#         grad_fn=<CatBackward0>),
#  326: tensor([[ 0.4320,  1.0179,  1.1584,  ..., -0.8008,  0.1809,  0.0988],
#          [-1.0968,  0.1298,  0.4853,  ..., -0.6361,  0.1682,  0.2090],
#          [-0.1827, -0.1757,  0.7035,  ..., -0.7662, -1.3708, -1.4684],
#          ...,
#          [-0.6980,  0.3327, -0.4617,  ...,  0.0016,  0.4031,  0.5195],
#          [ 0.5225, -0.2450,  0.6068,  ..., -0.4578,  0.0867,  0.1525],
#          [-0.3920, -0.5495,  0.0448,  ...,  0.0083,  0.8336,  0.6624]],
#         grad_fn=<CatBackward0>),
#  119: tensor([[ 1.2002,  1.8061,  1.7585,  ...,  1.8110, -0.6584, -0.6094],
#          [-0.4342,  2.9874,  2.1407,  ...,  0.0283, -0.4773, -0.5304],
#          [-1.8857, -1.9837, -0.1842,  ..., -1.5007, -0.8725, -0.8072],
#          ...,
#          [-2.7294, -0.0775, -0.0709,  ..., -1.3837,  0.7032,  1.7412],
#          [ 1.7079, -1.6275,  2.2054,  ...,  0.8142, -0.6570, -0.8452],
#          [-2.6633, -0.8899, -2.5702,  ..., -0.4346, -0.8398, -2.2870]],
#         grad_fn=<CatBackward0>),
#  246: tensor([[-0.1568, -0.1180, -0.1949,  ...,  0.1837, -0.0433, -0.0331],
#          [ 0.0377, -0.0504,  0.2431,  ..., -0.0207,  0.1349,  0.1616],
#          [-0.9414, -0.4091, -0.2953,  ..., -0.0489,  0.0359,  0.0123],
#          ...,
#          [ 1.0385, -0.3423, -0.2142,  ...,  0.2212,  0.4735,  0.2651],
#          [ 0.1038, -0.1511,  0.3792,  ...,  0.0784,  0.0550,  0.0797],
#          [ 0.0862,  0.1593, -0.3829,  ..., -0.1636, -0.1070, -0.1167]],
#         grad_fn=<CatBackward0>),
#  49: tensor([[-0.4040, -0.1760, -0.5735,  ..., -0.8320,  0.0513,  0.0209],
#          [-0.2888,  0.2231, -0.3046,  ..., -0.2131, -2.0679, -2.0188],
#          [-0.1972,  0.4620,  1.7443,  ...,  0.6065, -0.0724,  0.0099],
#          ...,
#          [ 0.4775,  0.7628,  1.1581,  ...,  1.8747, -0.9542, -0.3619],
#          [ 0.6075,  0.4174,  0.6557,  ..., -0.5154, -0.2765, -0.3658],
#          [ 0.3222, -0.3746,  0.0581,  ...,  1.0229, -2.6111, -2.8825]],
#         grad_fn=<CatBackward0>),
#  245: tensor([[-0.4815, -0.0412, -0.2680,  ...,  0.2000, -0.4703, -0.5536],
#          [-0.4706, -0.0883, -0.1962,  ...,  0.1638, -0.4484, -0.4542],
#          [-0.4424,  0.0737, -0.1583,  ...,  0.1733, -0.3987, -0.4099],
#          ...,
#          [-2.4619, -0.1836, -0.1906,  ...,  0.2659, -0.6616, -0.9131],
#          [ 0.7838,  0.1752,  0.3096,  ..., -0.2361,  0.1871,  0.1718],
#          [-0.1187,  0.2103,  0.2122,  ..., -0.1540, -0.2443, -0.0833]],
#         grad_fn=<CatBackward0>),
#  236: tensor([[-1.0574e-01, -1.5707e-01,  2.1867e-01,  ..., -8.2472e-01,
#           -6.1863e-01, -7.8053e-01],
#          [ 5.8466e-01,  9.1621e-02, -2.3446e-01,  ...,  4.1649e-02,
#           -4.2015e-01, -6.2305e-01],
#          [ 2.3158e-01, -1.7124e-01,  1.4537e-01,  ...,  8.2856e-01,
#            3.8134e-01,  5.0759e-01],
#          ...,
#          [-5.0659e-01,  3.7374e-01,  1.8070e-01,  ...,  1.0946e+00,
#           -1.9546e-01, -2.1781e-01],
#          [-6.1097e-01,  4.0901e-01,  8.1555e-01,  ..., -6.0496e-01,
#           -8.0843e-02,  8.2702e-04],
#          [ 7.6070e-01, -7.0888e-01,  6.5975e-01,  ..., -1.4893e-02,
#            5.5640e-02,  1.2404e-01]], grad_fn=<CatBackward0>),
#  168: tensor([[ 0.4723, -0.2328, -0.6432,  ...,  0.3493,  0.0053,  0.0264],
#          [ 0.0131, -0.1663, -0.4192,  ..., -0.0519,  0.3042,  0.2773],
#          [ 0.8531,  0.7791,  0.5900,  ..., -0.0917, -0.4200, -0.4553],
#          ...,
#          [ 1.1460, -0.5336,  2.6896,  ..., -4.0694, -0.8809, -0.9925],
#          [-0.1622, -0.0541, -0.1412,  ...,  0.4233,  0.0601, -0.0797],
#          [-0.6993, -0.2592, -1.0325,  ...,  0.4959,  0.3949,  0.5452]],
#         grad_fn=<CatBackward0>),
#  93: tensor([[ 0.2356, -0.3519, -0.1074,  ..., -0.4243, -0.0569, -0.0809],
#          [-0.4958, -0.0866,  0.0015,  ...,  0.0298, -0.3008, -0.3879],
#          [-0.4727, -0.2795, -0.3770,  ..., -0.3068, -0.5401, -0.4703],
#          ...,
#          [-0.2582, -0.3599, -0.1564,  ..., -0.3887,  0.0278, -0.1757],
#          [ 0.4225,  0.1664,  0.3470,  ...,  0.6183,  0.0041,  0.0985],
#          [ 0.3187, -0.4251, -0.6070,  ..., -1.0661, -0.0112, -0.1810]],
#         grad_fn=<CatBackward0>),
#  91: tensor([[ 2.8082, -0.4671,  0.3252,  ..., -1.8786, -2.0694, -2.0626],
#          [ 0.2816,  0.7246,  0.3960,  ...,  0.5775,  1.9828,  2.0545],
#          [-0.6286, -0.2514, -0.8850,  ..., -0.8715, -1.4115, -1.3554],
#          ...,
#          [ 0.1576, -0.4006, -0.5081,  ..., -0.3097,  0.0202, -0.2553],
#          [-0.9055,  0.6950,  0.9361,  ...,  0.2124, -0.0393, -0.1431],
#          [ 0.0945, -0.3377, -0.0952,  ...,  0.0593,  0.6905, -0.0248]],
#         grad_fn=<CatBackward0>),
#  322: tensor([[-0.2883,  0.1572,  0.1400,  ...,  0.2112, -0.4108, -0.4133],
#          [-0.4674,  0.1928,  0.3114,  ...,  1.1342, -1.0215, -0.9822],
#          [-0.8931,  0.1467,  0.8277,  ..., -0.6035, -1.0654, -1.1093],
#          ...,
#          [-0.7057,  0.1392, -0.1958,  ...,  0.0834,  0.0682, -0.0854],
#          [ 2.2232, -0.1082,  0.3751,  ..., -0.2413,  0.0625,  0.3569],
#          [-0.9947,  0.0713, -0.2029,  ..., -1.1133, -0.8366, -0.9811]],
#         grad_fn=<CatBackward0>),
#  123: tensor([[ 0.8107, -1.1451,  0.3856,  ..., -0.0846,  0.0367,  0.0685],
#          [ 0.1763, -1.2404,  1.3837,  ..., -0.5801,  0.7186,  0.6428],
#          [ 0.5816, -0.5361,  0.2628,  ..., -0.6312,  0.3821,  0.3933],
#          ...,
#          [-0.4655,  0.2960, -0.1113,  ...,  0.0378, -0.6338, -0.5731],
#          [ 0.0422, -0.4785,  0.6321,  ..., -0.4832, -0.1112,  0.0635],
#          [-0.4806, -0.5280,  0.7744,  ..., -0.5027, -0.4577,  0.2629]],
#         grad_fn=<CatBackward0>),
#  264: tensor([[ 1.2568,  2.0890, -1.8869,  ...,  1.2288, -0.5959, -0.5393],
#          [-1.4167, -0.3486,  0.2695,  ...,  0.4784, -0.8168, -0.8039],
#          [-1.0974, -0.3813,  0.4812,  ..., -1.2425, -0.2010, -0.1285],
#          ...,
#          [-0.0242, -0.4904,  0.1118,  ..., -0.0913, -0.1651,  0.2440],
#          [-0.0754, -0.0979, -0.3640,  ...,  0.2705,  0.1873,  0.1906],
#          [-0.6201, -0.1099,  0.3058,  ..., -0.2058, -0.1764, -0.0446]],
#         grad_fn=<CatBackward0>),
#  260: tensor([[ 0.5216, -0.1021, -0.6689,  ...,  0.2773, -0.1078, -0.1040],
#          [-0.0705, -0.3082, -0.0434,  ..., -0.3115, -0.1490, -0.2667],
#          [ 0.2854, -0.7337,  0.6993,  ..., -0.5999, -0.6325, -0.5595],
#          ...,
#          [ 0.4938, -0.2992,  0.2183,  ..., -0.2134,  0.6732,  0.8515],
#          [-0.3102,  0.2417, -0.0856,  ...,  0.1680, -0.3106, -0.4406],
#          [ 0.4965, -0.0700,  0.2889,  ..., -0.1512,  0.7546,  0.7912]],
#         grad_fn=<CatBackward0>),
#  141: tensor([[-0.3929, -0.5298,  0.8408,  ..., -0.6857,  0.3733,  0.3546],
#          [-0.9423,  0.5354, -0.2625,  ..., -0.9804,  1.5362,  1.5493],
#          [ 0.6729, -0.0129, -0.5996,  ...,  0.1350, -0.4300, -0.4394],
#          ...,
#          [-0.7316,  0.7129, -0.4238,  ..., -0.0705,  0.5758, -0.0273],
#          [-0.7681,  1.2075,  0.2986,  ...,  0.3979, -0.5261,  0.1038],
#          [-0.6893,  0.0920, -0.3775,  ..., -0.3185,  0.7874,  0.2558]],
#         grad_fn=<CatBackward0>),
#  162: tensor([[ 0.2063,  0.1556, -0.2611,  ..., -0.1820,  0.6026,  0.5096],
#          [-0.6085,  0.1828,  0.0837,  ..., -0.2781,  0.3213,  0.3088],
#          [ 0.0335,  0.8915, -0.3346,  ...,  0.0254, -0.7532, -0.7042],
#          ...,
#          [ 0.4336,  0.1472, -0.7815,  ..., -0.0175,  0.0979,  0.1867],
#          [-0.4099,  0.0880, -0.0810,  ..., -0.1852, -0.0863, -0.1178],
#          [ 0.1037,  0.2952, -0.3890,  ...,  0.1512, -0.3669, -0.3209]],
#         grad_fn=<CatBackward0>),
#  120: tensor([[-2.8296, -0.9776,  0.1925,  ...,  0.0596,  0.7990,  0.7524],
#          [-0.9499, -0.2117, -1.0337,  ..., -0.8618, -1.2270, -1.2948],
#          [-1.3525, -0.1943,  1.4945,  ..., -0.7593, -2.9227, -2.9283],
#          ...,
#          [ 1.3063, -0.2324, -0.3954,  ..., -0.3736, -0.0258, -0.5161],
#          [-0.0066, -1.3509,  0.1119,  ..., -0.4067, -1.8140, -0.9828],
#          [-2.0413, -0.1313,  0.3425,  ...,  0.3134,  0.5205, -0.3546]],
#         grad_fn=<CatBackward0>)}
