# %%
import sys
sys.path.insert(0, '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/Canada/')

# %%
import torch
import pandas as pd
import numpy as np
import statistics
import torch
import random
import time
import numpy as np
#from transformers import AdamW
from torch.utils.tensorboard import SummaryWriter
import pickle
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import shutil
import itertools

from model.GRU_model import *
from pipeline_config import *
from utils import *

# %%
# Seeds for comparisons:

torch.manual_seed(1)
np.random.seed(2)
random.seed(3)
#torch.use_deterministic_algorithms(True)

# %%
with open(train_dataset_path, 'rb') as f:
    train_dataset_dict = pickle.load(f)
    
with open(test_dataset_path, 'rb') as f:
    test_dataset_dict = pickle.load(f)

with open(category_id_to_category_name_path, 'rb') as f:
    category_id_to_name_dict = pickle.load(f)
    
with open(categories_per_indent_path, 'rb') as f:
    categories_per_indent_dict = pickle.load(f)

with open(son_parent_path, 'rb') as f:
    son_parent_dict = pickle.load(f)

# %%
print(f'Features: {Features}')
print(f'HiddenSize: {HiddenSize}')
print(f'LayersDim: {LayersDim}')
print(f'OutputDim: {OutputDim}')
print(f'DropoutProb: {DropoutProb}')
print(f'Lr : {Lr}')
print(f'Epochs : {Epochs}')
# Out:
# Features: 1
# HiddenSize: 64
# LayersDim: 1
# OutputDim: 1
# DropoutProb: 0.0
# Lr : 0.01
# Epochs : 100

# %%
cnt = 0
for indent in sorted(list(categories_per_indent_dict.keys())):
    for category in categories_per_indent_dict[indent]:
        cnt+=1

cnt
# Out:
# 293

# %%
def hgru_model(son_parent_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weights_path):

    categories_counter = 0

    for indent in sorted(list(categories_per_indent_dict.keys())):
        for category in categories_per_indent_dict[indent]:
            print(f'indent: {indent}')
            category_name = category_id_to_name_dict[category]
            print(f'category_name: {category_name}')

            categories_counter+= 1
            print(f'categories_counter: {categories_counter}')

            if int(indent) == 0 or son_parent_dict[category] not in categories_per_indent_dict[indent-1]:
                print(f'category with 0 loss coef: {category_name}|{category}')
                loss_coef=0
                parent_weights=0
            else:
                son = category
                parent = son_parent_dict[son]
                parent_name = category_id_to_name_dict[parent]
                loss_coef = 4.0852794322516647*np.exp(-7) #4.789798464077446*np.exp(-7)
                parent_model = Model
                parent_optimizer = Optimizer
                parent_model, optimizer, checkpoint, valid_loss_min = load_checkpoint(weights_path+parent_name+'.pt', parent_model, parent_optimizer)
                parent_weights = unify_model_weights(parent_model)
 
            
            train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category_name], test_dataset_dict[category_name])
            model = Model
            optimizer = Optimizer
            model.to(Device)
            saving_param_path = weights_path+category_name+'.pt'
            training_and_evaluation(model, train_dataloader, test_dataloader, optimizer, category_name, parent_weights, loss_coef, path=saving_param_path)

# %%
hgru_models = hgru_model(son_parent_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weightspath)
# Out:
# indent: 0.0
# category_name: All-items
# categories_counter: 1
# category with 0 loss coef: All-items|2
# indent: 1.0
# category_name: Alcoholic beverages, tobacco products and recreational cannabis
# categories_counter: 2
# indent: 1.0
# category_name: All-items excluding alcoholic beverages, tobacco products and smokers' supplies and recreational cannabis
# categories_counter: 3
# indent: 1.0
# category_name: All-items excluding energy
# categories_counter: 4
# indent: 1.0
# category_name: All-items excluding food
# categories_counter: 5
# indent: 1.0
# category_name: All-items excluding food and energy
# categories_counter: 6
# indent: 1.0
# category_name: All-items excluding gasoline
# categories_counter: 7
# indent: 1.0
# category_name: All-items excluding mortgage interest cost
# categories_counter: 8
# indent: 1.0
# category_name: All-items excluding shelter
# categories_counter: 9
# indent: 1.0
# category_name: Clothing and footwear
# categories_counter: 10
# indent: 1.0
# category_name: Energy
# categories_counter: 11
# indent: 1.0
# category_name: Food
# categories_counter: 12
# indent: 1.0
# category_name: Food and energy
# categories_counter: 13
# indent: 1.0
# category_name: Health and personal care
# categories_counter: 14
# indent: 1.0
# category_name: Household operations, furnishings and equipment
# categories_counter: 15
# indent: 1.0
# category_name: Recreation, education and reading
# categories_counter: 16
# indent: 1.0
# category_name: Shelter
# categories_counter: 17
# indent: 1.0
# category_name: Transportation
# categories_counter: 18
# indent: 2.0
# category_name: Alcoholic beverages
# categories_counter: 19
# indent: 2.0
# category_name: Clothing
# categories_counter: 20
# indent: 2.0
# category_name: Clothing accessories, watches and jewellery
# categories_counter: 21
# indent: 2.0
# category_name: Clothing material, notions and services
# categories_counter: 22
# indent: 2.0
# category_name: Education and reading
# categories_counter: 23
# indent: 2.0
# category_name: Food purchased from restaurants
# categories_counter: 24
# indent: 2.0
# category_name: Food purchased from stores
# categories_counter: 25
# indent: 2.0
# category_name: Footwear
# categories_counter: 26
# indent: 2.0
# category_name: Fresh fruit and vegetables
# categories_counter: 27
# indent: 2.0
# category_name: Health care
# categories_counter: 28
# indent: 2.0
# category_name: Household furnishings and equipment
# categories_counter: 29
# indent: 2.0
# category_name: Household operations
# categories_counter: 30
# indent: 2.0
# category_name: Owned accommodation
# categories_counter: 31
# indent: 2.0
# category_name: Personal care
# categories_counter: 32
# indent: 2.0
# category_name: Private transportation
# categories_counter: 33
# indent: 2.0
# category_name: Public transportation
# categories_counter: 34
# indent: 2.0
# category_name: Recreation
# categories_counter: 35
# indent: 2.0
# category_name: Recreational cannabis
# categories_counter: 36
# indent: 2.0
# category_name: Rented accommodation
# categories_counter: 37
# indent: 2.0
# category_name: Tobacco products and smokers' supplies
# categories_counter: 38
# indent: 2.0
# category_name: Water, fuel and electricity
# categories_counter: 39
# indent: 3.0
# category_name: Alcoholic beverages purchased from stores
# categories_counter: 40
# indent: 3.0
# category_name: Alcoholic beverages served in licensed establishments
# categories_counter: 41
# indent: 3.0
# category_name: Athletic footwear
# categories_counter: 42
# indent: 3.0
# category_name: Bakery and cereal products (excluding baby food
# categories_counter: 43
# indent: 3.0
# category_name: Child care and housekeeping services
# categories_counter: 44
# indent: 3.0
# category_name: Children's clothing
# categories_counter: 45
# indent: 3.0
# category_name: Children's footwear (excluding athletic
# categories_counter: 46
# indent: 3.0
# category_name: Cigarettes
# categories_counter: 47
# indent: 3.0
# category_name: Clothing accessories
# categories_counter: 48
# indent: 3.0
# category_name: Communications
# categories_counter: 49
# indent: 3.0
# category_name: Dairy products and eggs
# categories_counter: 50
# indent: 3.0
# category_name: Education
# categories_counter: 51
# indent: 3.0
# category_name: Electricity
# categories_counter: 52
# indent: 3.0
# category_name: Fish, seafood and other marine products
# categories_counter: 53
# indent: 3.0
# category_name: Food purchased from cafeterias and other restaurants
# categories_counter: 54
# indent: 3.0
# category_name: Food purchased from fast food and take-out restaurants
# categories_counter: 55
# indent: 3.0
# category_name: Food purchased from table-service restaurants
# categories_counter: 56
# indent: 3.0
# category_name: Fruit, fruit preparations and nuts
# categories_counter: 57
# indent: 3.0
# category_name: Fuel oil and other fuels
# categories_counter: 58
# indent: 3.0
# category_name: Furniture and household textiles
# categories_counter: 59
# indent: 3.0
# category_name: Health care goods
# categories_counter: 60
# indent: 3.0
# category_name: Health care services
# categories_counter: 61
# indent: 3.0
# category_name: Home entertainment equipment, parts and services
# categories_counter: 62
# indent: 3.0
# category_name: Homeowners' home and mortgage insurance
# categories_counter: 63
# indent: 3.0
# category_name: Homeowners' maintenance and repairs
# categories_counter: 64
# indent: 3.0
# category_name: Homeowners' replacement cost
# categories_counter: 65
# indent: 3.0
# category_name: Household cleaning products
# categories_counter: 66
# indent: 3.0
# category_name: Household equipment
# categories_counter: 67
# indent: 3.0
# category_name: Inter-city transportation
# categories_counter: 68
# indent: 3.0
# category_name: Jewellery
# categories_counter: 69
# indent: 3.0
# category_name: Local and commuter transportation
# categories_counter: 70
# indent: 3.0
# category_name: Meat
# categories_counter: 71
# indent: 3.0
# category_name: Men's clothing
# categories_counter: 72
# indent: 3.0
# category_name: Men's footwear (excluding athletic
# categories_counter: 73
# indent: 3.0
# category_name: Mortgage interest cost
# categories_counter: 74
# indent: 3.0
# category_name: Natural gas
# categories_counter: 75
# indent: 3.0
# category_name: Operation of passenger vehicles
# categories_counter: 76
# indent: 3.0
# category_name: Other cultural and recreational services
# categories_counter: 77
# indent: 3.0
# category_name: Other food products and non-alcoholic beverages
# categories_counter: 78
# indent: 3.0
# category_name: Other household goods and services
# categories_counter: 79
# indent: 3.0
# category_name: Other owned accommodation expenses
# categories_counter: 80
# indent: 3.0
# category_name: Other tobacco products and smokers' supplies
# categories_counter: 81
# indent: 3.0
# category_name: Paper, plastic and aluminum foil supplies
# categories_counter: 82
# indent: 3.0
# category_name: Personal care services
# categories_counter: 83
# indent: 3.0
# category_name: Personal care supplies and equipment
# categories_counter: 84
# indent: 3.0
# category_name: Private transportation excluding gasoline
# categories_counter: 85
# indent: 3.0
# category_name: Property taxes and other special charges
# categories_counter: 86
# indent: 3.0
# category_name: Purchase and operation of recreational vehicles
# categories_counter: 87
# indent: 3.0
# category_name: Purchase, leasing and rental of passenger vehicles
# categories_counter: 88
# indent: 3.0
# category_name: Reading material (excluding textbooks
# categories_counter: 89
# indent: 3.0
# category_name: Recreational equipment and services (excluding recreational vehicles
# categories_counter: 90
# indent: 3.0
# category_name: Rent
# categories_counter: 91
# indent: 3.0
# category_name: Services related to household furnishings and equipment
# categories_counter: 92
# indent: 3.0
# category_name: Tenants' insurance premiums
# categories_counter: 93
# indent: 3.0
# category_name: Tenants' maintenance, repairs and other expenses
# categories_counter: 94
# indent: 3.0
# category_name: Travel services
# categories_counter: 95
# indent: 3.0
# category_name: Vegetables and vegetable preparations
# categories_counter: 96
# indent: 3.0
# category_name: Watches
# categories_counter: 97
# indent: 3.0
# category_name: Water
# categories_counter: 98
# indent: 3.0
# category_name: Women's clothing
# categories_counter: 99
# indent: 3.0
# category_name: Women's footwear (excluding athletic
# categories_counter: 100
# indent: 4.0
# category_name: Air transportation
# categories_counter: 101
# indent: 4.0
# category_name: Audio equipment
# categories_counter: 102
# indent: 4.0
# category_name: Bakery products
# categories_counter: 103
# indent: 4.0
# category_name: Beer purchased from stores
# categories_counter: 104
# indent: 4.0
# category_name: Beer served in licensed establishments
# categories_counter: 105
# indent: 4.0
# category_name: Books and reading material (excluding textbooks
# categories_counter: 106
# indent: 4.0
# category_name: Cereal products (excluding baby food
# categories_counter: 107
# indent: 4.0
# category_name: Child care services
# categories_counter: 108
# indent: 4.0
# category_name: City bus and subway transportation
# categories_counter: 109
# indent: 4.0
# category_name: Coffee and tea
# categories_counter: 110
# indent: 4.0
# category_name: Condiments, spices and vinegars
# categories_counter: 111
# indent: 4.0
# category_name: Dairy products
# categories_counter: 112
# indent: 4.0
# category_name: Dental care services
# categories_counter: 113
# indent: 4.0
# category_name: Detergents and soaps (other than personal care
# categories_counter: 114
# indent: 4.0
# category_name: Digital computing equipment and devices
# categories_counter: 115
# indent: 4.0
# category_name: Edible fats and oils
# categories_counter: 116
# indent: 4.0
# category_name: Eggs
# categories_counter: 117
# indent: 4.0
# category_name: Eye care goods
# categories_counter: 118
# indent: 4.0
# category_name: Eye care services
# categories_counter: 119
# indent: 4.0
# category_name: Financial services
# categories_counter: 120
# indent: 4.0
# category_name: Fish
# categories_counter: 121
# indent: 4.0
# category_name: Fresh fruit
# categories_counter: 122
# indent: 4.0
# category_name: Fresh or frozen meat (excluding poultry
# categories_counter: 123
# indent: 4.0
# category_name: Fresh or frozen poultry
# categories_counter: 124
# indent: 4.0
# category_name: Fresh vegetables
# categories_counter: 125
# indent: 4.0
# category_name: Furniture
# categories_counter: 126
# indent: 4.0
# category_name: Gasoline
# categories_counter: 127
# indent: 4.0
# category_name: Household appliances
# categories_counter: 128
# indent: 4.0
# category_name: Household textiles
# categories_counter: 129
# indent: 4.0
# category_name: Housekeeping services
# categories_counter: 130
# indent: 4.0
# category_name: Internet access services
# categories_counter: 131
# indent: 4.0
# category_name: Liquor purchased from stores
# categories_counter: 132
# indent: 4.0
# category_name: Liquor served in licensed establishments
# categories_counter: 133
# indent: 4.0
# category_name: Magazines and periodicals
# categories_counter: 134
# indent: 4.0
# category_name: Medicinal and pharmaceutical products
# categories_counter: 135
# indent: 4.0
# category_name: Newspapers
# categories_counter: 136
# indent: 4.0
# category_name: Non-alcoholic beverages
# categories_counter: 137
# indent: 4.0
# category_name: Non-electric kitchen utensils, tableware and cookware
# categories_counter: 138
# indent: 4.0
# category_name: Nuts and seeds
# categories_counter: 139
# indent: 4.0
# category_name: Operation of recreational vehicles
# categories_counter: 140
# indent: 4.0
# category_name: Oral-hygiene products
# categories_counter: 141
# indent: 4.0
# category_name: Other food preparations
# categories_counter: 142
# indent: 4.0
# category_name: Other health care goods
# categories_counter: 143
# indent: 4.0
# category_name: Other health care services
# categories_counter: 144
# indent: 4.0
# category_name: Other horticultural goods
# categories_counter: 145
# indent: 4.0
# category_name: Other household cleaning products
# categories_counter: 146
# indent: 4.0
# category_name: Other household services
# categories_counter: 147
# indent: 4.0
# category_name: Other household supplies
# categories_counter: 148
# indent: 4.0
# category_name: Other lessons, courses and education services
# categories_counter: 149
# indent: 4.0
# category_name: Other passenger vehicle operating expenses
# categories_counter: 150
# indent: 4.0
# category_name: Other personal care supplies and equipment
# categories_counter: 151
# indent: 4.0
# category_name: Other recreational equipment
# categories_counter: 152
# indent: 4.0
# category_name: Paper supplies
# categories_counter: 153
# indent: 4.0
# category_name: Passenger vehicle parts, maintenance and repairs
# categories_counter: 154
# indent: 4.0
# category_name: Personal soap
# categories_counter: 155
# indent: 4.0
# category_name: Pet food and supplies
# categories_counter: 156
# indent: 4.0
# category_name: Photographic equipment and supplies
# categories_counter: 157
# indent: 4.0
# category_name: Plastic and aluminum foil supplies
# categories_counter: 158
# indent: 4.0
# category_name: Postal and other communications services
# categories_counter: 159
# indent: 4.0
# category_name: Preserved fruit and fruit preparations
# categories_counter: 160
# indent: 4.0
# category_name: Preserved vegetables and vegetable preparations
# categories_counter: 161
# indent: 4.0
# category_name: Processed meat
# categories_counter: 162
# indent: 4.0
# category_name: Purchase and leasing of passenger vehicles
# categories_counter: 163
# indent: 4.0
# category_name: Purchase of digital media
# categories_counter: 164
# indent: 4.0
# category_name: Purchase of recreational vehicles and outboard motors
# categories_counter: 165
# indent: 4.0
# category_name: Rail, highway bus and other inter-city transportation
# categories_counter: 166
# indent: 4.0
# category_name: Recreational services
# categories_counter: 167
# indent: 4.0
# category_name: Rental of passenger vehicles
# categories_counter: 168
# indent: 4.0
# category_name: School textbooks and supplies
# categories_counter: 169
# indent: 4.0
# category_name: Seafood and other marine products
# categories_counter: 170
# indent: 4.0
# category_name: Seeds, plants and cut flowers
# categories_counter: 171
# indent: 4.0
# category_name: Spectator entertainment (excluding video and audio subscription services
# categories_counter: 172
# indent: 4.0
# category_name: Sporting and exercise equipment
# categories_counter: 173
# indent: 4.0
# category_name: Sugar and confectionery
# categories_counter: 174
# indent: 4.0
# category_name: Taxi and other local and commuter transportation services
# categories_counter: 175
# indent: 4.0
# category_name: Telephone equipment
# categories_counter: 176
# indent: 4.0
# category_name: Telephone services
# categories_counter: 177
# indent: 4.0
# category_name: Toiletry items and cosmetics
# categories_counter: 178
# indent: 4.0
# category_name: Tools and other household equipment
# categories_counter: 179
# indent: 4.0
# category_name: Toys, games (excluding video games) and hobby supplies
# categories_counter: 180
# indent: 4.0
# category_name: Travel tours
# categories_counter: 181
# indent: 4.0
# category_name: Traveller accommodation
# categories_counter: 182
# indent: 4.0
# category_name: Tuition fees
# categories_counter: 183
# indent: 4.0
# category_name: Use of recreational facilities and services
# categories_counter: 184
# indent: 4.0
# category_name: Video and audio subscription services
# categories_counter: 185
# indent: 4.0
# category_name: Video equipment
# categories_counter: 186
# indent: 4.0
# category_name: Wine purchased from stores
# categories_counter: 187
# indent: 4.0
# category_name: Wine served in licensed establishments
# categories_counter: 188
# indent: 5.0
# category_name: All other food preparations
# categories_counter: 189
# indent: 5.0
# category_name: All other passenger vehicle operating expenses
# categories_counter: 190
# indent: 5.0
# category_name: Apples
# categories_counter: 191
# indent: 5.0
# category_name: Baby foods
# categories_counter: 192
# indent: 5.0
# category_name: Bananas
# categories_counter: 193
# indent: 5.0
# category_name: Bedding and other household textiles
# categories_counter: 194
# indent: 5.0
# category_name: Bleach and other household chemical products
# categories_counter: 195
# indent: 5.0
# category_name: Bread, rolls and buns
# categories_counter: 196
# indent: 5.0
# category_name: Breakfast cereal and other cereal products (excluding baby food
# categories_counter: 197
# indent: 5.0
# category_name: Butter
# categories_counter: 198
# indent: 5.0
# category_name: Canned and other preserved fish
# categories_counter: 199
# indent: 5.0
# category_name: Canned vegetables and other vegetable preparations
# categories_counter: 200
# indent: 5.0
# category_name: Cellular services
# categories_counter: 201
# indent: 5.0
# category_name: Cheese
# categories_counter: 202
# indent: 5.0
# category_name: Coffee
# categories_counter: 203
# indent: 5.0
# category_name: Computer equipment, software and supplies
# categories_counter: 204
# indent: 5.0
# category_name: Confectionery
# categories_counter: 205
# indent: 5.0
# category_name: Cookies and crackers
# categories_counter: 206
# indent: 5.0
# category_name: Cooking appliances
# categories_counter: 207
# indent: 5.0
# category_name: Detergents and rinse agents for dish washing
# categories_counter: 208
# indent: 5.0
# category_name: Drivers' licences
# categories_counter: 209
# indent: 5.0
# category_name: Fabric softener
# categories_counter: 210
# indent: 5.0
# category_name: Flour and flour-based mixes
# categories_counter: 211
# indent: 5.0
# category_name: Fresh milk
# categories_counter: 212
# indent: 5.0
# category_name: Fresh or frozen beef
# categories_counter: 213
# indent: 5.0
# category_name: Fresh or frozen chicken
# categories_counter: 214
# indent: 5.0
# category_name: Fresh or frozen fish (including portions and fish sticks
# categories_counter: 215
# indent: 5.0
# category_name: Fresh or frozen pork
# categories_counter: 216
# indent: 5.0
# category_name: Frozen and dried vegetables
# categories_counter: 217
# indent: 5.0
# category_name: Frozen food preparations
# categories_counter: 218
# indent: 5.0
# category_name: Fruit juices
# categories_counter: 219
# indent: 5.0
# category_name: Fuel, parts and accessories for recreational vehicles
# categories_counter: 220
# indent: 5.0
# category_name: Ham and bacon
# categories_counter: 221
# indent: 5.0
# category_name: Household cleaning and polishing products
# categories_counter: 222
# indent: 5.0
# category_name: Household paper supplies
# categories_counter: 223
# indent: 5.0
# category_name: Household tools (including lawn, garden and snow removal equipment
# categories_counter: 224
# indent: 5.0
# category_name: Ice cream and related products
# categories_counter: 225
# indent: 5.0
# category_name: Insurance, licences and other services for recreational vehicles
# categories_counter: 226
# indent: 5.0
# category_name: Laundry and dishwashing appliances
# categories_counter: 227
# indent: 5.0
# category_name: Laundry detergents and soaps
# categories_counter: 228
# indent: 5.0
# category_name: Leasing of passenger vehicles
# categories_counter: 229
# indent: 5.0
# category_name: Lettuce
# categories_counter: 230
# indent: 5.0
# category_name: Margarine
# categories_counter: 231
# indent: 5.0
# category_name: Medicinal cannabis
# categories_counter: 232
# indent: 5.0
# category_name: Multipurpose digital devices
# categories_counter: 233
# indent: 5.0
# category_name: Non-prescribed medicines
# categories_counter: 234
# indent: 5.0
# category_name: Oranges
# categories_counter: 235
# indent: 5.0
# category_name: Other bakery products
# categories_counter: 236
# indent: 5.0
# category_name: Other dairy products
# categories_counter: 237
# indent: 5.0
# category_name: Other edible fats and oils
# categories_counter: 238
# indent: 5.0
# category_name: Other fresh fruit
# categories_counter: 239
# indent: 5.0
# category_name: Other fresh or frozen meat (excluding poultry
# categories_counter: 240
# indent: 5.0
# category_name: Other fresh or frozen poultry
# categories_counter: 241
# indent: 5.0
# category_name: Other fresh vegetables
# categories_counter: 242
# indent: 5.0
# category_name: Other furniture
# categories_counter: 243
# indent: 5.0
# category_name: Other household appliances
# categories_counter: 244
# indent: 5.0
# category_name: Other household equipment
# categories_counter: 245
# indent: 5.0
# category_name: Other preserved fruit and fruit preparations
# categories_counter: 246
# indent: 5.0
# category_name: Other processed meat
# categories_counter: 247
# indent: 5.0
# category_name: Other shellfish
# categories_counter: 248
# indent: 5.0
# category_name: Parking fees
# categories_counter: 249
# indent: 5.0
# category_name: Passenger vehicle insurance premiums
# categories_counter: 250
# indent: 5.0
# category_name: Passenger vehicle maintenance and repair services
# categories_counter: 251
# indent: 5.0
# category_name: Passenger vehicle parts, accessories and supplies
# categories_counter: 252
# indent: 5.0
# category_name: Passenger vehicle registration fees
# categories_counter: 253
# indent: 5.0
# category_name: Pasta products
# categories_counter: 254
# indent: 5.0
# category_name: Potatoes
# categories_counter: 255
# indent: 5.0
# category_name: Prescribed medicines (excluding medicinal cannabis
# categories_counter: 256
# indent: 5.0
# category_name: Purchase of passenger vehicles
# categories_counter: 257
# indent: 5.0
# category_name: Refrigerators and freezers
# categories_counter: 258
# indent: 5.0
# category_name: Rice and rice-based mixes
# categories_counter: 259
# indent: 5.0
# category_name: Shrimps and prawns
# categories_counter: 260
# indent: 5.0
# category_name: Soup
# categories_counter: 261
# indent: 5.0
# category_name: Stationery
# categories_counter: 262
# indent: 5.0
# category_name: Sugar and syrup
# categories_counter: 263
# indent: 5.0
# category_name: Tea
# categories_counter: 264
# indent: 5.0
# category_name: Tomatoes
# categories_counter: 265
# indent: 5.0
# category_name: Upholstered furniture
# categories_counter: 266
# indent: 5.0
# category_name: Window coverings
# categories_counter: 267
# indent: 5.0
# category_name: Wooden furniture
# categories_counter: 268
# indent: 6.0
# category_name: All other miscellaneous food preparations
# categories_counter: 269
# indent: 6.0
# category_name: Bacon
# categories_counter: 270
# indent: 6.0
# category_name: Canned fruit
# categories_counter: 271
# indent: 6.0
# category_name: Canned infant or junior foods
# categories_counter: 272
# indent: 6.0
# category_name: Canned salmon
# categories_counter: 273
# indent: 6.0
# category_name: Canned tuna
# categories_counter: 274
# indent: 6.0
# category_name: Cheddar cheese
# categories_counter: 275
# indent: 6.0
# category_name: Dried and dehydrated fruit
# categories_counter: 276
# indent: 6.0
# category_name: Dry or fresh pasta
# categories_counter: 277
# indent: 6.0
# category_name: Frozen fruit
# categories_counter: 278
# indent: 6.0
# category_name: Ham excluding deli ham
# categories_counter: 279
# indent: 6.0
# category_name: Infant formula
# categories_counter: 280
# indent: 6.0
# category_name: Instant and other coffee
# categories_counter: 281
# indent: 6.0
# category_name: Jam, jelly and other preserves
# categories_counter: 282
# indent: 6.0
# category_name: Low-fat milk
# categories_counter: 283
# indent: 6.0
# category_name: Mozzarella cheese
# categories_counter: 284
# indent: 6.0
# category_name: Nut butter
# categories_counter: 285
# indent: 6.0
# category_name: Pasta mixes
# categories_counter: 286
# indent: 6.0
# category_name: Potato chips and other snack products n.e.c
# categories_counter: 287
# indent: 6.0
# category_name: Processed cheese
# categories_counter: 288
# indent: 6.0
# category_name: Purchase of new passenger vehicles
# categories_counter: 289
# indent: 6.0
# category_name: Purchase of used passenger vehicles
# categories_counter: 290
# indent: 6.0
# category_name: Roasted or ground coffee
# categories_counter: 291
# indent: 6.0
# category_name: Unripened or fresh cheese
# categories_counter: 292
# indent: 6.0
# category_name: Whole milk
# categories_counter: 293

# %% [markdown]
# Save prediction dict:

# %%
def get_results_on_test_set(weights_path, train_dataset_dict, test_dataset_dict, categories = None):
    predictions_dict = {}
    if categories is None:
        categories = list(test_dataset_dict.keys())
        
    for category in categories:
        print(category)
        train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category], test_dataset_dict[category])
        basic_model = Model
        basic_optimizer = Optimizer
        ckp_path = weights_path+category+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        predictions = get_predictions_on_test_set(model, test_dataloader)
        predictions_dict[category] = predictions
    return predictions_dict

# %%
categories_lists = list(categories_per_indent_dict.values())
categories_id = list(itertools.chain.from_iterable(categories_lists))
categories = []
for category_id in categories_id:
    categories.append(category_id_to_name_dict[category_id])
    
predictions_dict = get_results_on_test_set(weightspath, train_dataset_dict, test_dataset_dict, categories = categories)
# Out:
# Air transportation
# Audio equipment
# Bakery products
# Beer purchased from stores
# Beer served in licensed establishments
# Books and reading material (excluding textbooks
# Cereal products (excluding baby food
# Child care services
# City bus and subway transportation
# Coffee and tea
# Condiments, spices and vinegars
# Dairy products
# Dental care services
# Detergents and soaps (other than personal care
# Digital computing equipment and devices
# Edible fats and oils
# Eggs
# Eye care goods
# Eye care services
# Financial services
# Fish
# Fresh fruit
# Fresh or frozen meat (excluding poultry
# Fresh or frozen poultry
# Fresh vegetables
# Furniture
# Gasoline
# Household appliances
# Household textiles
# Housekeeping services
# Internet access services
# Liquor purchased from stores
# Liquor served in licensed establishments
# Magazines and periodicals
# Medicinal and pharmaceutical products
# Newspapers
# Non-alcoholic beverages
# Non-electric kitchen utensils, tableware and cookware
# Nuts and seeds
# Operation of recreational vehicles
# Oral-hygiene products
# Other food preparations
# Other health care goods
# Other health care services
# Other horticultural goods
# Other household cleaning products
# Other household services
# Other household supplies
# Other lessons, courses and education services
# Other passenger vehicle operating expenses
# Other personal care supplies and equipment
# Other recreational equipment
# Paper supplies
# Passenger vehicle parts, maintenance and repairs
# Personal soap
# Pet food and supplies
# Photographic equipment and supplies
# Plastic and aluminum foil supplies
# Postal and other communications services
# Preserved fruit and fruit preparations
# Preserved vegetables and vegetable preparations
# Processed meat
# Purchase and leasing of passenger vehicles
# Purchase of digital media
# Purchase of recreational vehicles and outboard motors
# Rail, highway bus and other inter-city transportation
# Recreational services
# Rental of passenger vehicles
# School textbooks and supplies
# Seafood and other marine products
# Seeds, plants and cut flowers
# Spectator entertainment (excluding video and audio subscription services
# Sporting and exercise equipment
# Sugar and confectionery
# Taxi and other local and commuter transportation services
# Telephone equipment
# Telephone services
# Toiletry items and cosmetics
# Tools and other household equipment
# Toys, games (excluding video games) and hobby supplies
# Travel tours
# Traveller accommodation
# Tuition fees
# Use of recreational facilities and services
# Video and audio subscription services
# Video equipment
# Wine purchased from stores
# Wine served in licensed establishments
# Alcoholic beverages
# Clothing
# Clothing accessories, watches and jewellery
# Clothing material, notions and services
# Education and reading
# Food purchased from restaurants
# Food purchased from stores
# Footwear
# Fresh fruit and vegetables
# Health care
# Household furnishings and equipment
# Household operations
# Owned accommodation
# Personal care
# Private transportation
# Public transportation
# Recreation
# Recreational cannabis
# Rented accommodation
# Tobacco products and smokers' supplies
# Water, fuel and electricity
# Alcoholic beverages purchased from stores
# Alcoholic beverages served in licensed establishments
# Athletic footwear
# Bakery and cereal products (excluding baby food
# Child care and housekeeping services
# Children's clothing
# Children's footwear (excluding athletic
# Cigarettes
# Clothing accessories
# Communications
# Dairy products and eggs
# Education
# Electricity
# Fish, seafood and other marine products
# Food purchased from cafeterias and other restaurants
# Food purchased from fast food and take-out restaurants
# Food purchased from table-service restaurants
# Fruit, fruit preparations and nuts
# Fuel oil and other fuels
# Furniture and household textiles
# Health care goods
# Health care services
# Home entertainment equipment, parts and services
# Homeowners' home and mortgage insurance
# Homeowners' maintenance and repairs
# Homeowners' replacement cost
# Household cleaning products
# Household equipment
# Inter-city transportation
# Jewellery
# Local and commuter transportation
# Meat
# Men's clothing
# Men's footwear (excluding athletic
# Mortgage interest cost
# Natural gas
# Operation of passenger vehicles
# Other cultural and recreational services
# Other food products and non-alcoholic beverages
# Other household goods and services
# Other owned accommodation expenses
# Other tobacco products and smokers' supplies
# Paper, plastic and aluminum foil supplies
# Personal care services
# Personal care supplies and equipment
# Private transportation excluding gasoline
# Property taxes and other special charges
# Purchase and operation of recreational vehicles
# Purchase, leasing and rental of passenger vehicles
# Reading material (excluding textbooks
# Recreational equipment and services (excluding recreational vehicles
# Rent
# Services related to household furnishings and equipment
# Tenants' insurance premiums
# Tenants' maintenance, repairs and other expenses
# Travel services
# Vegetables and vegetable preparations
# Watches
# Water
# Women's clothing
# Women's footwear (excluding athletic
# Alcoholic beverages, tobacco products and recreational cannabis
# All-items excluding alcoholic beverages, tobacco products and smokers' supplies and recreational cannabis
# All-items excluding energy
# All-items excluding food
# All-items excluding food and energy
# All-items excluding gasoline
# All-items excluding mortgage interest cost
# All-items excluding shelter
# Clothing and footwear
# Energy
# Food
# Food and energy
# Health and personal care
# Household operations, furnishings and equipment
# Recreation, education and reading
# Shelter
# Transportation
# All other food preparations
# All other passenger vehicle operating expenses
# Apples
# Baby foods
# Bananas
# Bedding and other household textiles
# Bleach and other household chemical products
# Bread, rolls and buns
# Breakfast cereal and other cereal products (excluding baby food
# Butter
# Canned and other preserved fish
# Canned vegetables and other vegetable preparations
# Cellular services
# Cheese
# Coffee
# Computer equipment, software and supplies
# Confectionery
# Cookies and crackers
# Cooking appliances
# Detergents and rinse agents for dish washing
# Drivers' licences
# Fabric softener
# Flour and flour-based mixes
# Fresh milk
# Fresh or frozen beef
# Fresh or frozen chicken
# Fresh or frozen fish (including portions and fish sticks
# Fresh or frozen pork
# Frozen and dried vegetables
# Frozen food preparations
# Fruit juices
# Fuel, parts and accessories for recreational vehicles
# Ham and bacon
# Household cleaning and polishing products
# Household paper supplies
# Household tools (including lawn, garden and snow removal equipment
# Ice cream and related products
# Insurance, licences and other services for recreational vehicles
# Laundry and dishwashing appliances
# Laundry detergents and soaps
# Leasing of passenger vehicles
# Lettuce
# Margarine
# Medicinal cannabis
# Multipurpose digital devices
# Non-prescribed medicines
# Oranges
# Other bakery products
# Other dairy products
# Other edible fats and oils
# Other fresh fruit
# Other fresh or frozen meat (excluding poultry
# Other fresh or frozen poultry
# Other fresh vegetables
# Other furniture
# Other household appliances
# Other household equipment
# Other preserved fruit and fruit preparations
# Other processed meat
# Other shellfish
# Parking fees
# Passenger vehicle insurance premiums
# Passenger vehicle maintenance and repair services
# Passenger vehicle parts, accessories and supplies
# Passenger vehicle registration fees
# Pasta products
# Potatoes
# Prescribed medicines (excluding medicinal cannabis
# Purchase of passenger vehicles
# Refrigerators and freezers
# Rice and rice-based mixes
# Shrimps and prawns
# Soup
# Stationery
# Sugar and syrup
# Tea
# Tomatoes
# Upholstered furniture
# Window coverings
# Wooden furniture
# All other miscellaneous food preparations
# Bacon
# Canned fruit
# Canned infant or junior foods
# Canned salmon
# Canned tuna
# Cheddar cheese
# Dried and dehydrated fruit
# Dry or fresh pasta
# Frozen fruit
# Ham excluding deli ham
# Infant formula
# Instant and other coffee
# Jam, jelly and other preserves
# Low-fat milk
# Mozzarella cheese
# Nut butter
# Pasta mixes
# Potato chips and other snack products n.e.c
# Processed cheese
# Purchase of new passenger vehicles
# Purchase of used passenger vehicles
# Roasted or ground coffee
# Unripened or fresh cheese
# Whole milk
# All-items

# %%
with open(test_predictions_path, 'wb') as handle:
    pickle.dump(predictions_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Save model weights in dict for bi-directional use:

# %%
categories_lists = list(categories_per_indent_dict.values())
categories_id = list(itertools.chain.from_iterable(categories_lists))
categories = []
for category_id in categories_id:
    categories.append(category_id_to_name_dict[category_id])

category_id_list = []
 
# list out keys and values separately
key_list = list(category_id_to_name_dict.keys())
val_list = list(category_id_to_name_dict.values())

for cat_name in categories:
    position = val_list.index(cat_name)
    category_id_list.append(key_list[position])

# %%
def get_weights_per_category(category_id_list, dir_path):
    basic_model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
    basic_optimizer = torch.optim.AdamW(basic_model.parameters(), lr=Lr)
    #basic_model.to(device)

    best_models_weights_dict = {}

    for category_id in category_id_list:
        category_name = category_id_to_name_dict[category_id]
        ckp_path = dir_path+category_name+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        category_model_weights = unify_model_weights(model)
        best_models_weights_dict[category_id] = category_model_weights
        
    return best_models_weights_dict

# %%
dir_path = '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/Canada/hgru/models_weights/'

# %%
category_id_list = []
 
# list out keys and values separately
key_list = list(category_id_to_name_dict.keys())
val_list = list(category_id_to_name_dict.values())

for cat_name in categories:
    position = val_list.index(cat_name)
    category_id_list.append(key_list[position])

# %%
len(categories)
# Out:
# 293

# %%
weights_dict = get_weights_per_category(category_id_list, dir_path)

# %%
with open(hgru_model_weights_path, 'wb') as handle:
    pickle.dump(weights_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
Lr
# Out:
# 0.01
