# %%
import sys
sys.path.insert(0, '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/')

# %%
import torch
import pandas as pd
import numpy as np
import statistics
import torch
import random
import time
import numpy as np
#from transformers import AdamW
from torch.utils.tensorboard import SummaryWriter
import pickle
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import shutil
import itertools

from model.GRU_model import *
from pipeline_config import *
from utils import *

# %%
# Seeds for comparisons:

torch.manual_seed(1)
np.random.seed(2)
random.seed(3)
#torch.use_deterministic_algorithms(True)

# %%
with open(train_dataset_path, 'rb') as f:
    train_dataset_dict = pickle.load(f)
    
with open(test_dataset_path, 'rb') as f:
    test_dataset_dict = pickle.load(f)

with open(category_id_to_category_name_path, 'rb') as f:
    category_id_to_name_dict = pickle.load(f)
    
with open(categories_per_indent_path, 'rb') as f:
    categories_per_indent_dict = pickle.load(f)

with open(son_parent_path, 'rb') as f:
    son_parent_dict = pickle.load(f)

# %%
print(f'Features: {Features}')
print(f'HiddenSize: {HiddenSize}')
print(f'LayersDim: {LayersDim}')
print(f'OutputDim: {OutputDim}')
print(f'DropoutProb: {DropoutProb}')
print(f'Lr : {Lr}')
print(f'Epochs : {Epochs}')
# Out:
# Features: 1
# HiddenSize: 64
# LayersDim: 1
# OutputDim: 1
# DropoutProb: 0.0
# Lr : 0.01
# Epochs : 100

# %%
cnt = 0
for indent in sorted(list(categories_per_indent_dict.keys())):
    for category in categories_per_indent_dict[indent]:
        cnt+=1

cnt
# Out:
# 350

# %%
def hgru_model(son_parent_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weights_path):

    categories_counter = 0

    for indent in sorted(list(categories_per_indent_dict.keys())):
        for category in categories_per_indent_dict[indent]:
            print(f'indent: {indent}')
            category_name = category_id_to_name_dict[category]
            print(f'category_name: {category_name}')

            categories_counter+= 1
            print(f'categories_counter: {categories_counter}')

            if int(indent) == 0 or son_parent_dict[category] not in categories_per_indent_dict[indent-1]:
                print(f'category with 0 loss coef: {category_name}|{category}')
                loss_coef=0
                parent_weights=0
            else:
                son = category
                parent = son_parent_dict[son]
                parent_name = category_id_to_name_dict[parent]
                loss_coef = 1*np.exp(-10)
                parent_model = Model
                parent_optimizer = Optimizer
                parent_model, optimizer, checkpoint, valid_loss_min = load_checkpoint(weights_path+parent_name+'.pt', parent_model, parent_optimizer)
                parent_weights = unify_model_weights(parent_model)
 
            
            train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category_name], test_dataset_dict[category_name])
            model = Model
            optimizer = Optimizer
            model.to(Device)
            saving_param_path = weights_path+category_name+'.pt'
            training_and_evaluation(model, train_dataloader, test_dataloader, optimizer, category_name, parent_weights, loss_coef, path=saving_param_path)

# %%
hgru_models = hgru_model(son_parent_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weightspath)
# Out:
# indent: 0.0
# category_name: All items
# categories_counter: 1
# category with 0 loss coef: All items|8106.0
# indent: 1.0
# category_name: All items less energy
# categories_counter: 2
# indent: 1.0
# category_name: All items less food
# categories_counter: 3
# indent: 1.0
# category_name: All items less food and energy
# categories_counter: 4
# indent: 1.0
# category_name: All items less food and shelter
# categories_counter: 5
# indent: 1.0
# category_name: All items less food, shelter, and energy
# categories_counter: 6
# indent: 1.0
# category_name: All items less food, shelter, energy, and used cars and trucks
# categories_counter: 7
# indent: 1.0
# category_name: All items less medical care
# categories_counter: 8
# indent: 1.0
# category_name: All items less shelter
# categories_counter: 9
# indent: 1.0
# category_name: Apparel less footwear
# categories_counter: 10
# indent: 1.0
# category_name: Commodities
# categories_counter: 11
# indent: 1.0
# category_name: Durables
# categories_counter: 12
# indent: 1.0
# category_name: Education and communication
# categories_counter: 13
# indent: 1.0
# category_name: Energy
# categories_counter: 14
# indent: 1.0
# category_name: Food
# categories_counter: 15
# indent: 1.0
# category_name: Food and beverages
# categories_counter: 16
# indent: 1.0
# category_name: Fuels and utilities
# categories_counter: 17
# indent: 1.0
# category_name: Household furnishings and operations
# categories_counter: 18
# indent: 1.0
# category_name: Housing
# categories_counter: 19
# indent: 1.0
# category_name: Medical care
# categories_counter: 20
# indent: 1.0
# category_name: Nondurables
# categories_counter: 21
# indent: 1.0
# category_name: Other goods and services
# categories_counter: 22
# indent: 1.0
# category_name: Other services
# categories_counter: 23
# indent: 1.0
# category_name: Recreation
# categories_counter: 24
# indent: 1.0
# category_name: Services
# categories_counter: 25
# indent: 1.0
# category_name: Transportation
# categories_counter: 26
# indent: 1.0
# category_name: Utilities and public transportation
# categories_counter: 27
# indent: 2.0
# category_name: Commodities less food
# categories_counter: 28
# indent: 2.0
# category_name: Commodities less food and beverages
# categories_counter: 29
# indent: 2.0
# category_name: Commodities less food and energy commodities
# categories_counter: 30
# indent: 2.0
# category_name: Commodities less food, energy, and used cars and trucks
# categories_counter: 31
# indent: 2.0
# category_name: Communication
# categories_counter: 32
# indent: 2.0
# category_name: Domestically produced farm food
# categories_counter: 33
# indent: 2.0
# category_name: Education
# categories_counter: 34
# indent: 2.0
# category_name: Energy commodities
# categories_counter: 35
# indent: 2.0
# category_name: Energy services
# categories_counter: 36
# indent: 2.0
# category_name: Food at home
# categories_counter: 37
# indent: 2.0
# category_name: Food away from home
# categories_counter: 38
# indent: 2.0
# category_name: Household energy
# categories_counter: 39
# indent: 2.0
# category_name: Nondurables less food
# categories_counter: 40
# indent: 2.0
# category_name: Nondurables less food and apparel
# categories_counter: 41
# indent: 2.0
# category_name: Nondurables less food and beverages
# categories_counter: 42
# indent: 2.0
# category_name: Nondurables less food, beverages, and apparel
# categories_counter: 43
# indent: 2.0
# category_name: Personal care
# categories_counter: 44
# indent: 2.0
# category_name: Pets, pet products and services
# categories_counter: 45
# indent: 2.0
# category_name: Photography
# categories_counter: 46
# indent: 2.0
# category_name: Private transportation
# categories_counter: 47
# indent: 2.0
# category_name: Services less energy services
# categories_counter: 48
# indent: 2.0
# category_name: Services less medical care services
# categories_counter: 49
# indent: 2.0
# category_name: Services less rent of shelter
# categories_counter: 50
# indent: 2.0
# category_name: Video and audio
# categories_counter: 51
# indent: 3.0
# category_name: Alcoholic beverages
# categories_counter: 52
# indent: 3.0
# category_name: Apparel
# categories_counter: 53
# indent: 3.0
# category_name: Cereals and bakery products
# categories_counter: 54
# indent: 3.0
# category_name: Dairy and related products
# categories_counter: 55
# indent: 3.0
# category_name: Education and communication commodities
# categories_counter: 56
# indent: 3.0
# category_name: Electricity
# categories_counter: 57
# indent: 3.0
# category_name: Food from vending machines and mobile vendors
# categories_counter: 58
# indent: 3.0
# category_name: Fruits and vegetables
# categories_counter: 59
# indent: 3.0
# category_name: Fuel oil and other fuels
# categories_counter: 60
# indent: 3.0
# category_name: Full service meals and snacks
# categories_counter: 61
# indent: 3.0
# category_name: Household furnishings and supplies
# categories_counter: 62
# indent: 3.0
# category_name: Information and information processing
# categories_counter: 63
# indent: 3.0
# category_name: Information technology, hardware and services
# categories_counter: 64
# indent: 3.0
# category_name: Limited service meals and snacks
# categories_counter: 65
# indent: 3.0
# category_name: Meats, poultry, fish, and eggs
# categories_counter: 66
# indent: 3.0
# category_name: Medical care commodities
# categories_counter: 67
# indent: 3.0
# category_name: Motor fuel
# categories_counter: 68
# indent: 3.0
# category_name: New and used motor vehicles
# categories_counter: 69
# indent: 3.0
# category_name: Nonalcoholic beverages and beverage materials
# categories_counter: 70
# indent: 3.0
# category_name: Other food at home
# categories_counter: 71
# indent: 3.0
# category_name: Other food away from home
# categories_counter: 72
# indent: 3.0
# category_name: Other goods
# categories_counter: 73
# indent: 3.0
# category_name: Recreation commodities
# categories_counter: 74
# indent: 3.0
# category_name: Shelter
# categories_counter: 75
# indent: 3.0
# category_name: Transportation commodities less motor fuel
# categories_counter: 76
# indent: 4.0
# category_name: Alcoholic beverages at home
# categories_counter: 77
# indent: 4.0
# category_name: Alcoholic beverages away from home
# categories_counter: 78
# indent: 4.0
# category_name: Appliances
# categories_counter: 79
# indent: 4.0
# category_name: Beverage materials including coffee and tea
# categories_counter: 80
# indent: 4.0
# category_name: Cereals and cereal products
# categories_counter: 81
# indent: 4.0
# category_name: Cheese and related products
# categories_counter: 82
# indent: 4.0
# category_name: Education and communication services
# categories_counter: 83
# indent: 4.0
# category_name: Educational books and supplies
# categories_counter: 84
# indent: 4.0
# category_name: Fats and oils
# categories_counter: 85
# indent: 4.0
# category_name: Footwear
# categories_counter: 86
# indent: 4.0
# category_name: Fresh fruits and vegetables
# categories_counter: 87
# indent: 4.0
# category_name: Fuel oil
# categories_counter: 88
# indent: 4.0
# category_name: Furniture and bedding
# categories_counter: 89
# indent: 4.0
# category_name: Gasoline all types
# categories_counter: 90
# indent: 4.0
# category_name: Housekeeping supplies
# categories_counter: 91
# indent: 4.0
# category_name: Ice cream and related products
# categories_counter: 92
# indent: 4.0
# category_name: Infants’ and toddlers’ apparel
# categories_counter: 93
# indent: 4.0
# category_name: Information technology commodities
# categories_counter: 94
# indent: 4.0
# category_name: Jewelry and watches
# categories_counter: 95
# indent: 4.0
# category_name: Juices and nonalcoholic drinks
# categories_counter: 96
# indent: 4.0
# category_name: Medical care services
# categories_counter: 97
# indent: 4.0
# category_name: Medical equipment and supplies
# categories_counter: 98
# indent: 4.0
# category_name: Medicinal drugs
# categories_counter: 99
# indent: 4.0
# category_name: Men’s and boys’ apparel
# categories_counter: 100
# indent: 4.0
# category_name: Milk
# categories_counter: 101
# indent: 4.0
# category_name: Miscellaneous personal goods
# categories_counter: 102
# indent: 4.0
# category_name: New vehicles
# categories_counter: 103
# indent: 4.0
# category_name: Other dairy and related products
# categories_counter: 104
# indent: 4.0
# category_name: Other household equipment and furnishings
# categories_counter: 105
# indent: 4.0
# category_name: Other motor fuels
# categories_counter: 106
# indent: 4.0
# category_name: Other personal services
# categories_counter: 107
# indent: 4.0
# category_name: Other recreational goods
# categories_counter: 108
# indent: 4.0
# category_name: Personal care products
# categories_counter: 109
# indent: 4.0
# category_name: Pets and pet products
# categories_counter: 110
# indent: 4.0
# category_name: Photographic equipment and supplies
# categories_counter: 111
# indent: 4.0
# category_name: Propane, kerosene, and firewood
# categories_counter: 112
# indent: 4.0
# category_name: Recreation services
# categories_counter: 113
# indent: 4.0
# category_name: Recreational reading materials
# categories_counter: 114
# indent: 4.0
# category_name: Rent of shelter
# categories_counter: 115
# indent: 4.0
# category_name: Sporting goods
# categories_counter: 116
# indent: 4.0
# category_name: Sugar and sweets
# categories_counter: 117
# indent: 4.0
# category_name: Tobacco and smoking products
# categories_counter: 118
# indent: 4.0
# category_name: Tools, hardware, outdoor equipment and supplies
# categories_counter: 119
# indent: 4.0
# category_name: Transportation services
# categories_counter: 120
# indent: 4.0
# category_name: Video and audio products
# categories_counter: 121
# indent: 4.0
# category_name: Water and sewer and trash collection services
# categories_counter: 122
# indent: 4.0
# category_name: Window and floor coverings and other linens
# categories_counter: 123
# indent: 4.0
# category_name: Women’s and girls’ apparel
# categories_counter: 124
# indent: 5.0
# category_name: Audio equipment
# categories_counter: 125
# indent: 5.0
# category_name: Bakery products
# categories_counter: 126
# indent: 5.0
# category_name: Bedroom furniture
# categories_counter: 127
# indent: 5.0
# category_name: Beer, ale, and other malt beverages at home
# categories_counter: 128
# indent: 5.0
# category_name: Beer, ale, and other malt beverages away from home
# categories_counter: 129
# indent: 5.0
# category_name: Boys’ and girls’ footwear
# categories_counter: 130
# indent: 5.0
# category_name: Boys’ apparel
# categories_counter: 131
# indent: 5.0
# category_name: Breakfast cereal
# categories_counter: 132
# indent: 5.0
# category_name: Butter and margarine
# categories_counter: 133
# indent: 5.0
# category_name: Candy and chewing gum
# categories_counter: 134
# indent: 5.0
# category_name: Car and truck rental
# categories_counter: 135
# category with 0 loss coef: Car and truck rental|1556.0
# indent: 5.0
# category_name: Carbonated drinks
# categories_counter: 136
# indent: 5.0
# category_name: Cigarettes
# categories_counter: 137
# indent: 5.0
# category_name: Clocks, lamps, and decorator items
# categories_counter: 138
# indent: 5.0
# category_name: Coffee
# categories_counter: 139
# indent: 5.0
# category_name: College textbooks
# categories_counter: 140
# indent: 5.0
# category_name: Computer software and accessories
# categories_counter: 141
# indent: 5.0
# category_name: Cosmetics, perfume, bath, nail preparations and implements
# categories_counter: 142
# indent: 5.0
# category_name: Dishes and flatware
# categories_counter: 143
# indent: 5.0
# category_name: Distilled spirits at home
# categories_counter: 144
# indent: 5.0
# category_name: Eggs
# categories_counter: 145
# category with 0 loss coef: Eggs|5556.0
# indent: 5.0
# category_name: Floor coverings
# categories_counter: 146
# indent: 5.0
# category_name: Flour and prepared flour mixes
# categories_counter: 147
# indent: 5.0
# category_name: Fresh fruits
# categories_counter: 148
# indent: 5.0
# category_name: Fresh milk other than whole
# categories_counter: 149
# indent: 5.0
# category_name: Fresh vegetables
# categories_counter: 150
# indent: 5.0
# category_name: Fresh whole milk
# categories_counter: 151
# indent: 5.0
# category_name: Frozen noncarbonated juices and drinks
# categories_counter: 152
# indent: 5.0
# category_name: Garbage and trash collection
# categories_counter: 153
# indent: 5.0
# category_name: Gasoline, unleaded midgrade
# categories_counter: 154
# category with 0 loss coef: Gasoline, unleaded midgrade|5687.0
# indent: 5.0
# category_name: Gasoline, unleaded premium
# categories_counter: 155
# category with 0 loss coef: Gasoline, unleaded premium|6324.0
# indent: 5.0
# category_name: Gasoline, unleaded regular
# categories_counter: 156
# category with 0 loss coef: Gasoline, unleaded regular|4879.0
# indent: 5.0
# category_name: Girls’ apparel
# categories_counter: 157
# indent: 5.0
# category_name: Hair, dental, shaving, and miscellaneous personal care products
# categories_counter: 158
# indent: 5.0
# category_name: Health insurance
# categories_counter: 159
# indent: 5.0
# category_name: Hospital and related services
# categories_counter: 160
# indent: 5.0
# category_name: Household cleaning products
# categories_counter: 161
# indent: 5.0
# category_name: Household paper products
# categories_counter: 162
# indent: 5.0
# category_name: Indoor plants and flowers
# categories_counter: 163
# indent: 5.0
# category_name: Internet services and electronic information providers
# categories_counter: 164
# indent: 5.0
# category_name: Jewelry
# categories_counter: 165
# indent: 5.0
# category_name: Living room, kitchen, and dining room furniture
# categories_counter: 166
# indent: 5.0
# category_name: Lodging away from home
# categories_counter: 167
# indent: 5.0
# category_name: Major appliances
# categories_counter: 168
# indent: 5.0
# category_name: Meats
# categories_counter: 169
# category with 0 loss coef: Meats|5354.0
# indent: 5.0
# category_name: Men’s apparel
# categories_counter: 170
# indent: 5.0
# category_name: Men’s footwear
# categories_counter: 171
# indent: 5.0
# category_name: Miscellaneous household products
# categories_counter: 172
# indent: 5.0
# category_name: Miscellaneous personal services
# categories_counter: 173
# indent: 5.0
# category_name: Motor vehicle fees
# categories_counter: 174
# indent: 5.0
# category_name: Motor vehicle insurance
# categories_counter: 175
# indent: 5.0
# category_name: Motor vehicle maintenance and repair
# categories_counter: 176
# indent: 5.0
# category_name: Moving, storage, freight expense
# categories_counter: 177
# category with 0 loss coef: Moving, storage, freight expense|133.0
# indent: 5.0
# category_name: Music instruments and accessories
# categories_counter: 178
# indent: 5.0
# category_name: New cars
# categories_counter: 179
# category with 0 loss coef: New cars|5782.0
# indent: 5.0
# category_name: New trucks
# categories_counter: 180
# category with 0 loss coef: New trucks|9870.0
# indent: 5.0
# category_name: Newspapers and magazines
# categories_counter: 181
# indent: 5.0
# category_name: Nonelectric cookware and tableware
# categories_counter: 182
# indent: 5.0
# category_name: Nonfrozen noncarbonated juices and drinks
# categories_counter: 183
# indent: 5.0
# category_name: Nonprescription drugs
# categories_counter: 184
# indent: 5.0
# category_name: Other appliances
# categories_counter: 185
# indent: 5.0
# category_name: Other beverage materials including tea
# categories_counter: 186
# indent: 5.0
# category_name: Other fats and oils including peanut butter
# categories_counter: 187
# indent: 5.0
# category_name: Other foods
# categories_counter: 188
# indent: 5.0
# category_name: Other furniture
# categories_counter: 189
# indent: 5.0
# category_name: Other linens
# categories_counter: 190
# indent: 5.0
# category_name: Other recreation services
# categories_counter: 191
# indent: 5.0
# category_name: Other sweets
# categories_counter: 192
# indent: 5.0
# category_name: Other video equipment
# categories_counter: 193
# indent: 5.0
# category_name: Outdoor equipment and supplies
# categories_counter: 194
# indent: 5.0
# category_name: Personal care services
# categories_counter: 195
# indent: 5.0
# category_name: Personal computers and peripheral equipment
# categories_counter: 196
# category with 0 loss coef: Personal computers and peripheral equipment|980.0
# indent: 5.0
# category_name: Pet food
# categories_counter: 197
# indent: 5.0
# category_name: Pet services including veterinary
# categories_counter: 198
# indent: 5.0
# category_name: Photographers and film processing
# categories_counter: 199
# indent: 5.0
# category_name: Photographic equipment
# categories_counter: 200
# indent: 5.0
# category_name: Postage and delivery services
# categories_counter: 201
# indent: 5.0
# category_name: Prescription drugs
# categories_counter: 202
# indent: 5.0
# category_name: Processed fruits and vegetables
# categories_counter: 203
# indent: 5.0
# category_name: Professional services
# categories_counter: 204
# indent: 5.0
# category_name: Public transportation
# categories_counter: 205
# indent: 5.0
# category_name: Purchase of pets, pet supplies, accessories
# categories_counter: 206
# indent: 5.0
# category_name: Recorded music and music subscriptions
# categories_counter: 207
# indent: 5.0
# category_name: Recreational books
# categories_counter: 208
# indent: 5.0
# category_name: Rent of primary residence
# categories_counter: 209
# indent: 5.0
# category_name: Rice, pasta, cornmeal
# categories_counter: 210
# indent: 5.0
# category_name: Salad dressing
# categories_counter: 211
# indent: 5.0
# category_name: Sewing machines, fabric and supplies
# categories_counter: 212
# indent: 5.0
# category_name: Sports equipment
# categories_counter: 213
# indent: 5.0
# category_name: Sports vehicles including bicycles
# categories_counter: 214
# indent: 5.0
# category_name: Stationery, stationery supplies, gift wrap
# categories_counter: 215
# indent: 5.0
# category_name: Sugar and artificial sweeteners
# categories_counter: 216
# indent: 5.0
# category_name: Telephone hardware, calculators, and other consumer information items
# categories_counter: 217
# indent: 5.0
# category_name: Telephone services
# categories_counter: 218
# indent: 5.0
# category_name: Televisions
# categories_counter: 219
# indent: 5.0
# category_name: Tenants’ and household insurance
# categories_counter: 220
# indent: 5.0
# category_name: Tires
# categories_counter: 221
# category with 0 loss coef: Tires|6900.0
# indent: 5.0
# category_name: Tobacco products other than cigarettes
# categories_counter: 222
# indent: 5.0
# category_name: Tools, hardware and supplies
# categories_counter: 223
# indent: 5.0
# category_name: Toys
# categories_counter: 224
# indent: 5.0
# category_name: Tuition, other school fees, and childcare
# categories_counter: 225
# indent: 5.0
# category_name: Vehicle accessories other than tires
# categories_counter: 226
# category with 0 loss coef: Vehicle accessories other than tires|1564.0
# indent: 5.0
# category_name: Video and audio services
# categories_counter: 227
# indent: 5.0
# category_name: Watches
# categories_counter: 228
# indent: 5.0
# category_name: Water and sewerage maintenance
# categories_counter: 229
# indent: 5.0
# category_name: Window coverings
# categories_counter: 230
# indent: 5.0
# category_name: Wine at home
# categories_counter: 231
# indent: 5.0
# category_name: Wine away from home
# categories_counter: 232
# indent: 5.0
# category_name: Women’s apparel
# categories_counter: 233
# indent: 5.0
# category_name: Women’s footwear
# categories_counter: 234
# indent: 6.0
# category_name: Admissions
# categories_counter: 235
# indent: 6.0
# category_name: Airline fare
# categories_counter: 236
# indent: 6.0
# category_name: Apparel services other than laundry and dry cleaning
# categories_counter: 237
# indent: 6.0
# category_name: Apples
# categories_counter: 238
# indent: 6.0
# category_name: Bananas
# categories_counter: 239
# indent: 6.0
# category_name: Beef and veal
# categories_counter: 240
# indent: 6.0
# category_name: Bread
# categories_counter: 241
# indent: 6.0
# category_name: Butter
# categories_counter: 242
# indent: 6.0
# category_name: Cakes, cupcakes, and cookies
# categories_counter: 243
# indent: 6.0
# category_name: Canned fruits and vegetables
# categories_counter: 244
# indent: 6.0
# category_name: Child care and nursery school
# categories_counter: 245
# indent: 6.0
# category_name: Citrus fruits
# categories_counter: 246
# indent: 6.0
# category_name: College tuition and fees
# categories_counter: 247
# indent: 6.0
# category_name: Delivery services
# categories_counter: 248
# indent: 6.0
# category_name: Dental services
# categories_counter: 249
# indent: 6.0
# category_name: Distilled spirits, excluding whiskey, at home
# categories_counter: 250
# indent: 6.0
# category_name: Elementary and high school tuition and fees
# categories_counter: 251
# indent: 6.0
# category_name: Eyeglasses and eye care
# categories_counter: 252
# indent: 6.0
# category_name: Financial services
# categories_counter: 253
# indent: 6.0
# category_name: Fish and seafood
# categories_counter: 254
# indent: 6.0
# category_name: Fresh biscuits, rolls, muffins
# categories_counter: 255
# indent: 6.0
# category_name: Frozen and freeze dried prepared foods
# categories_counter: 256
# indent: 6.0
# category_name: Frozen fruits and vegetables
# categories_counter: 257
# indent: 6.0
# category_name: Funeral expenses
# categories_counter: 258
# indent: 6.0
# category_name: Haircuts and other personal care services
# categories_counter: 259
# indent: 6.0
# category_name: Housing at school, excluding board
# categories_counter: 260
# indent: 6.0
# category_name: Instant and freeze dried coffee
# categories_counter: 261
# indent: 6.0
# category_name: Intracity transportation
# categories_counter: 262
# indent: 6.0
# category_name: Land-line telephone services
# categories_counter: 263
# indent: 6.0
# category_name: Laundry and dry cleaning services
# categories_counter: 264
# indent: 6.0
# category_name: Laundry equipment
# categories_counter: 265
# indent: 6.0
# category_name: Lettuce
# categories_counter: 266
# indent: 6.0
# category_name: Margarine
# categories_counter: 267
# indent: 6.0
# category_name: Men’s pants and shorts
# categories_counter: 268
# indent: 6.0
# category_name: Men’s shirts and sweaters
# categories_counter: 269
# indent: 6.0
# category_name: Men’s suits, sport coats, and outerwear
# categories_counter: 270
# indent: 6.0
# category_name: Motor oil, coolant, and fluids
# categories_counter: 271
# indent: 6.0
# category_name: Motor vehicle maintenance and servicing
# categories_counter: 272
# indent: 6.0
# category_name: Motor vehicle repair
# categories_counter: 273
# indent: 6.0
# category_name: Nursing homes and adult day services
# categories_counter: 274
# indent: 6.0
# category_name: Other bakery products
# categories_counter: 275
# indent: 6.0
# category_name: Other fresh fruits
# categories_counter: 276
# indent: 6.0
# category_name: Other fresh vegetables
# categories_counter: 277
# indent: 6.0
# category_name: Other intercity transportation
# categories_counter: 278
# indent: 6.0
# category_name: Other lodging away from home including hotels and motels
# categories_counter: 279
# indent: 6.0
# category_name: Other meats
# categories_counter: 280
# indent: 6.0
# category_name: Other miscellaneous foods
# categories_counter: 281
# indent: 6.0
# category_name: Other processed fruits and vegetables including dried
# categories_counter: 282
# indent: 6.0
# category_name: Owners’ equivalent rent of primary residence
# categories_counter: 283
# category with 0 loss coef: Owners’ equivalent rent of primary residence|2972.0
# indent: 6.0
# category_name: Parking and other fees
# categories_counter: 284
# indent: 6.0
# category_name: Physicians’ services
# categories_counter: 285
# indent: 6.0
# category_name: Pork
# categories_counter: 286
# indent: 6.0
# category_name: Postage
# categories_counter: 287
# indent: 6.0
# category_name: Potatoes
# categories_counter: 288
# indent: 6.0
# category_name: Poultry
# categories_counter: 289
# indent: 6.0
# category_name: Rice
# categories_counter: 290
# indent: 6.0
# category_name: Roasted coffee
# categories_counter: 291
# indent: 6.0
# category_name: Services by other medical professionals
# categories_counter: 292
# indent: 6.0
# category_name: Snacks
# categories_counter: 293
# indent: 6.0
# category_name: Soups
# categories_counter: 294
# indent: 6.0
# category_name: Spices, seasonings, condiments, sauces
# categories_counter: 295
# indent: 6.0
# category_name: State motor vehicle registration and license fees
# categories_counter: 296
# indent: 6.0
# category_name: Technical and business school tuition and fees
# categories_counter: 297
# indent: 6.0
# category_name: Tomatoes
# categories_counter: 298
# indent: 6.0
# category_name: Toys, games, hobbies and playground equipment
# categories_counter: 299
# indent: 6.0
# category_name: Vehicle parts and equipment other than tires
# categories_counter: 300
# indent: 6.0
# category_name: Veterinarian services
# categories_counter: 301
# indent: 6.0
# category_name: Whiskey at home
# categories_counter: 302
# indent: 6.0
# category_name: Wireless telephone services
# categories_counter: 303
# indent: 6.0
# category_name: Women’s dresses
# categories_counter: 304
# indent: 6.0
# category_name: Women’s outerwear
# categories_counter: 305
# indent: 6.0
# category_name: Women’s suits and separates
# categories_counter: 306
# indent: 6.0
# category_name: Women’s underwear, nightwear, sportswear and accessories
# categories_counter: 307
# indent: 7.0
# category_name: Admission to movies, theaters, and concerts
# categories_counter: 308
# indent: 7.0
# category_name: Bacon, breakfast sausage, and related products
# categories_counter: 309
# indent: 7.0
# category_name: Bread other than white
# categories_counter: 310
# indent: 7.0
# category_name: Canned fruits
# categories_counter: 311
# indent: 7.0
# category_name: Canned vegetables
# categories_counter: 312
# indent: 7.0
# category_name: Checking account and other bank services
# categories_counter: 313
# indent: 7.0
# category_name: Chicken
# categories_counter: 314
# indent: 7.0
# category_name: Cookies
# categories_counter: 315
# indent: 7.0
# category_name: Crackers, bread, and cracker products
# categories_counter: 316
# indent: 7.0
# category_name: Dried beans, peas, and lentils
# categories_counter: 317
# indent: 7.0
# category_name: Frankfurters
# categories_counter: 318
# indent: 7.0
# category_name: Fresh cakes and cupcakes
# categories_counter: 319
# indent: 7.0
# category_name: Fresh fish and seafood
# categories_counter: 320
# indent: 7.0
# category_name: Fresh sweetrolls, coffeecakes, doughnuts
# categories_counter: 321
# indent: 7.0
# category_name: Frozen and refrigerated bakery products, pies, tarts, turnovers
# categories_counter: 322
# indent: 7.0
# category_name: Frozen vegetables
# categories_counter: 323
# indent: 7.0
# category_name: Ham
# categories_counter: 324
# indent: 7.0
# category_name: Intracity mass transit
# categories_counter: 325
# indent: 7.0
# category_name: Lunchmeats
# categories_counter: 326
# indent: 7.0
# category_name: Oranges, including tangerines
# categories_counter: 327
# indent: 7.0
# category_name: Other condiments
# categories_counter: 328
# indent: 7.0
# category_name: Other pork including roasts and picnics
# categories_counter: 329
# indent: 7.0
# category_name: Other uncooked poultry including turkey
# categories_counter: 330
# indent: 7.0
# category_name: Parking fees and tolls
# categories_counter: 331
# indent: 7.0
# category_name: Pork chops
# categories_counter: 332
# indent: 7.0
# category_name: Prepared salads
# categories_counter: 333
# indent: 7.0
# category_name: Processed fish and seafood
# categories_counter: 334
# indent: 7.0
# category_name: Salt and other seasonings and spices
# categories_counter: 335
# indent: 7.0
# category_name: Sauces and gravies
# categories_counter: 336
# indent: 7.0
# category_name: Ship fare
# categories_counter: 337
# indent: 7.0
# category_name: Uncooked beef roasts
# categories_counter: 338
# indent: 7.0
# category_name: Uncooked beef steaks
# categories_counter: 339
# indent: 7.0
# category_name: Uncooked ground beef
# categories_counter: 340
# indent: 7.0
# category_name: Uncooked other beef and veal
# categories_counter: 341
# indent: 7.0
# category_name: Video discs and other media
# categories_counter: 342
# category with 0 loss coef: Video discs and other media|6541.0
# indent: 7.0
# category_name: White bread
# categories_counter: 343
# indent: 8.0
# category_name: Bacon and related products
# categories_counter: 344
# indent: 8.0
# category_name: Breakfast sausage and related products
# categories_counter: 345
# indent: 8.0
# category_name: Fresh and frozen chicken parts
# categories_counter: 346
# indent: 8.0
# category_name: Fresh whole chicken
# categories_counter: 347
# indent: 8.0
# category_name: Frozen fish and seafood
# categories_counter: 348
# indent: 8.0
# category_name: Ham, excluding canned
# categories_counter: 349
# indent: 8.0
# category_name: Shelf stable fish and seafood
# categories_counter: 350

# %% [markdown]
# Save prediction dict:

# %%
def get_results_on_test_set(weights_path, train_dataset_dict, test_dataset_dict, categories = None):
    predictions_dict = {}
    if categories is None:
        categories = list(test_dataset_dict.keys())
        
    for category in categories:
        print(category)
        train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category], test_dataset_dict[category])
        basic_model = Model
        basic_optimizer = Optimizer
        ckp_path = weights_path+category+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        predictions = get_predictions_on_test_set(model, test_dataloader)
        predictions_dict[category] = predictions
    return predictions_dict

# %%
categories_lists = list(categories_per_indent_dict.values())
categories_id = list(itertools.chain.from_iterable(categories_lists))
categories = []
for category_id in categories_id:
    categories.append(category_id_to_name_dict[category_id])
    
predictions_dict = get_results_on_test_set(weightspath, train_dataset_dict, test_dataset_dict, categories = categories)
# Out:
# Admission to movies, theaters, and concerts
# Bacon, breakfast sausage, and related products
# Bread other than white
# Canned fruits
# Canned vegetables
# Checking account and other bank services
# Chicken
# Cookies
# Crackers, bread, and cracker products
# Dried beans, peas, and lentils
# Frankfurters
# Fresh cakes and cupcakes
# Fresh fish and seafood
# Fresh sweetrolls, coffeecakes, doughnuts
# Frozen and refrigerated bakery products, pies, tarts, turnovers
# Frozen vegetables
# Ham
# Intracity mass transit
# Lunchmeats
# Oranges, including tangerines
# Other condiments
# Other pork including roasts and picnics
# Other uncooked poultry including turkey
# Parking fees and tolls
# Pork chops
# Prepared salads
# Processed fish and seafood
# Salt and other seasonings and spices
# Sauces and gravies
# Ship fare
# Uncooked beef roasts
# Uncooked beef steaks
# Uncooked ground beef
# Uncooked other beef and veal
# Video discs and other media
# White bread
# Admissions
# Airline fare
# Apparel services other than laundry and dry cleaning
# Apples
# Bananas
# Beef and veal
# Bread
# Butter
# Cakes, cupcakes, and cookies
# Canned fruits and vegetables
# Child care and nursery school
# Citrus fruits
# College tuition and fees
# Delivery services
# Dental services
# Distilled spirits, excluding whiskey, at home
# Elementary and high school tuition and fees
# Eyeglasses and eye care
# Financial services
# Fish and seafood
# Fresh biscuits, rolls, muffins
# Frozen and freeze dried prepared foods
# Frozen fruits and vegetables
# Funeral expenses
# Haircuts and other personal care services
# Housing at school, excluding board
# Instant and freeze dried coffee
# Intracity transportation
# Land-line telephone services
# Laundry and dry cleaning services
# Laundry equipment
# Lettuce
# Margarine
# Men’s pants and shorts
# Men’s shirts and sweaters
# Men’s suits, sport coats, and outerwear
# Motor oil, coolant, and fluids
# Motor vehicle maintenance and servicing
# Motor vehicle repair
# Nursing homes and adult day services
# Other bakery products
# Other fresh fruits
# Other fresh vegetables
# Other intercity transportation
# Other lodging away from home including hotels and motels
# Other meats
# Other miscellaneous foods
# Other processed fruits and vegetables including dried
# Owners’ equivalent rent of primary residence
# Parking and other fees
# Physicians’ services
# Pork
# Postage
# Potatoes
# Poultry
# Rice
# Roasted coffee
# Services by other medical professionals
# Snacks
# Soups
# Spices, seasonings, condiments, sauces
# State motor vehicle registration and license fees
# Technical and business school tuition and fees
# Tomatoes
# Toys, games, hobbies and playground equipment
# Vehicle parts and equipment other than tires
# Veterinarian services
# Whiskey at home
# Wireless telephone services
# Women’s dresses
# Women’s outerwear
# Women’s suits and separates
# Women’s underwear, nightwear, sportswear and accessories
# Alcoholic beverages
# Apparel
# Cereals and bakery products
# Dairy and related products
# Education and communication commodities
# Electricity
# Food from vending machines and mobile vendors
# Fruits and vegetables
# Fuel oil and other fuels
# Full service meals and snacks
# Household furnishings and supplies
# Information and information processing
# Information technology, hardware and services
# Limited service meals and snacks
# Meats, poultry, fish, and eggs
# Medical care commodities
# Motor fuel
# New and used motor vehicles
# Nonalcoholic beverages and beverage materials
# Other food at home
# Other food away from home
# Other goods
# Recreation commodities
# Shelter
# Transportation commodities less motor fuel
# Alcoholic beverages at home
# Alcoholic beverages away from home
# Appliances
# Beverage materials including coffee and tea
# Cereals and cereal products
# Cheese and related products
# Education and communication services
# Educational books and supplies
# Fats and oils
# Footwear
# Fresh fruits and vegetables
# Fuel oil
# Furniture and bedding
# Gasoline all types
# Housekeeping supplies
# Ice cream and related products
# Infants’ and toddlers’ apparel
# Information technology commodities
# Jewelry and watches
# Juices and nonalcoholic drinks
# Medical care services
# Medical equipment and supplies
# Medicinal drugs
# Men’s and boys’ apparel
# Milk
# Miscellaneous personal goods
# New vehicles
# Other dairy and related products
# Other household equipment and furnishings
# Other motor fuels
# Other personal services
# Other recreational goods
# Personal care products
# Pets and pet products
# Photographic equipment and supplies
# Propane, kerosene, and firewood
# Recreation services
# Recreational reading materials
# Rent of shelter
# Sporting goods
# Sugar and sweets
# Tobacco and smoking products
# Tools, hardware, outdoor equipment and supplies
# Transportation services
# Video and audio products
# Water and sewer and trash collection services
# Window and floor coverings and other linens
# Women’s and girls’ apparel
# All items
# All items less energy
# All items less food
# All items less food and energy
# All items less food and shelter
# All items less food, shelter, and energy
# All items less food, shelter, energy, and used cars and trucks
# All items less medical care
# All items less shelter
# Apparel less footwear
# Commodities
# Durables
# Education and communication
# Energy
# Food
# Food and beverages
# Fuels and utilities
# Household furnishings and operations
# Housing
# Medical care
# Nondurables
# Other goods and services
# Other services
# Recreation
# Services
# Transportation
# Utilities and public transportation
# Audio equipment
# Bakery products
# Bedroom furniture
# Beer, ale, and other malt beverages at home
# Beer, ale, and other malt beverages away from home
# Boys’ and girls’ footwear
# Boys’ apparel
# Breakfast cereal
# Butter and margarine
# Candy and chewing gum
# Car and truck rental
# Carbonated drinks
# Cigarettes
# Clocks, lamps, and decorator items
# Coffee
# College textbooks
# Computer software and accessories
# Cosmetics, perfume, bath, nail preparations and implements
# Dishes and flatware
# Distilled spirits at home
# Eggs
# Floor coverings
# Flour and prepared flour mixes
# Fresh fruits
# Fresh milk other than whole
# Fresh vegetables
# Fresh whole milk
# Frozen noncarbonated juices and drinks
# Garbage and trash collection
# Gasoline, unleaded midgrade
# Gasoline, unleaded premium
# Gasoline, unleaded regular
# Girls’ apparel
# Hair, dental, shaving, and miscellaneous personal care products
# Health insurance
# Hospital and related services
# Household cleaning products
# Household paper products
# Indoor plants and flowers
# Internet services and electronic information providers
# Jewelry
# Living room, kitchen, and dining room furniture
# Lodging away from home
# Major appliances
# Meats
# Men’s apparel
# Men’s footwear
# Miscellaneous household products
# Miscellaneous personal services
# Motor vehicle fees
# Motor vehicle insurance
# Motor vehicle maintenance and repair
# Moving, storage, freight expense
# Music instruments and accessories
# New cars
# New trucks
# Newspapers and magazines
# Nonelectric cookware and tableware
# Nonfrozen noncarbonated juices and drinks
# Nonprescription drugs
# Other appliances
# Other beverage materials including tea
# Other fats and oils including peanut butter
# Other foods
# Other furniture
# Other linens
# Other recreation services
# Other sweets
# Other video equipment
# Outdoor equipment and supplies
# Personal care services
# Personal computers and peripheral equipment
# Pet food
# Pet services including veterinary
# Photographers and film processing
# Photographic equipment
# Postage and delivery services
# Prescription drugs
# Processed fruits and vegetables
# Professional services
# Public transportation
# Purchase of pets, pet supplies, accessories
# Recorded music and music subscriptions
# Recreational books
# Rent of primary residence
# Rice, pasta, cornmeal
# Salad dressing
# Sewing machines, fabric and supplies
# Sports equipment
# Sports vehicles including bicycles
# Stationery, stationery supplies, gift wrap
# Sugar and artificial sweeteners
# Telephone hardware, calculators, and other consumer information items
# Telephone services
# Televisions
# Tenants’ and household insurance
# Tires
# Tobacco products other than cigarettes
# Tools, hardware and supplies
# Toys
# Tuition, other school fees, and childcare
# Vehicle accessories other than tires
# Video and audio services
# Watches
# Water and sewerage maintenance
# Window coverings
# Wine at home
# Wine away from home
# Women’s apparel
# Women’s footwear
# Bacon and related products
# Breakfast sausage and related products
# Fresh and frozen chicken parts
# Fresh whole chicken
# Frozen fish and seafood
# Ham, excluding canned
# Shelf stable fish and seafood
# Commodities less food
# Commodities less food and beverages
# Commodities less food and energy commodities
# Commodities less food, energy, and used cars and trucks
# Communication
# Domestically produced farm food
# Education
# Energy commodities
# Energy services
# Food at home
# Food away from home
# Household energy
# Nondurables less food
# Nondurables less food and apparel
# Nondurables less food and beverages
# Nondurables less food, beverages, and apparel
# Personal care
# Pets, pet products and services
# Photography
# Private transportation
# Services less energy services
# Services less medical care services
# Services less rent of shelter
# Video and audio

# %%
with open(test_predictions_path, 'wb') as handle:
    pickle.dump(predictions_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Save model weights in dict for bi-directional use:

# %%
categories_lists = list(categories_per_indent_dict.values())
categories_id = list(itertools.chain.from_iterable(categories_lists))
categories = []
for category_id in categories_id:
    categories.append(category_id_to_name_dict[category_id])

category_id_list = []
 
# list out keys and values separately
key_list = list(category_id_to_name_dict.keys())
val_list = list(category_id_to_name_dict.values())

for cat_name in categories:
    position = val_list.index(cat_name)
    category_id_list.append(key_list[position])

# %%
def get_weights_per_category(category_id_list, dir_path):
    basic_model = GRUModel(input_dim = Features, hidden_dim = HiddenSize, layer_dim = LayersDim, output_dim = OutputDim, dropout_prob = DropoutProb)
    basic_optimizer = torch.optim.AdamW(basic_model.parameters(), lr=Lr)
    #basic_model.to(device)

    best_models_weights_dict = {}

    for category_id in category_id_list:
        category_name = category_id_to_name_dict[category_id]
        ckp_path = dir_path+category_name+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        category_model_weights = unify_model_weights(model)
        best_models_weights_dict[category_id] = category_model_weights
        
    return best_models_weights_dict

# %%
dir_path = '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/hgru/models_weights/'

# %%
category_id_list = []
 
# list out keys and values separately
key_list = list(category_id_to_name_dict.keys())
val_list = list(category_id_to_name_dict.values())

for cat_name in categories:
    position = val_list.index(cat_name)
    category_id_list.append(key_list[position])

# %%
len(categories)
# Out:
# 350

# %%
weights_dict = get_weights_per_category(category_id_list, dir_path)

# %%
with open(hgru_model_weights_path, 'wb') as handle:
    pickle.dump(weights_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
Lr
# Out:
# 0.01
