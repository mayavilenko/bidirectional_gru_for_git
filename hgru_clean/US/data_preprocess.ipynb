# %%
import pickle
from preprocess_config import *

# %% [markdown]
# # Read and Process Data:

# %%
with open(dataset_dict_path, 'rb') as f:
    raw_dataset_dict = pickle.load(f)

# %%
raw_dataset_dict['All items']
# Out:
#        Category_id   Category  Year        Date    Price  Inflation t-12  \
# 53849       8106.0  All items  1984  1984-01-15  101.900             NaN
# 53850       8106.0  All items  1984  1984-02-15  102.400        0.489477
# 53851       8106.0  All items  1984  1984-03-15  102.600        0.195122
# 53852       8106.0  All items  1984  1984-04-15  103.100        0.486146
# 53853       8106.0  All items  1984  1984-05-15  103.400        0.290557
# ...            ...        ...   ...         ...      ...             ...
# 54321       8106.0  All items  2023  2023-05-15  303.294        0.124049
# 54322       8106.0  All items  2023  2023-06-15  303.841        0.180191
# 54323       8106.0  All items  2023  2023-07-15  304.348        0.166725
# 54324       8106.0  All items  2023  2023-08-15  306.269        0.629202
# 54325       8106.0  All items  2023  2023-09-15  307.481        0.394950
#
#        Inflation t-11  Inflation t-10  Inflation t-9  Inflation t-8  ...  \
# 53849             NaN             NaN            NaN            NaN  ...
# 53850             NaN             NaN            NaN            NaN  ...
# 53851        0.489477             NaN            NaN            NaN  ...
# 53852        0.195122        0.489477            NaN            NaN  ...
# 53853        0.486146        0.195122       0.489477            NaN  ...
# ...               ...             ...            ...            ...  ...
# 54321        0.367109        0.053028       0.369323       0.809829  ...
# 54322        0.124049        0.367109       0.053028       0.369323  ...
# 54323        0.180191        0.124049       0.367109       0.053028  ...
# 54324        0.166725        0.180191       0.124049       0.367109  ...
# 54325        0.629202        0.166725       0.180191       0.124049  ...
#
#        Inflation t-4  Inflation t-3  Inflation t-2  Inflation t-1  \
# 53849            NaN            NaN            NaN            NaN
# 53850            NaN            NaN            NaN            NaN
# 53851            NaN            NaN            NaN            NaN
# 53852            NaN            NaN            NaN            NaN
# 53853            NaN            NaN            NaN            NaN
# ...              ...            ...            ...            ...
# 54321       0.385226       0.118127      -0.019302       1.313580
# 54322       0.437442       0.385226       0.118127      -0.019302
# 54323       0.096242       0.437442       0.385226       0.118127
# 54324      -0.079469       0.096242       0.437442       0.385226
# 54325       0.809829      -0.079469       0.096242       0.437442
#
#        Inflation t  Inflation t+1  Indent  Weight  Parent  Parent_ID
# 53849          NaN       0.489477     0.0   100.0     NaN        NaN
# 53850          NaN       0.195122     0.0   100.0     NaN        NaN
# 53851          NaN       0.486146     0.0   100.0     NaN        NaN
# 53852          NaN       0.290557     0.0   100.0     NaN        NaN
# 53853          NaN       0.289715     0.0   100.0     NaN        NaN
# ...            ...            ...     ...     ...     ...        ...
# 54321     0.969089       0.180191     0.0   100.0     NaN        NaN
# 54322     1.313580       0.166725     0.0   100.0     NaN        NaN
# 54323    -0.019302       0.629202     0.0   100.0     NaN        NaN
# 54324     0.118127       0.394950     0.0   100.0     NaN        NaN
# 54325     0.385226            NaN     0.0   100.0     NaN        NaN
#
# [477 rows x 23 columns]

# %%
def train_test_split(dic: dict, year: int) -> dict:
    train = {}
    test = {}
    for key in dic.keys():
        category_df = dic[key]
        train[key] = category_df[category_df['Year'] <= year]
        test[key] = category_df[category_df['Year'] > year]
    return train, test

raw_train_data_dict, raw_test_data_dict = train_test_split(raw_dataset_dict, year=Year)

# %%
def get_relevant_features(dic: dict, drop_columns: list) -> dict:
    processed_dict = dic.copy()
    for key in list(processed_dict.keys()):
        processed_dict[key] = processed_dict[key].drop(columns=drop_columns)
        processed_dict[key].dropna(inplace=True)
    return processed_dict

drop_columns = ['Category_id', 'Category', 'Year', 'Date', 'Price', 'Indent', 'Weight', 'Parent', 'Parent_ID']

train_data_dict = get_relevant_features(raw_train_data_dict, drop_columns)

test_data_dict = get_relevant_features(raw_test_data_dict, drop_columns)

# %%
def get_coefficients(dic: dict) -> dict:
    weight_dict = {}
    for key in list(dic.keys()):
        max_dt = dic[key].Date.max()
        cat_weight = dic[key][dic[key]['Date']==max_dt].Weight.values[0]
        weight_dict[key] = cat_weight
    return weight_dict

weight_dict = get_coefficients(raw_train_data_dict)

# %% [markdown]
# # Sanity Tests:

# %%
train_data_dict['All items']
# Out:
#        Inflation t-12  Inflation t-11  Inflation t-10  Inflation t-9  \
# 53862        0.472814        0.189753        0.000000       0.000000
# 53863        0.376648        0.472814        0.189753       0.000000
# 53864        0.468824        0.376648        0.472814       0.189753
# 53865        0.373483        0.468824        0.376648       0.472814
# 53866        0.279200        0.373483        0.468824       0.376648
# ...               ...             ...             ...            ...
# 54288        0.369596        0.584957        0.563764      -0.052378
# 54289        0.203120        0.369596        0.584957       0.563764
# 54290        0.044570        0.203120        0.369596       0.584957
# 54291        0.188816        0.044570        0.203120       0.369596
# 54292        0.366634        0.188816        0.044570       0.203120
#
#        Inflation t-8  Inflation t-7  Inflation t-6  Inflation t-5  \
# 53862       0.285307       0.477328       0.383510       0.384986
# 53863       0.000000       0.285307       0.477328       0.383510
# 53864       0.000000       0.000000       0.285307       0.477328
# 53865       0.189753       0.000000       0.000000       0.285307
# 53866       0.472814       0.189753       0.000000       0.000000
# ...              ...            ...            ...            ...
# 54288      -0.798284      -0.424370       0.088825       0.123328
# 54289      -0.052378      -0.798284      -0.424370       0.088825
# 54290       0.563764      -0.052378      -0.798284      -0.424370
# 54291       0.584957       0.563764      -0.052378      -0.798284
# 54292       0.369596       0.584957       0.563764      -0.052378
#
#        Inflation t-4  Inflation t-3  Inflation t-2  Inflation t-1  \
# 53862       0.289715       0.290557       0.486146       0.195122
# 53863       0.384986       0.289715       0.290557       0.486146
# 53864       0.383510       0.384986       0.289715       0.290557
# 53865       0.477328       0.383510       0.384986       0.289715
# 53866       0.285307       0.477328       0.383510       0.384986
# ...              ...            ...            ...            ...
# 54288       0.218807       0.258149       0.355510       0.022627
# 54289       0.123328       0.218807       0.258149       0.355510
# 54290       0.088825       0.123328       0.218807       0.258149
# 54291      -0.424370       0.088825       0.123328       0.218807
# 54292      -0.798284      -0.424370       0.088825       0.123328
#
#        Inflation t  Inflation t+1
# 53862     0.489477       0.376648
# 53863     0.195122       0.468824
# 53864     0.486146       0.373483
# 53865     0.290557       0.279200
# 53866     0.289715       0.185701
# ...            ...            ...
# 54288     0.054248       0.203120
# 54289     0.022627       0.044570
# 54290     0.355510       0.188816
# 54291     0.258149       0.366634
# 54292     0.218807       0.174044
#
# [431 rows x 14 columns]

# %%
weight_dict
# Out:
# {'Admission to movies, theaters, and concerts': 0.331,
#  'Admissions': 0.647,
#  'Airline fare': 0.684,
#  'Alcoholic beverages': 0.972,
#  'Alcoholic beverages at home': 0.607,
#  'Alcoholic beverages away from home': 0.365,
#  'All items': 100.0,
#  'All items less energy': 92.81,
#  'All items less food': 86.636,
#  'All items less food and energy': 79.446,
#  'All items less food and shelter': 53.343,
#  'All items less food, shelter, and energy': 46.153,
#  'All items less food, shelter, energy, and used cars and trucks': 43.756,
#  'All items less medical care': 91.304,
#  'All items less shelter': 66.707,
#  'Apparel': 3.065,
#  'Apparel less footwear': 2.392,
#  'Apparel services other than laundry and dry cleaning': 0.029,
#  'Apples': 0.076,
#  'Appliances': 0.219,
#  'Audio equipment': 0.044,
#  'Bacon and related products': 0.065,
#  'Bacon, breakfast sausage, and related products': 0.132,
#  'Bakery products': 0.654,
#  'Bananas': 0.079,
#  'Bedroom furniture': 0.324,
#  'Beef and veal': 0.426,
#  'Beer, ale, and other malt beverages at home': 0.27,
#  'Beer, ale, and other malt beverages away from home': 0.122666666666667,
#  'Beverage materials including coffee and tea': 0.251,
#  'Boys’ and girls’ footwear': 0.162,
#  'Boys’ apparel': 0.181,
#  'Bread': 0.193,
#  'Bread other than white': 0.097,
#  'Breakfast cereal': 0.149,
#  'Breakfast sausage and related products': 0.065,
#  'Butter': 0.03,
#  'Butter and margarine': 0.061,
#  'Cakes, cupcakes, and cookies': 0.164,
#  'Candy and chewing gum': 0.184,
#  'Canned fruits': 0.073,
#  'Canned fruits and vegetables': 0.151,
#  'Canned vegetables': 0.073,
#  'Car and truck rental': 0.108,
#  'Carbonated drinks': 0.267,
#  'Cereals and bakery products': 0.962,
#  'Cereals and cereal products': 0.308,
#  'Checking account and other bank services': 0.1205,
#  'Cheese and related products': 0.232,
#  'Chicken': 0.258,
#  'Child care and nursery school': 0.808,
#  'Cigarettes': 0.585,
#  'Citrus fruits': 0.149,
#  'Clocks, lamps, and decorator items': 0.28,
#  'Coffee': 0.161,
#  'College textbooks': 0.131,
#  'College tuition and fees': 1.615,
#  'Commodities': 36.817,
#  'Commodities less food': 23.453,
#  'Commodities less food and beverages': 22.48,
#  'Commodities less food and energy commodities': 19.624,
#  'Commodities less food, energy, and used cars and trucks': 17.227,
#  'Communication': 3.524,
#  'Computer software and accessories': 0.024,
#  'Cookies': 0.0825,
#  'Cosmetics, perfume, bath, nail preparations and implements': 0.298,
#  'Crackers, bread, and cracker products': 0.067333333333333,
#  'Dairy and related products': 0.724,
#  'Delivery services': 0.014,
#  'Dental services': 0.79,
#  'Dishes and flatware': 0.052,
#  'Distilled spirits at home': 0.082,
#  'Distilled spirits, excluding whiskey, at home': 0.0405,
#  'Domestically produced farm food': 6.089,
#  'Dried beans, peas, and lentils': 0.044,
#  'Durables': 9.975,
#  'Education': 3.041,
#  'Education and communication': 6.565,
#  'Education and communication commodities': 0.527,
#  'Education and communication services': 6.038,
#  'Educational books and supplies': 0.13,
#  'Eggs': 0.092,
#  'Electricity': 2.594,
#  'Elementary and high school tuition and fees': 0.336,
#  'Energy': 7.19,
#  'Energy commodities': 3.829,
#  'Energy services': 3.361,
#  'Eyeglasses and eye care': 0.317,
#  'Fats and oils': 0.214,
#  'Financial services': 0.244,
#  'Fish and seafood': 0.252,
#  'Floor coverings': 0.055,
#  'Flour and prepared flour mixes': 0.04,
#  'Food': 13.364,
#  'Food and beverages': 14.337,
#  'Food at home': 7.304,
#  'Food away from home': 6.06,
#  'Food from vending machines and mobile vendors': 0.092,
#  'Footwear': 0.674,
#  'Frankfurters': 0.05525,
#  'Fresh and frozen chicken parts': 0.1295,
#  'Fresh biscuits, rolls, muffins': 0.092,
#  'Fresh cakes and cupcakes': 0.0825,
#  'Fresh fish and seafood': 0.13,
#  'Fresh fruits': 0.543,
#  'Fresh fruits and vegetables': 1.034,
#  'Fresh milk other than whole': 0.1005,
#  'Fresh sweetrolls, coffeecakes, doughnuts': 0.067333333333333,
#  'Fresh vegetables': 0.491,
#  'Fresh whole chicken': 0.1295,
#  'Fresh whole milk': 0.1005,
#  'Frozen and freeze dried prepared foods': 0.234,
#  'Frozen and refrigerated bakery products, pies, tarts, turnovers': 0.067333333333333,
#  'Frozen fish and seafood': 0.0615,
#  'Frozen fruits and vegetables': 0.077,
#  'Frozen noncarbonated juices and drinks': 0.009,
#  'Frozen vegetables': 0.077,
#  'Fruits and vegetables': 1.305,
#  'Fuel oil': 0.113,
#  'Fuel oil and other fuels': 0.188,
#  'Fuels and utilities': 4.643,
#  'Full service meals and snacks': 3.009,
#  'Funeral expenses': 0.128,
#  'Furniture and bedding': 0.895,
#  'Garbage and trash collection': 0.268,
#  'Gasoline all types': 2.721,
#  'Gasoline, unleaded midgrade': 1.22366666666667,
#  'Gasoline, unleaded premium': 1.22366666666667,
#  'Gasoline, unleaded regular': 1.22366666666667,
#  'Girls’ apparel': 0.181,
#  'Hair, dental, shaving, and miscellaneous personal care products': 0.38,
#  'Haircuts and other personal care services': 0.632,
#  'Ham': 0.05,
#  'Ham, excluding canned': 0.051,
#  'Health insurance': 1.124,
#  'Hospital and related services': 2.617,
#  'Household cleaning products': 0.331,
#  'Household energy': 3.549,
#  'Household furnishings and operations': 4.282,
#  'Household furnishings and supplies': 3.394,
#  'Household paper products': 0.222,
#  'Housekeeping supplies': 0.839,
#  'Housing': 42.217,
#  'Housing at school, excluding board': 0.114,
#  'Ice cream and related products': 0.107,
#  'Indoor plants and flowers': 0.094,
#  'Infants’ and toddlers’ apparel': 0.138,
#  'Information and information processing': 3.411,
#  'Information technology commodities': 0.397,
#  'Information technology, hardware and services': 1.192,
#  'Instant and freeze dried coffee': 0.0805,
#  'Internet services and electronic information providers': 0.786,
#  'Intracity mass transit': 0.278,
#  'Intracity transportation': 0.278,
#  'Jewelry': 0.151,
#  'Jewelry and watches': 0.243,
#  'Juices and nonalcoholic drinks': 0.633,
#  'Land-line telephone services': 0.573,
#  'Laundry and dry cleaning services': 0.241,
#  'Laundry equipment': 0.081,
#  'Lettuce': 0.065,
#  'Limited service meals and snacks': 2.581,
#  'Living room, kitchen, and dining room furniture': 0.433,
#  'Lodging away from home': 0.962,
#  'Lunchmeats': 0.05525,
#  'Major appliances': 0.081,
#  'Margarine': 0.03,
#  'Meats': 0.937,
#  'Meats, poultry, fish, and eggs': 1.504,
#  'Medical care': 8.696,
#  'Medical care commodities': 1.696,
#  'Medical care services': 7.0,
#  'Medical equipment and supplies': 0.057,
#  'Medicinal drugs': 1.638,
#  'Men’s and boys’ apparel': 0.784,
#  'Men’s apparel': 0.603,
#  'Men’s footwear': 0.219,
#  'Men’s pants and shorts': 0.156,
#  'Men’s shirts and sweaters': 0.175,
#  'Men’s suits, sport coats, and outerwear': 0.112,
#  'Milk': 0.2,
#  'Miscellaneous household products': 0.286,
#  'Miscellaneous personal goods': 0.208,
#  'Miscellaneous personal services': 1.022,
#  'Motor fuel': 3.641,
#  'Motor oil, coolant, and fluids': 0.078,
#  'Motor vehicle fees': 0.545,
#  'Motor vehicle insurance': 2.407,
#  'Motor vehicle maintenance and repair': 1.13,
#  'Motor vehicle maintenance and servicing': 0.638,
#  'Motor vehicle repair': 0.371,
#  'Moving, storage, freight expense': 0.102,
#  'Music instruments and accessories': 0.035,
#  'New and used motor vehicles': 6.987,
#  'New cars': 1.862,
#  'New trucks': 1.862,
#  'New vehicles': 3.729,
#  'Newspapers and magazines': 0.07,
#  'Nonalcoholic beverages and beverage materials': 0.884,
#  'Nondurables': 26.842,
#  'Nondurables less food': 13.477,
#  'Nondurables less food and apparel': 10.412,
#  'Nondurables less food and beverages': 12.505,
#  'Nondurables less food, beverages, and apparel': 9.44,
#  'Nonelectric cookware and tableware': 0.081,
#  'Nonfrozen noncarbonated juices and drinks': 0.358,
#  'Nonprescription drugs': 0.337,
#  'Nursing homes and adult day services': 0.195,
#  'Oranges, including tangerines': 0.155,
#  'Other appliances': 0.134,
#  'Other bakery products': 0.205,
#  'Other beverage materials including tea': 0.09,
#  'Other condiments': 0.067,
#  'Other dairy and related products': 0.186,
#  'Other fats and oils including peanut butter': 0.101,
#  'Other food at home': 1.833,
#  'Other food away from home': 0.197,
#  'Other foods': 1.34,
#  'Other fresh fruits': 0.238,
#  'Other fresh vegetables': 0.267,
#  'Other furniture': 0.128,
#  'Other goods': 1.553,
#  'Other goods and services': 3.207,
#  'Other household equipment and furnishings': 0.507,
#  'Other intercity transportation': 0.164,
#  'Other linens': 0.156,
#  'Other lodging away from home including hotels and motels': 0.848,
#  'Other meats': 0.221,
#  'Other miscellaneous foods': 0.393,
#  'Other motor fuels': 0.085,
#  'Other personal services': 1.654,
#  'Other pork including roasts and picnics': 0.065,
#  'Other processed fruits and vegetables including dried': 0.043,
#  'Other recreation services': 1.827,
#  'Other recreational goods': 0.326,
#  'Other services': 11.584,
#  'Other sweets': 0.054,
#  'Other uncooked poultry including turkey': 0.057,
#  'Other video equipment': 0.027,
#  'Outdoor equipment and supplies': 0.313,
#  'Owners’ equivalent rent of primary residence': 22.685,
#  'Parking and other fees': 0.247,
#  'Parking fees and tolls': 0.1225,
#  'Personal care': 2.547,
#  'Personal care products': 0.684,
#  'Personal care services': 0.632,
#  'Personal computers and peripheral equipment': 0.304,
#  'Pet food': 0.3025,
#  'Pet services including veterinary': 0.42,
#  'Pets and pet products': 0.608,
#  'Pets, pet products and services': 1.027,
#  'Photographers and film processing': 0.038,
#  'Photographic equipment': 0.0165,
#  'Photographic equipment and supplies': 0.032,
#  'Photography': 0.072,
#  'Physicians’ services': 1.735,
#  'Pork': 0.29,
#  'Pork chops': 0.043,
#  'Postage': 0.099,
#  'Postage and delivery services': 0.113,
#  'Potatoes': 0.079,
#  'Poultry': 0.315,
#  'Prepared salads': 0.401,
#  'Prescription drugs': 1.302,
#  'Private transportation': 15.091,
#  'Processed fish and seafood': 0.122,
#  'Processed fruits and vegetables': 0.271,
#  'Professional services': 3.259,
#  'Propane, kerosene, and firewood': 0.075,
#  'Public transportation': 1.133,
#  'Purchase of pets, pet supplies, accessories': 0.3025,
#  'Recorded music and music subscriptions': 0.047,
#  'Recreation': 5.688,
#  'Recreation commodities': 1.796,
#  'Recreation services': 3.892,
#  'Recreational books': 0.045,
#  'Recreational reading materials': 0.115,
#  'Rent of primary residence': 7.932,
#  'Rent of shelter': 32.919,
#  'Rice': 0.119,
#  'Rice, pasta, cornmeal': 0.118,
#  'Roasted coffee': 0.0805,
#  'Salad dressing': 0.052,
#  'Salt and other seasonings and spices': 0.067,
#  'Sauces and gravies': 0.067,
#  'Services': 63.183,
#  'Services by other medical professionals': 0.416,
#  'Services less energy services': 59.822,
#  'Services less medical care services': 56.183,
#  'Services less rent of shelter': 30.264,
#  'Sewing machines, fabric and supplies': 0.025,
#  'Shelf stable fish and seafood': 0.0615,
#  'Shelter': 33.293,
#  'Ship fare': 0.055666666666667,
#  'Snacks': 0.31,
#  'Soups': 0.081,
#  'Spices, seasonings, condiments, sauces': 0.272,
#  'Sporting goods': 0.493,
#  'Sports equipment': 0.2,
#  'Sports vehicles including bicycles': 0.286,
#  'State motor vehicle registration and license fees': 0.28,
#  'Stationery, stationery supplies, gift wrap': 0.0995,
#  'Sugar and artificial sweeteners': 0.042,
#  'Sugar and sweets': 0.279,
#  'Technical and business school tuition and fees': 0.032,
#  'Telephone hardware, calculators, and other consumer information items': 0.07,
#  'Telephone services': 2.219,
#  'Televisions': 0.096,
#  'Tenants’ and household insurance': 0.373,
#  'Tires': 0.227,
#  'Tobacco and smoking products': 0.66,
#  'Tobacco products other than cigarettes': 0.06,
#  'Tomatoes': 0.08,
#  'Tools, hardware and supplies': 0.2,
#  'Tools, hardware, outdoor equipment and supplies': 0.676,
#  'Toys': 0.255,
#  'Toys, games, hobbies and playground equipment': 0.252,
#  'Transportation': 16.224,
#  'Transportation commodities less motor fuel': 6.621,
#  'Transportation services': 5.962,
#  'Tuition, other school fees, and childcare': 2.911,
#  'Uncooked beef roasts': 0.061,
#  'Uncooked beef steaks': 0.158,
#  'Uncooked ground beef': 0.17,
#  'Uncooked other beef and veal': 0.037,
#  'Utilities and public transportation': 9.322,
#  'Vehicle accessories other than tires': 0.155,
#  'Vehicle parts and equipment other than tires': 0.078,
#  'Veterinarian services': 0.2085,
#  'Video and audio': 1.827,
#  'Video and audio products': 0.222,
#  'Video and audio services': 1.605,
#  'Video discs and other media': 0.043,
#  'Watches': 0.092,
#  'Water and sewer and trash collection services': 1.094,
#  'Water and sewerage maintenance': 0.826,
#  'Whiskey at home': 0.0405,
#  'White bread': 0.097,
#  'Window and floor coverings and other linens': 0.257,
#  'Window coverings': 0.046,
#  'Wine at home': 0.255,
#  'Wine away from home': 0.122666666666667,
#  'Wireless telephone services': 1.647,
#  'Women’s and girls’ apparel': 1.226,
#  'Women’s apparel': 1.045,
#  'Women’s dresses': 0.127,
#  'Women’s footwear': 0.293,
#  'Women’s outerwear': 0.073,
#  'Women’s suits and separates': 0.55,
#  'Women’s underwear, nightwear, sportswear and accessories': 0.283}

# %%
len(train_data_dict.keys())
# Out:
# 350

# %% [markdown]
# # Save Data:

# %%
with open(train_dataset_path, 'wb') as handle:
    pickle.dump(train_data_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(test_dataset_path, 'wb') as handle:
    pickle.dump(test_data_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open(coefficient_path, 'wb') as handle:
    pickle.dump(weight_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)
