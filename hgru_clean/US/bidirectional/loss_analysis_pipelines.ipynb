# %%
import sys
sys.path.insert(0, '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/')

# %%
import torch
import pandas as pd
import numpy as np
import statistics
import torch
import random
import time
import numpy as np
#from transformers import AdamW
from torch.utils.tensorboard import SummaryWriter
import pickle
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import shutil
import itertools
import os
from pathlib import Path

from model.GRU_model import *
from pipeline_config import *
from utils import *

# %%
# Seeds for comparisons:

torch.manual_seed(1)
np.random.seed(2)
random.seed(3)
torch.use_deterministic_algorithms(True)

# %%
with open(train_dataset_path, 'rb') as f:
    train_dataset_dict = pickle.load(f)
    
with open(test_dataset_path, 'rb') as f:
    test_dataset_dict = pickle.load(f)

with open(category_id_to_category_name_path, 'rb') as f:
    category_id_to_name_dict = pickle.load(f)
    
with open(categories_per_indent_path, 'rb') as f:
    categories_per_indent_dict = pickle.load(f)

with open(son_parent_path, 'rb') as f:
    son_parent_dict = pickle.load(f)

with open(parent_to_son_list_path, 'rb') as f:
    parent_to_son_list_dict = pickle.load(f)

with open(hgru_model_weights_path, 'rb') as f:
    hgru_weight_dict = pickle.load(f)

with open(coefficient_dict_path, 'rb') as f:
    coefficient_dict = pickle.load(f)

# %%
print(f'Features: {Features}')
print(f'HiddenSize: {HiddenSize}')
print(f'LayersDim: {LayersDim}')
print(f'OutputDim: {OutputDim}')
print(f'DropoutProb: {DropoutProb}')
print(f'Lr : {Lr}')
print(f'Epochs: {Epochs}')
# Out:
# Features: 1
# HiddenSize: 64
# LayersDim: 1
# OutputDim: 1
# DropoutProb: 0.0
# Lr : 0.125
# Epochs: 100

# %%
def get_results_on_test_set(weights_path, train_dataset_dict, test_dataset_dict, categories = None):
    predictions_dict = {}
    if categories is None:
        categories = list(test_dataset_dict.keys())
        
    for category in categories:
        if category == 'Food and beverages':
            continue
        print(category)
        train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category], test_dataset_dict[category])
        basic_model =GRUModel(input_dim=Features, hidden_dim=HiddenSize, layer_dim=LayersDim, output_dim=OutputDim, dropout_prob=DropoutProb, seed=0)
        basic_optimizer = torch.optim.AdamW(basic_model.parameters(), lr=Lr)
        ckp_path = weights_path+category+'.pt'
        model, optimizer, checkpoint, valid_loss_min = load_checkpoint(ckp_path, basic_model, basic_optimizer)
        predictions = get_predictions_on_test_set(model, test_dataloader)
        predictions_dict[category] = predictions
    return predictions_dict

# %%
def rmdir(dirc):
    dirc = Path(dirc)
    for itm in dirc.iterdir():
        if itm.is_dir():
            rmdir(itm)
            print("Deleting", itm, ".... successful.")
        else:
            itm.unlink()
    dirc.rmdir()

# %% [markdown]
# # Loss Analysis 1:

# %% [markdown]
# No Loss Term 1:

# %%
# Sanity Check:
weightspath_1
# Out:
# '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_1/'

# %%
def bi_directional_model_1(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weights_path, hgru_weight_dict, coefficient_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha):
    # deleting files in models_weights folder
    path = os.getcwd()
    desired_path = path + '/models_weights_1/'
    is_empty = not any(Path(desired_path).iterdir())

    if is_empty==False:
        rmdir(Path(desired_path))
    
    # deleting empty folder
    try:
        os.rmdir(desired_path)
    except OSError:
        print ("Deletion of the directory %s failed" % desired_path)
    else:
        print ("Successfully deleted the directory %s" % desired_path)

    # creating new folder
    try:
        os.mkdir(desired_path)
    except OSError:
        print ("Creation of the directory %s failed" % desired_path)
    else:
        print ("Successfully created the directory %s" % desired_path)
    #----------------------------------------------------------------------------------------------------------------------------------------------#
    loss_coef_1= 0
    loss_coef_2= 0.0001
    loss_coef_3= 2.2324747384839943*np.exp(-7)

    num_categories = 0
    bidrectional_models = {}


    for indent in sorted(list(categories_per_indent_dict.keys()),reverse=True):
        for category in categories_per_indent_dict[indent]:
            num_categories +=1
            print(f'num categories: {num_categories}')
            category_name = category_id_to_name_dict[category]
            print(f'category id|name: {category}|{category_name}')

            if (category not in list(parent_to_son_list_dict.keys())) or (set(parent_to_son_list_dict[category]['sons']).issubset(set(categories_per_indent_dict[indent+1]))):
                loss_coef_2 = 0   

            
            print('------------------------------------------------------------------')
            
            train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category_name], test_dataset_dict[category_name])
            model = Model
            optimizer = Optimizer
            model.to(Device)
            saving_param_path = weights_path+category_name+'.pt'
            
            bidrectional_models[category_name] = training_and_evaluation(model, indent, train_dataloader, test_dataloader, optimizer, category, hgru_weight_dict, coefficient_dict, son_parent_dict, parent_to_son_list_dict, category_id_to_name_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha, saving_param_path)
            
    return bidrectional_models

# %%
bidrectional_models_1 = bi_directional_model_1(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weightspath_1, hgru_weight_dict, coefficient_dict, 0, loss_coef_2, loss_coef_3, alpha)
# Out:
# Successfully deleted the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_1/
# Successfully created the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_1/
# num categories: 1
# category id|name: 9540.0|Bacon and related products
# ------------------------------------------------------------------
# num categories: 2
# category id|name: 8302.0|Breakfast sausage and related products
# ------------------------------------------------------------------
# num categories: 3
# category id|name: 2135.0|Fresh and frozen chicken parts
# ------------------------------------------------------------------
# num categories: 4
# category id|name: 3415.0|Fresh whole chicken
# ------------------------------------------------------------------
# num categories: 5
# category id|name: 4850.0|Frozen fish and seafood
# ------------------------------------------------------------------
# num categories: 6
# category id|name: 9972.0|Ham, excluding canned
# ------------------------------------------------------------------
# num categories: 7
# category id|name: 5846.0|Shelf stable fish and seafood
# ------------------------------------------------------------------
# num categories: 8
# category id|name: 290.0|Admission to movies, theaters, and concerts
# ------------------------------------------------------------------
# num categories: 9
# category id|name: 9102.0|Bacon, breakfast sausage, and related products
# ------------------------------------------------------------------
# num categories: 10
# category id|name: 4542.0|Bread other than white
# ------------------------------------------------------------------
# num categories: 11
# category id|name: 8257.0|Canned fruits
# ------------------------------------------------------------------
# num categories: 12
# category id|name: 2158.0|Canned vegetables
# ------------------------------------------------------------------
# num categories: 13
# category id|name: 9594.0|Checking account and other bank services
# ------------------------------------------------------------------
# num categories: 14
# category id|name: 1270.0|Chicken
# ------------------------------------------------------------------
# num categories: 15
# category id|name: 4182.0|Cookies
# ------------------------------------------------------------------
# num categories: 16
# category id|name: 9136.0|Crackers, bread, and cracker products
# ------------------------------------------------------------------
# num categories: 17
# category id|name: 5319.0|Dried beans, peas, and lentils
# ------------------------------------------------------------------
# num categories: 18
# category id|name: 4003.0|Frankfurters
# ------------------------------------------------------------------
# num categories: 19
# category id|name: 597.0|Fresh cakes and cupcakes
# ------------------------------------------------------------------
# num categories: 20
# category id|name: 7000.0|Fresh fish and seafood
# ------------------------------------------------------------------
# num categories: 21
# category id|name: 4288.0|Fresh sweetrolls, coffeecakes, doughnuts
# ------------------------------------------------------------------
# num categories: 22
# category id|name: 3655.0|Frozen and refrigerated bakery products, pies, tarts, turnovers
# ------------------------------------------------------------------
# num categories: 23
# category id|name: 8965.0|Frozen vegetables
# ------------------------------------------------------------------
# num categories: 24
# category id|name: 3234.0|Ham
# ------------------------------------------------------------------
# num categories: 25
# category id|name: 17.0|Intracity mass transit
# ------------------------------------------------------------------
# num categories: 26
# category id|name: 3829.0|Lunchmeats
# ------------------------------------------------------------------
# num categories: 27
# category id|name: 8352.0|Oranges, including tangerines
# ------------------------------------------------------------------
# num categories: 28
# category id|name: 2190.0|Other condiments
# ------------------------------------------------------------------
# num categories: 29
# category id|name: 8666.0|Other pork including roasts and picnics
# ------------------------------------------------------------------
# num categories: 30
# category id|name: 6263.0|Other uncooked poultry including turkey
# ------------------------------------------------------------------
# num categories: 31
# category id|name: 6375.0|Parking fees and tolls
# ------------------------------------------------------------------
# num categories: 32
# category id|name: 4791.0|Pork chops
# ------------------------------------------------------------------
# num categories: 33
# category id|name: 2722.0|Prepared salads
# ------------------------------------------------------------------
# num categories: 34
# category id|name: 8830.0|Processed fish and seafood
# ------------------------------------------------------------------
# num categories: 35
# category id|name: 5517.0|Salt and other seasonings and spices
# ------------------------------------------------------------------
# num categories: 36
# category id|name: 8728.0|Sauces and gravies
# ------------------------------------------------------------------
# num categories: 37
# category id|name: 5148.0|Ship fare
# ------------------------------------------------------------------
# num categories: 38
# category id|name: 2136.0|Uncooked beef roasts
# ------------------------------------------------------------------
# num categories: 39
# category id|name: 1842.0|Uncooked beef steaks
# ------------------------------------------------------------------
# num categories: 40
# category id|name: 5192.0|Uncooked ground beef
# ------------------------------------------------------------------
# num categories: 41
# category id|name: 7339.0|Uncooked other beef and veal
# ------------------------------------------------------------------
# num categories: 42
# category id|name: 6541.0|Video discs and other media
# ------------------------------------------------------------------
# num categories: 43
# category id|name: 4282.0|White bread
# ------------------------------------------------------------------
# num categories: 44
# category id|name: 9746.0|Admissions
# ------------------------------------------------------------------
# num categories: 45
# category id|name: 935.0|Airline fare
# ------------------------------------------------------------------
# num categories: 46
# category id|name: 7034.0|Apparel services other than laundry and dry cleaning
# ------------------------------------------------------------------
# num categories: 47
# category id|name: 4999.0|Apples
# ------------------------------------------------------------------
# num categories: 48
# category id|name: 3997.0|Bananas
# ------------------------------------------------------------------
# num categories: 49
# category id|name: 207.0|Beef and veal
# ------------------------------------------------------------------
# num categories: 50
# category id|name: 975.0|Bread
# ------------------------------------------------------------------
# num categories: 51
# category id|name: 4789.0|Butter
# ------------------------------------------------------------------
# num categories: 52
# category id|name: 8034.0|Cakes, cupcakes, and cookies
# ------------------------------------------------------------------
# num categories: 53
# category id|name: 2361.0|Canned fruits and vegetables
# ------------------------------------------------------------------
# num categories: 54
# category id|name: 7798.0|Child care and nursery school
# ------------------------------------------------------------------
# num categories: 55
# category id|name: 379.0|Citrus fruits
# ------------------------------------------------------------------
# num categories: 56
# category id|name: 3878.0|College tuition and fees
# ------------------------------------------------------------------
# num categories: 57
# category id|name: 3028.0|Delivery services
# ------------------------------------------------------------------
# num categories: 58
# category id|name: 9008.0|Dental services
# ------------------------------------------------------------------
# num categories: 59
# category id|name: 2863.0|Distilled spirits, excluding whiskey, at home
# ------------------------------------------------------------------
# num categories: 60
# category id|name: 4671.0|Elementary and high school tuition and fees
# ------------------------------------------------------------------
# num categories: 61
# category id|name: 7622.0|Eyeglasses and eye care
# ------------------------------------------------------------------
# num categories: 62
# category id|name: 7291.0|Financial services
# ------------------------------------------------------------------
# num categories: 63
# category id|name: 9469.0|Fish and seafood
# ------------------------------------------------------------------
# num categories: 64
# category id|name: 922.0|Fresh biscuits, rolls, muffins
# ------------------------------------------------------------------
# num categories: 65
# category id|name: 1434.0|Frozen and freeze dried prepared foods
# ------------------------------------------------------------------
# num categories: 66
# category id|name: 92.0|Frozen fruits and vegetables
# ------------------------------------------------------------------
# num categories: 67
# category id|name: 2175.0|Funeral expenses
# ------------------------------------------------------------------
# num categories: 68
# category id|name: 9359.0|Haircuts and other personal care services
# ------------------------------------------------------------------
# num categories: 69
# category id|name: 9153.0|Housing at school, excluding board
# ------------------------------------------------------------------
# num categories: 70
# category id|name: 4343.0|Instant and freeze dried coffee
# ------------------------------------------------------------------
# num categories: 71
# category id|name: 2740.0|Intracity transportation
# ------------------------------------------------------------------
# num categories: 72
# category id|name: 7646.0|Land-line telephone services
# ------------------------------------------------------------------
# num categories: 73
# category id|name: 4.0|Laundry and dry cleaning services
# ------------------------------------------------------------------
# num categories: 74
# category id|name: 8105.0|Laundry equipment
# ------------------------------------------------------------------
# num categories: 75
# category id|name: 3380.0|Lettuce
# ------------------------------------------------------------------
# num categories: 76
# category id|name: 1265.0|Margarine
# ------------------------------------------------------------------
# num categories: 77
# category id|name: 6934.0|Men’s pants and shorts
# ------------------------------------------------------------------
# num categories: 78
# category id|name: 7018.0|Men’s shirts and sweaters
# ------------------------------------------------------------------
# num categories: 79
# category id|name: 2606.0|Men’s suits, sport coats, and outerwear
# ------------------------------------------------------------------
# num categories: 80
# category id|name: 9435.0|Motor oil, coolant, and fluids
# ------------------------------------------------------------------
# num categories: 81
# category id|name: 7497.0|Motor vehicle maintenance and servicing
# ------------------------------------------------------------------
# num categories: 82
# category id|name: 1809.0|Motor vehicle repair
# ------------------------------------------------------------------
# num categories: 83
# category id|name: 1344.0|Nursing homes and adult day services
# ------------------------------------------------------------------
# num categories: 84
# category id|name: 8497.0|Other bakery products
# ------------------------------------------------------------------
# num categories: 85
# category id|name: 3215.0|Other fresh fruits
# ------------------------------------------------------------------
# num categories: 86
# category id|name: 1494.0|Other fresh vegetables
# ------------------------------------------------------------------
# num categories: 87
# category id|name: 9574.0|Other intercity transportation
# ------------------------------------------------------------------
# num categories: 88
# category id|name: 4418.0|Other lodging away from home including hotels and motels
# ------------------------------------------------------------------
# num categories: 89
# category id|name: 4535.0|Other meats
# ------------------------------------------------------------------
# num categories: 90
# category id|name: 5930.0|Other miscellaneous foods
# ------------------------------------------------------------------
# num categories: 91
# category id|name: 3337.0|Other processed fruits and vegetables including dried
# ------------------------------------------------------------------
# num categories: 92
# category id|name: 2972.0|Owners’ equivalent rent of primary residence
# ------------------------------------------------------------------
# num categories: 93
# category id|name: 759.0|Parking and other fees
# ------------------------------------------------------------------
# num categories: 94
# category id|name: 3292.0|Physicians’ services
# ------------------------------------------------------------------
# num categories: 95
# category id|name: 5855.0|Pork
# ------------------------------------------------------------------
# num categories: 96
# category id|name: 8784.0|Postage
# ------------------------------------------------------------------
# num categories: 97
# category id|name: 8287.0|Potatoes
# ------------------------------------------------------------------
# num categories: 98
# category id|name: 9948.0|Poultry
# ------------------------------------------------------------------
# num categories: 99
# category id|name: 7147.0|Rice
# ------------------------------------------------------------------
# num categories: 100
# category id|name: 1986.0|Roasted coffee
# ------------------------------------------------------------------
# num categories: 101
# category id|name: 1206.0|Services by other medical professionals
# ------------------------------------------------------------------
# num categories: 102
# category id|name: 7570.0|Snacks
# ------------------------------------------------------------------
# num categories: 103
# category id|name: 1351.0|Soups
# ------------------------------------------------------------------
# num categories: 104
# category id|name: 4846.0|Spices, seasonings, condiments, sauces
# ------------------------------------------------------------------
# num categories: 105
# category id|name: 1183.0|State motor vehicle registration and license fees
# ------------------------------------------------------------------
# num categories: 106
# category id|name: 3162.0|Technical and business school tuition and fees
# ------------------------------------------------------------------
# num categories: 107
# category id|name: 5692.0|Tomatoes
# ------------------------------------------------------------------
# num categories: 108
# category id|name: 8350.0|Toys, games, hobbies and playground equipment
# ------------------------------------------------------------------
# num categories: 109
# category id|name: 307.0|Vehicle parts and equipment other than tires
# ------------------------------------------------------------------
# num categories: 110
# category id|name: 9003.0|Veterinarian services
# ------------------------------------------------------------------
# num categories: 111
# category id|name: 2132.0|Whiskey at home
# ------------------------------------------------------------------
# num categories: 112
# category id|name: 655.0|Wireless telephone services
# ------------------------------------------------------------------
# num categories: 113
# category id|name: 452.0|Women’s dresses
# ------------------------------------------------------------------
# num categories: 114
# category id|name: 7718.0|Women’s outerwear
# ------------------------------------------------------------------
# num categories: 115
# category id|name: 9350.0|Women’s suits and separates
# ------------------------------------------------------------------
# num categories: 116
# category id|name: 9498.0|Women’s underwear, nightwear, sportswear and accessories
# ------------------------------------------------------------------
# num categories: 117
# category id|name: 7859.0|Audio equipment
# ------------------------------------------------------------------
# num categories: 118
# category id|name: 8566.0|Bakery products
# ------------------------------------------------------------------
# num categories: 119
# category id|name: 6797.0|Bedroom furniture
# ------------------------------------------------------------------
# num categories: 120
# category id|name: 2456.0|Beer, ale, and other malt beverages at home
# ------------------------------------------------------------------
# num categories: 121
# category id|name: 9333.0|Beer, ale, and other malt beverages away from home
# ------------------------------------------------------------------
# num categories: 122
# category id|name: 9448.0|Boys’ and girls’ footwear
# ------------------------------------------------------------------
# num categories: 123
# category id|name: 3935.0|Boys’ apparel
# ------------------------------------------------------------------
# num categories: 124
# category id|name: 6944.0|Breakfast cereal
# ------------------------------------------------------------------
# num categories: 125
# category id|name: 3369.0|Butter and margarine
# ------------------------------------------------------------------
# num categories: 126
# category id|name: 741.0|Candy and chewing gum
# ------------------------------------------------------------------
# num categories: 127
# category id|name: 1556.0|Car and truck rental
# ------------------------------------------------------------------
# num categories: 128
# category id|name: 6104.0|Carbonated drinks
# ------------------------------------------------------------------
# num categories: 129
# category id|name: 4451.0|Cigarettes
# ------------------------------------------------------------------
# num categories: 130
# category id|name: 4790.0|Clocks, lamps, and decorator items
# ------------------------------------------------------------------
# num categories: 131
# category id|name: 6082.0|Coffee
# ------------------------------------------------------------------
# num categories: 132
# category id|name: 7979.0|College textbooks
# ------------------------------------------------------------------
# num categories: 133
# category id|name: 6021.0|Computer software and accessories
# ------------------------------------------------------------------
# num categories: 134
# category id|name: 9308.0|Cosmetics, perfume, bath, nail preparations and implements
# ------------------------------------------------------------------
# num categories: 135
# category id|name: 3747.0|Dishes and flatware
# ------------------------------------------------------------------
# num categories: 136
# category id|name: 6418.0|Distilled spirits at home
# ------------------------------------------------------------------
# num categories: 137
# category id|name: 5556.0|Eggs
# ------------------------------------------------------------------
# num categories: 138
# category id|name: 7171.0|Floor coverings
# ------------------------------------------------------------------
# num categories: 139
# category id|name: 5489.0|Flour and prepared flour mixes
# ------------------------------------------------------------------
# num categories: 140
# category id|name: 8524.0|Fresh fruits
# ------------------------------------------------------------------
# num categories: 141
# category id|name: 1223.0|Fresh milk other than whole
# ------------------------------------------------------------------
# num categories: 142
# category id|name: 6147.0|Fresh vegetables
# ------------------------------------------------------------------
# num categories: 143
# category id|name: 2000.0|Fresh whole milk
# ------------------------------------------------------------------
# num categories: 144
# category id|name: 8552.0|Frozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 145
# category id|name: 5291.0|Garbage and trash collection
# ------------------------------------------------------------------
# num categories: 146
# category id|name: 5687.0|Gasoline, unleaded midgrade
# ------------------------------------------------------------------
# num categories: 147
# category id|name: 6324.0|Gasoline, unleaded premium
# ------------------------------------------------------------------
# num categories: 148
# category id|name: 4879.0|Gasoline, unleaded regular
# ------------------------------------------------------------------
# num categories: 149
# category id|name: 7561.0|Girls’ apparel
# ------------------------------------------------------------------
# num categories: 150
# category id|name: 6501.0|Hair, dental, shaving, and miscellaneous personal care products
# ------------------------------------------------------------------
# num categories: 151
# category id|name: 4532.0|Health insurance
# ------------------------------------------------------------------
# num categories: 152
# category id|name: 2710.0|Hospital and related services
# ------------------------------------------------------------------
# num categories: 153
# category id|name: 6610.0|Household cleaning products
# ------------------------------------------------------------------
# num categories: 154
# category id|name: 5202.0|Household paper products
# ------------------------------------------------------------------
# num categories: 155
# category id|name: 6096.0|Indoor plants and flowers
# ------------------------------------------------------------------
# num categories: 156
# category id|name: 4310.0|Internet services and electronic information providers
# ------------------------------------------------------------------
# num categories: 157
# category id|name: 3237.0|Jewelry
# ------------------------------------------------------------------
# num categories: 158
# category id|name: 2452.0|Living room, kitchen, and dining room furniture
# ------------------------------------------------------------------
# num categories: 159
# category id|name: 5762.0|Lodging away from home
# ------------------------------------------------------------------
# num categories: 160
# category id|name: 5082.0|Major appliances
# ------------------------------------------------------------------
# num categories: 161
# category id|name: 5354.0|Meats
# ------------------------------------------------------------------
# num categories: 162
# category id|name: 7821.0|Men’s apparel
# ------------------------------------------------------------------
# num categories: 163
# category id|name: 369.0|Men’s footwear
# ------------------------------------------------------------------
# num categories: 164
# category id|name: 8293.0|Miscellaneous household products
# ------------------------------------------------------------------
# num categories: 165
# category id|name: 6567.0|Miscellaneous personal services
# ------------------------------------------------------------------
# num categories: 166
# category id|name: 505.0|Motor vehicle fees
# ------------------------------------------------------------------
# num categories: 167
# category id|name: 6978.0|Motor vehicle insurance
# ------------------------------------------------------------------
# num categories: 168
# category id|name: 9790.0|Motor vehicle maintenance and repair
# ------------------------------------------------------------------
# num categories: 169
# category id|name: 133.0|Moving, storage, freight expense
# ------------------------------------------------------------------
# num categories: 170
# category id|name: 3628.0|Music instruments and accessories
# ------------------------------------------------------------------
# num categories: 171
# category id|name: 5782.0|New cars
# ------------------------------------------------------------------
# num categories: 172
# category id|name: 9870.0|New trucks
# ------------------------------------------------------------------
# num categories: 173
# category id|name: 7582.0|Newspapers and magazines
# ------------------------------------------------------------------
# num categories: 174
# category id|name: 9874.0|Nonelectric cookware and tableware
# ------------------------------------------------------------------
# num categories: 175
# category id|name: 7335.0|Nonfrozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 176
# category id|name: 8558.0|Nonprescription drugs
# ------------------------------------------------------------------
# num categories: 177
# category id|name: 1467.0|Other appliances
# ------------------------------------------------------------------
# num categories: 178
# category id|name: 7028.0|Other beverage materials including tea
# ------------------------------------------------------------------
# num categories: 179
# category id|name: 6039.0|Other fats and oils including peanut butter
# ------------------------------------------------------------------
# num categories: 180
# category id|name: 9728.0|Other foods
# ------------------------------------------------------------------
# num categories: 181
# category id|name: 7326.0|Other furniture
# ------------------------------------------------------------------
# num categories: 182
# category id|name: 5777.0|Other linens
# ------------------------------------------------------------------
# num categories: 183
# category id|name: 9744.0|Other recreation services
# ------------------------------------------------------------------
# num categories: 184
# category id|name: 315.0|Other sweets
# ------------------------------------------------------------------
# num categories: 185
# category id|name: 4138.0|Other video equipment
# ------------------------------------------------------------------
# num categories: 186
# category id|name: 4623.0|Outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 187
# category id|name: 1191.0|Personal care services
# ------------------------------------------------------------------
# num categories: 188
# category id|name: 980.0|Personal computers and peripheral equipment
# ------------------------------------------------------------------
# num categories: 189
# category id|name: 4226.0|Pet food
# ------------------------------------------------------------------
# num categories: 190
# category id|name: 1219.0|Pet services including veterinary
# ------------------------------------------------------------------
# num categories: 191
# category id|name: 2424.0|Photographers and film processing
# ------------------------------------------------------------------
# num categories: 192
# category id|name: 6539.0|Photographic equipment
# ------------------------------------------------------------------
# num categories: 193
# category id|name: 594.0|Postage and delivery services
# ------------------------------------------------------------------
# num categories: 194
# category id|name: 1369.0|Prescription drugs
# ------------------------------------------------------------------
# num categories: 195
# category id|name: 9100.0|Processed fruits and vegetables
# ------------------------------------------------------------------
# num categories: 196
# category id|name: 3965.0|Professional services
# ------------------------------------------------------------------
# num categories: 197
# category id|name: 4134.0|Public transportation
# ------------------------------------------------------------------
# num categories: 198
# category id|name: 8808.0|Purchase of pets, pet supplies, accessories
# ------------------------------------------------------------------
# num categories: 199
# category id|name: 737.0|Recorded music and music subscriptions
# ------------------------------------------------------------------
# num categories: 200
# category id|name: 3331.0|Recreational books
# ------------------------------------------------------------------
# num categories: 201
# category id|name: 4363.0|Rent of primary residence
# ------------------------------------------------------------------
# num categories: 202
# category id|name: 3008.0|Rice, pasta, cornmeal
# ------------------------------------------------------------------
# num categories: 203
# category id|name: 7.0|Salad dressing
# ------------------------------------------------------------------
# num categories: 204
# category id|name: 8663.0|Sewing machines, fabric and supplies
# ------------------------------------------------------------------
# num categories: 205
# category id|name: 2216.0|Sports equipment
# ------------------------------------------------------------------
# num categories: 206
# category id|name: 4414.0|Sports vehicles including bicycles
# ------------------------------------------------------------------
# num categories: 207
# category id|name: 8917.0|Stationery, stationery supplies, gift wrap
# ------------------------------------------------------------------
# num categories: 208
# category id|name: 3199.0|Sugar and artificial sweeteners
# ------------------------------------------------------------------
# num categories: 209
# category id|name: 2940.0|Telephone hardware, calculators, and other consumer information items
# ------------------------------------------------------------------
# num categories: 210
# category id|name: 2405.0|Telephone services
# ------------------------------------------------------------------
# num categories: 211
# category id|name: 5433.0|Televisions
# ------------------------------------------------------------------
# num categories: 212
# category id|name: 7981.0|Tenants’ and household insurance
# ------------------------------------------------------------------
# num categories: 213
# category id|name: 6900.0|Tires
# ------------------------------------------------------------------
# num categories: 214
# category id|name: 620.0|Tobacco products other than cigarettes
# ------------------------------------------------------------------
# num categories: 215
# category id|name: 5668.0|Tools, hardware and supplies
# ------------------------------------------------------------------
# num categories: 216
# category id|name: 3103.0|Toys
# ------------------------------------------------------------------
# num categories: 217
# category id|name: 2308.0|Tuition, other school fees, and childcare
# ------------------------------------------------------------------
# num categories: 218
# category id|name: 1564.0|Vehicle accessories other than tires
# ------------------------------------------------------------------
# num categories: 219
# category id|name: 4757.0|Video and audio services
# ------------------------------------------------------------------
# num categories: 220
# category id|name: 6459.0|Watches
# ------------------------------------------------------------------
# num categories: 221
# category id|name: 6884.0|Water and sewerage maintenance
# ------------------------------------------------------------------
# num categories: 222
# category id|name: 6848.0|Window coverings
# ------------------------------------------------------------------
# num categories: 223
# category id|name: 9946.0|Wine at home
# ------------------------------------------------------------------
# num categories: 224
# category id|name: 2743.0|Wine away from home
# ------------------------------------------------------------------
# num categories: 225
# category id|name: 8387.0|Women’s apparel
# ------------------------------------------------------------------
# num categories: 226
# category id|name: 4044.0|Women’s footwear
# ------------------------------------------------------------------
# num categories: 227
# category id|name: 2422.0|Alcoholic beverages at home
# ------------------------------------------------------------------
# num categories: 228
# category id|name: 5080.0|Alcoholic beverages away from home
# ------------------------------------------------------------------
# num categories: 229
# category id|name: 3958.0|Appliances
# ------------------------------------------------------------------
# num categories: 230
# category id|name: 7177.0|Beverage materials including coffee and tea
# ------------------------------------------------------------------
# num categories: 231
# category id|name: 232.0|Cereals and cereal products
# ------------------------------------------------------------------
# num categories: 232
# category id|name: 1043.0|Cheese and related products
# ------------------------------------------------------------------
# num categories: 233
# category id|name: 3707.0|Education and communication services
# ------------------------------------------------------------------
# num categories: 234
# category id|name: 5985.0|Educational books and supplies
# ------------------------------------------------------------------
# num categories: 235
# category id|name: 3612.0|Fats and oils
# ------------------------------------------------------------------
# num categories: 236
# category id|name: 7182.0|Footwear
# ------------------------------------------------------------------
# num categories: 237
# category id|name: 4607.0|Fresh fruits and vegetables
# ------------------------------------------------------------------
# num categories: 238
# category id|name: 5177.0|Fuel oil
# ------------------------------------------------------------------
# num categories: 239
# category id|name: 730.0|Furniture and bedding
# ------------------------------------------------------------------
# num categories: 240
# category id|name: 789.0|Gasoline all types
# ------------------------------------------------------------------
# num categories: 241
# category id|name: 2307.0|Housekeeping supplies
# ------------------------------------------------------------------
# num categories: 242
# category id|name: 6801.0|Ice cream and related products
# ------------------------------------------------------------------
# num categories: 243
# category id|name: 2101.0|Infants’ and toddlers’ apparel
# ------------------------------------------------------------------
# num categories: 244
# category id|name: 7569.0|Information technology commodities
# ------------------------------------------------------------------
# num categories: 245
# category id|name: 546.0|Jewelry and watches
# ------------------------------------------------------------------
# num categories: 246
# category id|name: 8886.0|Juices and nonalcoholic drinks
# ------------------------------------------------------------------
# num categories: 247
# category id|name: 7803.0|Medical care services
# ------------------------------------------------------------------
# num categories: 248
# category id|name: 3514.0|Medical equipment and supplies
# ------------------------------------------------------------------
# num categories: 249
# category id|name: 5658.0|Medicinal drugs
# ------------------------------------------------------------------
# num categories: 250
# category id|name: 2395.0|Men’s and boys’ apparel
# ------------------------------------------------------------------
# num categories: 251
# category id|name: 4634.0|Milk
# ------------------------------------------------------------------
# num categories: 252
# category id|name: 1381.0|Miscellaneous personal goods
# ------------------------------------------------------------------
# num categories: 253
# category id|name: 4291.0|New vehicles
# ------------------------------------------------------------------
# num categories: 254
# category id|name: 5142.0|Other dairy and related products
# ------------------------------------------------------------------
# num categories: 255
# category id|name: 6715.0|Other household equipment and furnishings
# ------------------------------------------------------------------
# num categories: 256
# category id|name: 8206.0|Other motor fuels
# ------------------------------------------------------------------
# num categories: 257
# category id|name: 2259.0|Other personal services
# ------------------------------------------------------------------
# num categories: 258
# category id|name: 4278.0|Other recreational goods
# ------------------------------------------------------------------
# num categories: 259
# category id|name: 1231.0|Personal care products
# ------------------------------------------------------------------
# num categories: 260
# category id|name: 7156.0|Pets and pet products
# ------------------------------------------------------------------
# num categories: 261
# category id|name: 8921.0|Photographic equipment and supplies
# ------------------------------------------------------------------
# num categories: 262
# category id|name: 2320.0|Propane, kerosene, and firewood
# ------------------------------------------------------------------
# num categories: 263
# category id|name: 8585.0|Recreation services
# ------------------------------------------------------------------
# num categories: 264
# category id|name: 7963.0|Recreational reading materials
# ------------------------------------------------------------------
# num categories: 265
# category id|name: 8577.0|Rent of shelter
# ------------------------------------------------------------------
# num categories: 266
# category id|name: 172.0|Sporting goods
# ------------------------------------------------------------------
# num categories: 267
# category id|name: 7995.0|Sugar and sweets
# ------------------------------------------------------------------
# num categories: 268
# category id|name: 949.0|Tobacco and smoking products
# ------------------------------------------------------------------
# num categories: 269
# category id|name: 6044.0|Tools, hardware, outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 270
# category id|name: 6999.0|Transportation services
# ------------------------------------------------------------------
# num categories: 271
# category id|name: 5590.0|Video and audio products
# ------------------------------------------------------------------
# num categories: 272
# category id|name: 3706.0|Water and sewer and trash collection services
# ------------------------------------------------------------------
# num categories: 273
# category id|name: 8669.0|Window and floor coverings and other linens
# ------------------------------------------------------------------
# num categories: 274
# category id|name: 7374.0|Women’s and girls’ apparel
# ------------------------------------------------------------------
# num categories: 275
# category id|name: 7635.0|Alcoholic beverages
# ------------------------------------------------------------------
# num categories: 276
# category id|name: 5516.0|Apparel
# ------------------------------------------------------------------
# num categories: 277
# category id|name: 2948.0|Cereals and bakery products
# ------------------------------------------------------------------
# num categories: 278
# category id|name: 5341.0|Dairy and related products
# ------------------------------------------------------------------
# num categories: 279
# category id|name: 4699.0|Education and communication commodities
# ------------------------------------------------------------------
# num categories: 280
# category id|name: 1202.0|Electricity
# ------------------------------------------------------------------
# num categories: 281
# category id|name: 6369.0|Food from vending machines and mobile vendors
# ------------------------------------------------------------------
# num categories: 282
# category id|name: 9499.0|Fruits and vegetables
# ------------------------------------------------------------------
# num categories: 283
# category id|name: 416.0|Fuel oil and other fuels
# ------------------------------------------------------------------
# num categories: 284
# category id|name: 3598.0|Full service meals and snacks
# ------------------------------------------------------------------
# num categories: 285
# category id|name: 5562.0|Household furnishings and supplies
# ------------------------------------------------------------------
# num categories: 286
# category id|name: 8625.0|Information and information processing
# ------------------------------------------------------------------
# num categories: 287
# category id|name: 5358.0|Information technology, hardware and services
# ------------------------------------------------------------------
# num categories: 288
# category id|name: 8446.0|Limited service meals and snacks
# ------------------------------------------------------------------
# num categories: 289
# category id|name: 8516.0|Meats, poultry, fish, and eggs
# ------------------------------------------------------------------
# num categories: 290
# category id|name: 5635.0|Medical care commodities
# ------------------------------------------------------------------
# num categories: 291
# category id|name: 3840.0|Motor fuel
# ------------------------------------------------------------------
# num categories: 292
# category id|name: 2973.0|New and used motor vehicles
# ------------------------------------------------------------------
# num categories: 293
# category id|name: 6387.0|Nonalcoholic beverages and beverage materials
# ------------------------------------------------------------------
# num categories: 294
# category id|name: 4196.0|Other food at home
# ------------------------------------------------------------------
# num categories: 295
# category id|name: 1346.0|Other food away from home
# ------------------------------------------------------------------
# num categories: 296
# category id|name: 5557.0|Other goods
# ------------------------------------------------------------------
# num categories: 297
# category id|name: 6582.0|Recreation commodities
# ------------------------------------------------------------------
# num categories: 298
# category id|name: 8742.0|Shelter
# ------------------------------------------------------------------
# num categories: 299
# category id|name: 690.0|Transportation commodities less motor fuel
# ------------------------------------------------------------------
# num categories: 300
# category id|name: 5867.0|Commodities less food
# ------------------------------------------------------------------
# num categories: 301
# category id|name: 3891.0|Commodities less food and beverages
# ------------------------------------------------------------------
# num categories: 302
# category id|name: 4935.0|Commodities less food and energy commodities
# ------------------------------------------------------------------
# num categories: 303
# category id|name: 9826.0|Commodities less food, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 304
# category id|name: 5970.0|Communication
# ------------------------------------------------------------------
# num categories: 305
# category id|name: 612.0|Domestically produced farm food
# ------------------------------------------------------------------
# num categories: 306
# category id|name: 314.0|Education
# ------------------------------------------------------------------
# num categories: 307
# category id|name: 8995.0|Energy commodities
# ------------------------------------------------------------------
# num categories: 308
# category id|name: 4748.0|Energy services
# ------------------------------------------------------------------
# num categories: 309
# category id|name: 4200.0|Food at home
# ------------------------------------------------------------------
# num categories: 310
# category id|name: 1345.0|Food away from home
# ------------------------------------------------------------------
# num categories: 311
# category id|name: 396.0|Household energy
# ------------------------------------------------------------------
# num categories: 312
# category id|name: 6247.0|Nondurables less food
# ------------------------------------------------------------------
# num categories: 313
# category id|name: 5488.0|Nondurables less food and apparel
# ------------------------------------------------------------------
# num categories: 314
# category id|name: 7080.0|Nondurables less food and beverages
# ------------------------------------------------------------------
# num categories: 315
# category id|name: 1465.0|Nondurables less food, beverages, and apparel
# ------------------------------------------------------------------
# num categories: 316
# category id|name: 6986.0|Personal care
# ------------------------------------------------------------------
# num categories: 317
# category id|name: 9321.0|Pets, pet products and services
# ------------------------------------------------------------------
# num categories: 318
# category id|name: 9325.0|Photography
# ------------------------------------------------------------------
# num categories: 319
# category id|name: 3815.0|Private transportation
# ------------------------------------------------------------------
# num categories: 320
# category id|name: 1033.0|Services less energy services
# ------------------------------------------------------------------
# num categories: 321
# category id|name: 5145.0|Services less medical care services
# ------------------------------------------------------------------
# num categories: 322
# category id|name: 9058.0|Services less rent of shelter
# ------------------------------------------------------------------
# num categories: 323
# category id|name: 5618.0|Video and audio
# ------------------------------------------------------------------
# num categories: 324
# category id|name: 4604.0|All items less energy
# ------------------------------------------------------------------
# num categories: 325
# category id|name: 3531.0|All items less food
# ------------------------------------------------------------------
# num categories: 326
# category id|name: 5306.0|All items less food and energy
# ------------------------------------------------------------------
# num categories: 327
# category id|name: 4114.0|All items less food and shelter
# ------------------------------------------------------------------
# num categories: 328
# category id|name: 5789.0|All items less food, shelter, and energy
# ------------------------------------------------------------------
# num categories: 329
# category id|name: 2208.0|All items less food, shelter, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 330
# category id|name: 2047.0|All items less medical care
# ------------------------------------------------------------------
# num categories: 331
# category id|name: 7199.0|All items less shelter
# ------------------------------------------------------------------
# num categories: 332
# category id|name: 3242.0|Apparel less footwear
# ------------------------------------------------------------------
# num categories: 333
# category id|name: 704.0|Commodities
# ------------------------------------------------------------------
# num categories: 334
# category id|name: 2665.0|Durables
# ------------------------------------------------------------------
# num categories: 335
# category id|name: 1868.0|Education and communication
# ------------------------------------------------------------------
# num categories: 336
# category id|name: 7558.0|Energy
# ------------------------------------------------------------------
# num categories: 337
# category id|name: 4934.0|Food
# ------------------------------------------------------------------
# num categories: 338
# category id|name: 9257.0|Food and beverages
# ------------------------------------------------------------------
# num categories: 339
# category id|name: 5463.0|Fuels and utilities
# ------------------------------------------------------------------
# num categories: 340
# category id|name: 9339.0|Household furnishings and operations
# ------------------------------------------------------------------
# num categories: 341
# category id|name: 6803.0|Housing
# ------------------------------------------------------------------
# num categories: 342
# category id|name: 3411.0|Medical care
# ------------------------------------------------------------------
# num categories: 343
# category id|name: 818.0|Nondurables
# ------------------------------------------------------------------
# num categories: 344
# category id|name: 8488.0|Other goods and services
# ------------------------------------------------------------------
# num categories: 345
# category id|name: 6741.0|Other services
# ------------------------------------------------------------------
# num categories: 346
# category id|name: 8575.0|Recreation
# ------------------------------------------------------------------
# num categories: 347
# category id|name: 9735.0|Services
# ------------------------------------------------------------------
# num categories: 348
# category id|name: 6812.0|Transportation
# ------------------------------------------------------------------
# num categories: 349
# category id|name: 7939.0|Utilities and public transportation
# ------------------------------------------------------------------
# num categories: 350
# category id|name: 8106.0|All items
# ------------------------------------------------------------------

# %% [markdown]
# Save prediction dict:

# %%
categories_lists = list(categories_per_indent_dict.values())
categories_id = list(itertools.chain.from_iterable(categories_lists))
categories = []
for category_id in categories_id:
    categories.append(category_id_to_name_dict[category_id])

# %%
predictions_dict_1 = get_results_on_test_set(weightspath_1, train_dataset_dict, test_dataset_dict, categories = categories)
with open(test_predictions_path_1, 'wb') as handle:
    pickle.dump(predictions_dict_1, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Admission to movies, theaters, and concerts
# Bacon, breakfast sausage, and related products
# Bread other than white
# Canned fruits
# Canned vegetables
# Checking account and other bank services
# Chicken
# Cookies
# Crackers, bread, and cracker products
# Dried beans, peas, and lentils
# Frankfurters
# Fresh cakes and cupcakes
# Fresh fish and seafood
# Fresh sweetrolls, coffeecakes, doughnuts
# Frozen and refrigerated bakery products, pies, tarts, turnovers
# Frozen vegetables
# Ham
# Intracity mass transit
# Lunchmeats
# Oranges, including tangerines
# Other condiments
# Other pork including roasts and picnics
# Other uncooked poultry including turkey
# Parking fees and tolls
# Pork chops
# Prepared salads
# Processed fish and seafood
# Salt and other seasonings and spices
# Sauces and gravies
# Ship fare
# Uncooked beef roasts
# Uncooked beef steaks
# Uncooked ground beef
# Uncooked other beef and veal
# Video discs and other media
# White bread
# Admissions
# Airline fare
# Apparel services other than laundry and dry cleaning
# Apples
# Bananas
# Beef and veal
# Bread
# Butter
# Cakes, cupcakes, and cookies
# Canned fruits and vegetables
# Child care and nursery school
# Citrus fruits
# College tuition and fees
# Delivery services
# Dental services
# Distilled spirits, excluding whiskey, at home
# Elementary and high school tuition and fees
# Eyeglasses and eye care
# Financial services
# Fish and seafood
# Fresh biscuits, rolls, muffins
# Frozen and freeze dried prepared foods
# Frozen fruits and vegetables
# Funeral expenses
# Haircuts and other personal care services
# Housing at school, excluding board
# Instant and freeze dried coffee
# Intracity transportation
# Land-line telephone services
# Laundry and dry cleaning services
# Laundry equipment
# Lettuce
# Margarine
# Men’s pants and shorts
# Men’s shirts and sweaters
# Men’s suits, sport coats, and outerwear
# Motor oil, coolant, and fluids
# Motor vehicle maintenance and servicing
# Motor vehicle repair
# Nursing homes and adult day services
# Other bakery products
# Other fresh fruits
# Other fresh vegetables
# Other intercity transportation
# Other lodging away from home including hotels and motels
# Other meats
# Other miscellaneous foods
# Other processed fruits and vegetables including dried
# Owners’ equivalent rent of primary residence
# Parking and other fees
# Physicians’ services
# Pork
# Postage
# Potatoes
# Poultry
# Rice
# Roasted coffee
# Services by other medical professionals
# Snacks
# Soups
# Spices, seasonings, condiments, sauces
# State motor vehicle registration and license fees
# Technical and business school tuition and fees
# Tomatoes
# Toys, games, hobbies and playground equipment
# Vehicle parts and equipment other than tires
# Veterinarian services
# Whiskey at home
# Wireless telephone services
# Women’s dresses
# Women’s outerwear
# Women’s suits and separates
# Women’s underwear, nightwear, sportswear and accessories
# Alcoholic beverages
# Apparel
# Cereals and bakery products
# Dairy and related products
# Education and communication commodities
# Electricity
# Food from vending machines and mobile vendors
# Fruits and vegetables
# Fuel oil and other fuels
# Full service meals and snacks
# Household furnishings and supplies
# Information and information processing
# Information technology, hardware and services
# Limited service meals and snacks
# Meats, poultry, fish, and eggs
# Medical care commodities
# Motor fuel
# New and used motor vehicles
# Nonalcoholic beverages and beverage materials
# Other food at home
# Other food away from home
# Other goods
# Recreation commodities
# Shelter
# Transportation commodities less motor fuel
# Alcoholic beverages at home
# Alcoholic beverages away from home
# Appliances
# Beverage materials including coffee and tea
# Cereals and cereal products
# Cheese and related products
# Education and communication services
# Educational books and supplies
# Fats and oils
# Footwear
# Fresh fruits and vegetables
# Fuel oil
# Furniture and bedding
# Gasoline all types
# Housekeeping supplies
# Ice cream and related products
# Infants’ and toddlers’ apparel
# Information technology commodities
# Jewelry and watches
# Juices and nonalcoholic drinks
# Medical care services
# Medical equipment and supplies
# Medicinal drugs
# Men’s and boys’ apparel
# Milk
# Miscellaneous personal goods
# New vehicles
# Other dairy and related products
# Other household equipment and furnishings
# Other motor fuels
# Other personal services
# Other recreational goods
# Personal care products
# Pets and pet products
# Photographic equipment and supplies
# Propane, kerosene, and firewood
# Recreation services
# Recreational reading materials
# Rent of shelter
# Sporting goods
# Sugar and sweets
# Tobacco and smoking products
# Tools, hardware, outdoor equipment and supplies
# Transportation services
# Video and audio products
# Water and sewer and trash collection services
# Window and floor coverings and other linens
# Women’s and girls’ apparel
# All items
# All items less energy
# All items less food
# All items less food and energy
# All items less food and shelter
# All items less food, shelter, and energy
# All items less food, shelter, energy, and used cars and trucks
# All items less medical care
# All items less shelter
# Apparel less footwear
# Commodities
# Durables
# Education and communication
# Energy
# Food
# Fuels and utilities
# Household furnishings and operations
# Housing
# Medical care
# Nondurables
# Other goods and services
# Other services
# Recreation
# Services
# Transportation
# Utilities and public transportation
# Audio equipment
# Bakery products
# Bedroom furniture
# Beer, ale, and other malt beverages at home
# Beer, ale, and other malt beverages away from home
# Boys’ and girls’ footwear
# Boys’ apparel
# Breakfast cereal
# Butter and margarine
# Candy and chewing gum
# Car and truck rental
# Carbonated drinks
# Cigarettes
# Clocks, lamps, and decorator items
# Coffee
# College textbooks
# Computer software and accessories
# Cosmetics, perfume, bath, nail preparations and implements
# Dishes and flatware
# Distilled spirits at home
# Eggs
# Floor coverings
# Flour and prepared flour mixes
# Fresh fruits
# Fresh milk other than whole
# Fresh vegetables
# Fresh whole milk
# Frozen noncarbonated juices and drinks
# Garbage and trash collection
# Gasoline, unleaded midgrade
# Gasoline, unleaded premium
# Gasoline, unleaded regular
# Girls’ apparel
# Hair, dental, shaving, and miscellaneous personal care products
# Health insurance
# Hospital and related services
# Household cleaning products
# Household paper products
# Indoor plants and flowers
# Internet services and electronic information providers
# Jewelry
# Living room, kitchen, and dining room furniture
# Lodging away from home
# Major appliances
# Meats
# Men’s apparel
# Men’s footwear
# Miscellaneous household products
# Miscellaneous personal services
# Motor vehicle fees
# Motor vehicle insurance
# Motor vehicle maintenance and repair
# Moving, storage, freight expense
# Music instruments and accessories
# New cars
# New trucks
# Newspapers and magazines
# Nonelectric cookware and tableware
# Nonfrozen noncarbonated juices and drinks
# Nonprescription drugs
# Other appliances
# Other beverage materials including tea
# Other fats and oils including peanut butter
# Other foods
# Other furniture
# Other linens
# Other recreation services
# Other sweets
# Other video equipment
# Outdoor equipment and supplies
# Personal care services
# Personal computers and peripheral equipment
# Pet food
# Pet services including veterinary
# Photographers and film processing
# Photographic equipment
# Postage and delivery services
# Prescription drugs
# Processed fruits and vegetables
# Professional services
# Public transportation
# Purchase of pets, pet supplies, accessories
# Recorded music and music subscriptions
# Recreational books
# Rent of primary residence
# Rice, pasta, cornmeal
# Salad dressing
# Sewing machines, fabric and supplies
# Sports equipment
# Sports vehicles including bicycles
# Stationery, stationery supplies, gift wrap
# Sugar and artificial sweeteners
# Telephone hardware, calculators, and other consumer information items
# Telephone services
# Televisions
# Tenants’ and household insurance
# Tires
# Tobacco products other than cigarettes
# Tools, hardware and supplies
# Toys
# Tuition, other school fees, and childcare
# Vehicle accessories other than tires
# Video and audio services
# Watches
# Water and sewerage maintenance
# Window coverings
# Wine at home
# Wine away from home
# Women’s apparel
# Women’s footwear
# Bacon and related products
# Breakfast sausage and related products
# Fresh and frozen chicken parts
# Fresh whole chicken
# Frozen fish and seafood
# Ham, excluding canned
# Shelf stable fish and seafood
# Commodities less food
# Commodities less food and beverages
# Commodities less food and energy commodities
# Commodities less food, energy, and used cars and trucks
# Communication
# Domestically produced farm food
# Education
# Energy commodities
# Energy services
# Food at home
# Food away from home
# Household energy
# Nondurables less food
# Nondurables less food and apparel
# Nondurables less food and beverages
# Nondurables less food, beverages, and apparel
# Personal care
# Pets, pet products and services
# Photography
# Private transportation
# Services less energy services
# Services less medical care services
# Services less rent of shelter
# Video and audio

# %% [markdown]
# # Loss Analysis 2:

# %% [markdown]
# No Loss Term 2:

# %%
# Sanity Check:
weightspath_2
# Out:
# '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_2/'

# %%
def bi_directional_model_2(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weights_path, hgru_weight_dict, coefficient_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha):
    # deleting files in models_weights folder
    path = os.getcwd()
    desired_path = path + '/models_weights_2/'
    is_empty = not any(Path(desired_path).iterdir())

    if is_empty==False:
        rmdir(Path(desired_path))
    
    # deleting empty folder
    try:
        os.rmdir(desired_path)
    except OSError:
        print ("Deletion of the directory %s failed" % desired_path)
    else:
        print ("Successfully deleted the directory %s" % desired_path)

    # creating new folder
    try:
        os.mkdir(desired_path)
    except OSError:
        print ("Creation of the directory %s failed" % desired_path)
    else:
        print ("Successfully created the directory %s" % desired_path)
    #----------------------------------------------------------------------------------------------------------------------------------------------#
    loss_coef_1= 8.092430201147471*np.exp(-7)
    loss_coef_2= 0
    loss_coef_3= 2.2324747384839943*np.exp(-7)
    
    num_categories = 0
    bidrectional_models = {}

    for indent in sorted(list(categories_per_indent_dict.keys()),reverse=True):
        for category in categories_per_indent_dict[indent]:
            num_categories +=1
            print(f'num categories: {num_categories}')
            category_name = category_id_to_name_dict[category]
            print(f'category id|name: {category}|{category_name}')

            if int(indent) == 0 or son_parent_dict[category] not in categories_per_indent_dict[indent-1]: 
                loss_coef_1 = 0
            
            print('------------------------------------------------------------------')
            
            train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category_name], test_dataset_dict[category_name])
            model = Model
            optimizer = Optimizer
            model.to(Device)
            saving_param_path = weights_path+category_name+'.pt'
            
            bidrectional_models[category_name] = training_and_evaluation(model, indent, train_dataloader, test_dataloader, optimizer, category, hgru_weight_dict, coefficient_dict, son_parent_dict, parent_to_son_list_dict, category_id_to_name_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha, saving_param_path)
            
    return bidrectional_models

# %%
bidrectional_models_2 = bi_directional_model_2(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weightspath_2, hgru_weight_dict, coefficient_dict, loss_coef_1, 0, loss_coef_3, alpha)
# Out:
# Deletion of the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_2/ failed
# Successfully created the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_2/
# num categories: 1
# category id|name: 9540.0|Bacon and related products
# ------------------------------------------------------------------
# num categories: 2
# category id|name: 8302.0|Breakfast sausage and related products
# ------------------------------------------------------------------
# num categories: 3
# category id|name: 2135.0|Fresh and frozen chicken parts
# ------------------------------------------------------------------
# num categories: 4
# category id|name: 3415.0|Fresh whole chicken
# ------------------------------------------------------------------
# num categories: 5
# category id|name: 4850.0|Frozen fish and seafood
# ------------------------------------------------------------------
# num categories: 6
# category id|name: 9972.0|Ham, excluding canned
# ------------------------------------------------------------------
# num categories: 7
# category id|name: 5846.0|Shelf stable fish and seafood
# ------------------------------------------------------------------
# num categories: 8
# category id|name: 290.0|Admission to movies, theaters, and concerts
# ------------------------------------------------------------------
# num categories: 9
# category id|name: 9102.0|Bacon, breakfast sausage, and related products
# ------------------------------------------------------------------
# num categories: 10
# category id|name: 4542.0|Bread other than white
# ------------------------------------------------------------------
# num categories: 11
# category id|name: 8257.0|Canned fruits
# ------------------------------------------------------------------
# num categories: 12
# category id|name: 2158.0|Canned vegetables
# ------------------------------------------------------------------
# num categories: 13
# category id|name: 9594.0|Checking account and other bank services
# ------------------------------------------------------------------
# num categories: 14
# category id|name: 1270.0|Chicken
# ------------------------------------------------------------------
# num categories: 15
# category id|name: 4182.0|Cookies
# ------------------------------------------------------------------
# num categories: 16
# category id|name: 9136.0|Crackers, bread, and cracker products
# ------------------------------------------------------------------
# num categories: 17
# category id|name: 5319.0|Dried beans, peas, and lentils
# ------------------------------------------------------------------
# num categories: 18
# category id|name: 4003.0|Frankfurters
# ------------------------------------------------------------------
# num categories: 19
# category id|name: 597.0|Fresh cakes and cupcakes
# ------------------------------------------------------------------
# num categories: 20
# category id|name: 7000.0|Fresh fish and seafood
# ------------------------------------------------------------------
# num categories: 21
# category id|name: 4288.0|Fresh sweetrolls, coffeecakes, doughnuts
# ------------------------------------------------------------------
# num categories: 22
# category id|name: 3655.0|Frozen and refrigerated bakery products, pies, tarts, turnovers
# ------------------------------------------------------------------
# num categories: 23
# category id|name: 8965.0|Frozen vegetables
# ------------------------------------------------------------------
# num categories: 24
# category id|name: 3234.0|Ham
# ------------------------------------------------------------------
# num categories: 25
# category id|name: 17.0|Intracity mass transit
# ------------------------------------------------------------------
# num categories: 26
# category id|name: 3829.0|Lunchmeats
# ------------------------------------------------------------------
# num categories: 27
# category id|name: 8352.0|Oranges, including tangerines
# ------------------------------------------------------------------
# num categories: 28
# category id|name: 2190.0|Other condiments
# ------------------------------------------------------------------
# num categories: 29
# category id|name: 8666.0|Other pork including roasts and picnics
# ------------------------------------------------------------------
# num categories: 30
# category id|name: 6263.0|Other uncooked poultry including turkey
# ------------------------------------------------------------------
# num categories: 31
# category id|name: 6375.0|Parking fees and tolls
# ------------------------------------------------------------------
# num categories: 32
# category id|name: 4791.0|Pork chops
# ------------------------------------------------------------------
# num categories: 33
# category id|name: 2722.0|Prepared salads
# ------------------------------------------------------------------
# num categories: 34
# category id|name: 8830.0|Processed fish and seafood
# ------------------------------------------------------------------
# num categories: 35
# category id|name: 5517.0|Salt and other seasonings and spices
# ------------------------------------------------------------------
# num categories: 36
# category id|name: 8728.0|Sauces and gravies
# ------------------------------------------------------------------
# num categories: 37
# category id|name: 5148.0|Ship fare
# ------------------------------------------------------------------
# num categories: 38
# category id|name: 2136.0|Uncooked beef roasts
# ------------------------------------------------------------------
# num categories: 39
# category id|name: 1842.0|Uncooked beef steaks
# ------------------------------------------------------------------
# num categories: 40
# category id|name: 5192.0|Uncooked ground beef
# ------------------------------------------------------------------
# num categories: 41
# category id|name: 7339.0|Uncooked other beef and veal
# ------------------------------------------------------------------
# num categories: 42
# category id|name: 6541.0|Video discs and other media
# ------------------------------------------------------------------
# num categories: 43
# category id|name: 4282.0|White bread
# ------------------------------------------------------------------
# num categories: 44
# category id|name: 9746.0|Admissions
# ------------------------------------------------------------------
# num categories: 45
# category id|name: 935.0|Airline fare
# ------------------------------------------------------------------
# num categories: 46
# category id|name: 7034.0|Apparel services other than laundry and dry cleaning
# ------------------------------------------------------------------
# num categories: 47
# category id|name: 4999.0|Apples
# ------------------------------------------------------------------
# num categories: 48
# category id|name: 3997.0|Bananas
# ------------------------------------------------------------------
# num categories: 49
# category id|name: 207.0|Beef and veal
# ------------------------------------------------------------------
# num categories: 50
# category id|name: 975.0|Bread
# ------------------------------------------------------------------
# num categories: 51
# category id|name: 4789.0|Butter
# ------------------------------------------------------------------
# num categories: 52
# category id|name: 8034.0|Cakes, cupcakes, and cookies
# ------------------------------------------------------------------
# num categories: 53
# category id|name: 2361.0|Canned fruits and vegetables
# ------------------------------------------------------------------
# num categories: 54
# category id|name: 7798.0|Child care and nursery school
# ------------------------------------------------------------------
# num categories: 55
# category id|name: 379.0|Citrus fruits
# ------------------------------------------------------------------
# num categories: 56
# category id|name: 3878.0|College tuition and fees
# ------------------------------------------------------------------
# num categories: 57
# category id|name: 3028.0|Delivery services
# ------------------------------------------------------------------
# num categories: 58
# category id|name: 9008.0|Dental services
# ------------------------------------------------------------------
# num categories: 59
# category id|name: 2863.0|Distilled spirits, excluding whiskey, at home
# ------------------------------------------------------------------
# num categories: 60
# category id|name: 4671.0|Elementary and high school tuition and fees
# ------------------------------------------------------------------
# num categories: 61
# category id|name: 7622.0|Eyeglasses and eye care
# ------------------------------------------------------------------
# num categories: 62
# category id|name: 7291.0|Financial services
# ------------------------------------------------------------------
# num categories: 63
# category id|name: 9469.0|Fish and seafood
# ------------------------------------------------------------------
# num categories: 64
# category id|name: 922.0|Fresh biscuits, rolls, muffins
# ------------------------------------------------------------------
# num categories: 65
# category id|name: 1434.0|Frozen and freeze dried prepared foods
# ------------------------------------------------------------------
# num categories: 66
# category id|name: 92.0|Frozen fruits and vegetables
# ------------------------------------------------------------------
# num categories: 67
# category id|name: 2175.0|Funeral expenses
# ------------------------------------------------------------------
# num categories: 68
# category id|name: 9359.0|Haircuts and other personal care services
# ------------------------------------------------------------------
# num categories: 69
# category id|name: 9153.0|Housing at school, excluding board
# ------------------------------------------------------------------
# num categories: 70
# category id|name: 4343.0|Instant and freeze dried coffee
# ------------------------------------------------------------------
# num categories: 71
# category id|name: 2740.0|Intracity transportation
# ------------------------------------------------------------------
# num categories: 72
# category id|name: 7646.0|Land-line telephone services
# ------------------------------------------------------------------
# num categories: 73
# category id|name: 4.0|Laundry and dry cleaning services
# ------------------------------------------------------------------
# num categories: 74
# category id|name: 8105.0|Laundry equipment
# ------------------------------------------------------------------
# num categories: 75
# category id|name: 3380.0|Lettuce
# ------------------------------------------------------------------
# num categories: 76
# category id|name: 1265.0|Margarine
# ------------------------------------------------------------------
# num categories: 77
# category id|name: 6934.0|Men’s pants and shorts
# ------------------------------------------------------------------
# num categories: 78
# category id|name: 7018.0|Men’s shirts and sweaters
# ------------------------------------------------------------------
# num categories: 79
# category id|name: 2606.0|Men’s suits, sport coats, and outerwear
# ------------------------------------------------------------------
# num categories: 80
# category id|name: 9435.0|Motor oil, coolant, and fluids
# ------------------------------------------------------------------
# num categories: 81
# category id|name: 7497.0|Motor vehicle maintenance and servicing
# ------------------------------------------------------------------
# num categories: 82
# category id|name: 1809.0|Motor vehicle repair
# ------------------------------------------------------------------
# num categories: 83
# category id|name: 1344.0|Nursing homes and adult day services
# ------------------------------------------------------------------
# num categories: 84
# category id|name: 8497.0|Other bakery products
# ------------------------------------------------------------------
# num categories: 85
# category id|name: 3215.0|Other fresh fruits
# ------------------------------------------------------------------
# num categories: 86
# category id|name: 1494.0|Other fresh vegetables
# ------------------------------------------------------------------
# num categories: 87
# category id|name: 9574.0|Other intercity transportation
# ------------------------------------------------------------------
# num categories: 88
# category id|name: 4418.0|Other lodging away from home including hotels and motels
# ------------------------------------------------------------------
# num categories: 89
# category id|name: 4535.0|Other meats
# ------------------------------------------------------------------
# num categories: 90
# category id|name: 5930.0|Other miscellaneous foods
# ------------------------------------------------------------------
# num categories: 91
# category id|name: 3337.0|Other processed fruits and vegetables including dried
# ------------------------------------------------------------------
# num categories: 92
# category id|name: 2972.0|Owners’ equivalent rent of primary residence
# ------------------------------------------------------------------
# num categories: 93
# category id|name: 759.0|Parking and other fees
# ------------------------------------------------------------------
# num categories: 94
# category id|name: 3292.0|Physicians’ services
# ------------------------------------------------------------------
# num categories: 95
# category id|name: 5855.0|Pork
# ------------------------------------------------------------------
# num categories: 96
# category id|name: 8784.0|Postage
# ------------------------------------------------------------------
# num categories: 97
# category id|name: 8287.0|Potatoes
# ------------------------------------------------------------------
# num categories: 98
# category id|name: 9948.0|Poultry
# ------------------------------------------------------------------
# num categories: 99
# category id|name: 7147.0|Rice
# ------------------------------------------------------------------
# num categories: 100
# category id|name: 1986.0|Roasted coffee
# ------------------------------------------------------------------
# num categories: 101
# category id|name: 1206.0|Services by other medical professionals
# ------------------------------------------------------------------
# num categories: 102
# category id|name: 7570.0|Snacks
# ------------------------------------------------------------------
# num categories: 103
# category id|name: 1351.0|Soups
# ------------------------------------------------------------------
# num categories: 104
# category id|name: 4846.0|Spices, seasonings, condiments, sauces
# ------------------------------------------------------------------
# num categories: 105
# category id|name: 1183.0|State motor vehicle registration and license fees
# ------------------------------------------------------------------
# num categories: 106
# category id|name: 3162.0|Technical and business school tuition and fees
# ------------------------------------------------------------------
# num categories: 107
# category id|name: 5692.0|Tomatoes
# ------------------------------------------------------------------
# num categories: 108
# category id|name: 8350.0|Toys, games, hobbies and playground equipment
# ------------------------------------------------------------------
# num categories: 109
# category id|name: 307.0|Vehicle parts and equipment other than tires
# ------------------------------------------------------------------
# num categories: 110
# category id|name: 9003.0|Veterinarian services
# ------------------------------------------------------------------
# num categories: 111
# category id|name: 2132.0|Whiskey at home
# ------------------------------------------------------------------
# num categories: 112
# category id|name: 655.0|Wireless telephone services
# ------------------------------------------------------------------
# num categories: 113
# category id|name: 452.0|Women’s dresses
# ------------------------------------------------------------------
# num categories: 114
# category id|name: 7718.0|Women’s outerwear
# ------------------------------------------------------------------
# num categories: 115
# category id|name: 9350.0|Women’s suits and separates
# ------------------------------------------------------------------
# num categories: 116
# category id|name: 9498.0|Women’s underwear, nightwear, sportswear and accessories
# ------------------------------------------------------------------
# num categories: 117
# category id|name: 7859.0|Audio equipment
# ------------------------------------------------------------------
# num categories: 118
# category id|name: 8566.0|Bakery products
# ------------------------------------------------------------------
# num categories: 119
# category id|name: 6797.0|Bedroom furniture
# ------------------------------------------------------------------
# num categories: 120
# category id|name: 2456.0|Beer, ale, and other malt beverages at home
# ------------------------------------------------------------------
# num categories: 121
# category id|name: 9333.0|Beer, ale, and other malt beverages away from home
# ------------------------------------------------------------------
# num categories: 122
# category id|name: 9448.0|Boys’ and girls’ footwear
# ------------------------------------------------------------------
# num categories: 123
# category id|name: 3935.0|Boys’ apparel
# ------------------------------------------------------------------
# num categories: 124
# category id|name: 6944.0|Breakfast cereal
# ------------------------------------------------------------------
# num categories: 125
# category id|name: 3369.0|Butter and margarine
# ------------------------------------------------------------------
# num categories: 126
# category id|name: 741.0|Candy and chewing gum
# ------------------------------------------------------------------
# num categories: 127
# category id|name: 1556.0|Car and truck rental
# ------------------------------------------------------------------
# num categories: 128
# category id|name: 6104.0|Carbonated drinks
# ------------------------------------------------------------------
# num categories: 129
# category id|name: 4451.0|Cigarettes
# ------------------------------------------------------------------
# num categories: 130
# category id|name: 4790.0|Clocks, lamps, and decorator items
# ------------------------------------------------------------------
# num categories: 131
# category id|name: 6082.0|Coffee
# ------------------------------------------------------------------
# num categories: 132
# category id|name: 7979.0|College textbooks
# ------------------------------------------------------------------
# num categories: 133
# category id|name: 6021.0|Computer software and accessories
# ------------------------------------------------------------------
# num categories: 134
# category id|name: 9308.0|Cosmetics, perfume, bath, nail preparations and implements
# ------------------------------------------------------------------
# num categories: 135
# category id|name: 3747.0|Dishes and flatware
# ------------------------------------------------------------------
# num categories: 136
# category id|name: 6418.0|Distilled spirits at home
# ------------------------------------------------------------------
# num categories: 137
# category id|name: 5556.0|Eggs
# ------------------------------------------------------------------
# num categories: 138
# category id|name: 7171.0|Floor coverings
# ------------------------------------------------------------------
# num categories: 139
# category id|name: 5489.0|Flour and prepared flour mixes
# ------------------------------------------------------------------
# num categories: 140
# category id|name: 8524.0|Fresh fruits
# ------------------------------------------------------------------
# num categories: 141
# category id|name: 1223.0|Fresh milk other than whole
# ------------------------------------------------------------------
# num categories: 142
# category id|name: 6147.0|Fresh vegetables
# ------------------------------------------------------------------
# num categories: 143
# category id|name: 2000.0|Fresh whole milk
# ------------------------------------------------------------------
# num categories: 144
# category id|name: 8552.0|Frozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 145
# category id|name: 5291.0|Garbage and trash collection
# ------------------------------------------------------------------
# num categories: 146
# category id|name: 5687.0|Gasoline, unleaded midgrade
# ------------------------------------------------------------------
# num categories: 147
# category id|name: 6324.0|Gasoline, unleaded premium
# ------------------------------------------------------------------
# num categories: 148
# category id|name: 4879.0|Gasoline, unleaded regular
# ------------------------------------------------------------------
# num categories: 149
# category id|name: 7561.0|Girls’ apparel
# ------------------------------------------------------------------
# num categories: 150
# category id|name: 6501.0|Hair, dental, shaving, and miscellaneous personal care products
# ------------------------------------------------------------------
# num categories: 151
# category id|name: 4532.0|Health insurance
# ------------------------------------------------------------------
# num categories: 152
# category id|name: 2710.0|Hospital and related services
# ------------------------------------------------------------------
# num categories: 153
# category id|name: 6610.0|Household cleaning products
# ------------------------------------------------------------------
# num categories: 154
# category id|name: 5202.0|Household paper products
# ------------------------------------------------------------------
# num categories: 155
# category id|name: 6096.0|Indoor plants and flowers
# ------------------------------------------------------------------
# num categories: 156
# category id|name: 4310.0|Internet services and electronic information providers
# ------------------------------------------------------------------
# num categories: 157
# category id|name: 3237.0|Jewelry
# ------------------------------------------------------------------
# num categories: 158
# category id|name: 2452.0|Living room, kitchen, and dining room furniture
# ------------------------------------------------------------------
# num categories: 159
# category id|name: 5762.0|Lodging away from home
# ------------------------------------------------------------------
# num categories: 160
# category id|name: 5082.0|Major appliances
# ------------------------------------------------------------------
# num categories: 161
# category id|name: 5354.0|Meats
# ------------------------------------------------------------------
# num categories: 162
# category id|name: 7821.0|Men’s apparel
# ------------------------------------------------------------------
# num categories: 163
# category id|name: 369.0|Men’s footwear
# ------------------------------------------------------------------
# num categories: 164
# category id|name: 8293.0|Miscellaneous household products
# ------------------------------------------------------------------
# num categories: 165
# category id|name: 6567.0|Miscellaneous personal services
# ------------------------------------------------------------------
# num categories: 166
# category id|name: 505.0|Motor vehicle fees
# ------------------------------------------------------------------
# num categories: 167
# category id|name: 6978.0|Motor vehicle insurance
# ------------------------------------------------------------------
# num categories: 168
# category id|name: 9790.0|Motor vehicle maintenance and repair
# ------------------------------------------------------------------
# num categories: 169
# category id|name: 133.0|Moving, storage, freight expense
# ------------------------------------------------------------------
# num categories: 170
# category id|name: 3628.0|Music instruments and accessories
# ------------------------------------------------------------------
# num categories: 171
# category id|name: 5782.0|New cars
# ------------------------------------------------------------------
# num categories: 172
# category id|name: 9870.0|New trucks
# ------------------------------------------------------------------
# num categories: 173
# category id|name: 7582.0|Newspapers and magazines
# ------------------------------------------------------------------
# num categories: 174
# category id|name: 9874.0|Nonelectric cookware and tableware
# ------------------------------------------------------------------
# num categories: 175
# category id|name: 7335.0|Nonfrozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 176
# category id|name: 8558.0|Nonprescription drugs
# ------------------------------------------------------------------
# num categories: 177
# category id|name: 1467.0|Other appliances
# ------------------------------------------------------------------
# num categories: 178
# category id|name: 7028.0|Other beverage materials including tea
# ------------------------------------------------------------------
# num categories: 179
# category id|name: 6039.0|Other fats and oils including peanut butter
# ------------------------------------------------------------------
# num categories: 180
# category id|name: 9728.0|Other foods
# ------------------------------------------------------------------
# num categories: 181
# category id|name: 7326.0|Other furniture
# ------------------------------------------------------------------
# num categories: 182
# category id|name: 5777.0|Other linens
# ------------------------------------------------------------------
# num categories: 183
# category id|name: 9744.0|Other recreation services
# ------------------------------------------------------------------
# num categories: 184
# category id|name: 315.0|Other sweets
# ------------------------------------------------------------------
# num categories: 185
# category id|name: 4138.0|Other video equipment
# ------------------------------------------------------------------
# num categories: 186
# category id|name: 4623.0|Outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 187
# category id|name: 1191.0|Personal care services
# ------------------------------------------------------------------
# num categories: 188
# category id|name: 980.0|Personal computers and peripheral equipment
# ------------------------------------------------------------------
# num categories: 189
# category id|name: 4226.0|Pet food
# ------------------------------------------------------------------
# num categories: 190
# category id|name: 1219.0|Pet services including veterinary
# ------------------------------------------------------------------
# num categories: 191
# category id|name: 2424.0|Photographers and film processing
# ------------------------------------------------------------------
# num categories: 192
# category id|name: 6539.0|Photographic equipment
# ------------------------------------------------------------------
# num categories: 193
# category id|name: 594.0|Postage and delivery services
# ------------------------------------------------------------------
# num categories: 194
# category id|name: 1369.0|Prescription drugs
# ------------------------------------------------------------------
# num categories: 195
# category id|name: 9100.0|Processed fruits and vegetables
# ------------------------------------------------------------------
# num categories: 196
# category id|name: 3965.0|Professional services
# ------------------------------------------------------------------
# num categories: 197
# category id|name: 4134.0|Public transportation
# ------------------------------------------------------------------
# num categories: 198
# category id|name: 8808.0|Purchase of pets, pet supplies, accessories
# ------------------------------------------------------------------
# num categories: 199
# category id|name: 737.0|Recorded music and music subscriptions
# ------------------------------------------------------------------
# num categories: 200
# category id|name: 3331.0|Recreational books
# ------------------------------------------------------------------
# num categories: 201
# category id|name: 4363.0|Rent of primary residence
# ------------------------------------------------------------------
# num categories: 202
# category id|name: 3008.0|Rice, pasta, cornmeal
# ------------------------------------------------------------------
# num categories: 203
# category id|name: 7.0|Salad dressing
# ------------------------------------------------------------------
# num categories: 204
# category id|name: 8663.0|Sewing machines, fabric and supplies
# ------------------------------------------------------------------
# num categories: 205
# category id|name: 2216.0|Sports equipment
# ------------------------------------------------------------------
# num categories: 206
# category id|name: 4414.0|Sports vehicles including bicycles
# ------------------------------------------------------------------
# num categories: 207
# category id|name: 8917.0|Stationery, stationery supplies, gift wrap
# ------------------------------------------------------------------
# num categories: 208
# category id|name: 3199.0|Sugar and artificial sweeteners
# ------------------------------------------------------------------
# num categories: 209
# category id|name: 2940.0|Telephone hardware, calculators, and other consumer information items
# ------------------------------------------------------------------
# num categories: 210
# category id|name: 2405.0|Telephone services
# ------------------------------------------------------------------
# num categories: 211
# category id|name: 5433.0|Televisions
# ------------------------------------------------------------------
# num categories: 212
# category id|name: 7981.0|Tenants’ and household insurance
# ------------------------------------------------------------------
# num categories: 213
# category id|name: 6900.0|Tires
# ------------------------------------------------------------------
# num categories: 214
# category id|name: 620.0|Tobacco products other than cigarettes
# ------------------------------------------------------------------
# num categories: 215
# category id|name: 5668.0|Tools, hardware and supplies
# ------------------------------------------------------------------
# num categories: 216
# category id|name: 3103.0|Toys
# ------------------------------------------------------------------
# num categories: 217
# category id|name: 2308.0|Tuition, other school fees, and childcare
# ------------------------------------------------------------------
# num categories: 218
# category id|name: 1564.0|Vehicle accessories other than tires
# ------------------------------------------------------------------
# num categories: 219
# category id|name: 4757.0|Video and audio services
# ------------------------------------------------------------------
# num categories: 220
# category id|name: 6459.0|Watches
# ------------------------------------------------------------------
# num categories: 221
# category id|name: 6884.0|Water and sewerage maintenance
# ------------------------------------------------------------------
# num categories: 222
# category id|name: 6848.0|Window coverings
# ------------------------------------------------------------------
# num categories: 223
# category id|name: 9946.0|Wine at home
# ------------------------------------------------------------------
# num categories: 224
# category id|name: 2743.0|Wine away from home
# ------------------------------------------------------------------
# num categories: 225
# category id|name: 8387.0|Women’s apparel
# ------------------------------------------------------------------
# num categories: 226
# category id|name: 4044.0|Women’s footwear
# ------------------------------------------------------------------
# num categories: 227
# category id|name: 2422.0|Alcoholic beverages at home
# ------------------------------------------------------------------
# num categories: 228
# category id|name: 5080.0|Alcoholic beverages away from home
# ------------------------------------------------------------------
# num categories: 229
# category id|name: 3958.0|Appliances
# ------------------------------------------------------------------
# num categories: 230
# category id|name: 7177.0|Beverage materials including coffee and tea
# ------------------------------------------------------------------
# num categories: 231
# category id|name: 232.0|Cereals and cereal products
# ------------------------------------------------------------------
# num categories: 232
# category id|name: 1043.0|Cheese and related products
# ------------------------------------------------------------------
# num categories: 233
# category id|name: 3707.0|Education and communication services
# ------------------------------------------------------------------
# num categories: 234
# category id|name: 5985.0|Educational books and supplies
# ------------------------------------------------------------------
# num categories: 235
# category id|name: 3612.0|Fats and oils
# ------------------------------------------------------------------
# num categories: 236
# category id|name: 7182.0|Footwear
# ------------------------------------------------------------------
# num categories: 237
# category id|name: 4607.0|Fresh fruits and vegetables
# ------------------------------------------------------------------
# num categories: 238
# category id|name: 5177.0|Fuel oil
# ------------------------------------------------------------------
# num categories: 239
# category id|name: 730.0|Furniture and bedding
# ------------------------------------------------------------------
# num categories: 240
# category id|name: 789.0|Gasoline all types
# ------------------------------------------------------------------
# num categories: 241
# category id|name: 2307.0|Housekeeping supplies
# ------------------------------------------------------------------
# num categories: 242
# category id|name: 6801.0|Ice cream and related products
# ------------------------------------------------------------------
# num categories: 243
# category id|name: 2101.0|Infants’ and toddlers’ apparel
# ------------------------------------------------------------------
# num categories: 244
# category id|name: 7569.0|Information technology commodities
# ------------------------------------------------------------------
# num categories: 245
# category id|name: 546.0|Jewelry and watches
# ------------------------------------------------------------------
# num categories: 246
# category id|name: 8886.0|Juices and nonalcoholic drinks
# ------------------------------------------------------------------
# num categories: 247
# category id|name: 7803.0|Medical care services
# ------------------------------------------------------------------
# num categories: 248
# category id|name: 3514.0|Medical equipment and supplies
# ------------------------------------------------------------------
# num categories: 249
# category id|name: 5658.0|Medicinal drugs
# ------------------------------------------------------------------
# num categories: 250
# category id|name: 2395.0|Men’s and boys’ apparel
# ------------------------------------------------------------------
# num categories: 251
# category id|name: 4634.0|Milk
# ------------------------------------------------------------------
# num categories: 252
# category id|name: 1381.0|Miscellaneous personal goods
# ------------------------------------------------------------------
# num categories: 253
# category id|name: 4291.0|New vehicles
# ------------------------------------------------------------------
# num categories: 254
# category id|name: 5142.0|Other dairy and related products
# ------------------------------------------------------------------
# num categories: 255
# category id|name: 6715.0|Other household equipment and furnishings
# ------------------------------------------------------------------
# num categories: 256
# category id|name: 8206.0|Other motor fuels
# ------------------------------------------------------------------
# num categories: 257
# category id|name: 2259.0|Other personal services
# ------------------------------------------------------------------
# num categories: 258
# category id|name: 4278.0|Other recreational goods
# ------------------------------------------------------------------
# num categories: 259
# category id|name: 1231.0|Personal care products
# ------------------------------------------------------------------
# num categories: 260
# category id|name: 7156.0|Pets and pet products
# ------------------------------------------------------------------
# num categories: 261
# category id|name: 8921.0|Photographic equipment and supplies
# ------------------------------------------------------------------
# num categories: 262
# category id|name: 2320.0|Propane, kerosene, and firewood
# ------------------------------------------------------------------
# num categories: 263
# category id|name: 8585.0|Recreation services
# ------------------------------------------------------------------
# num categories: 264
# category id|name: 7963.0|Recreational reading materials
# ------------------------------------------------------------------
# num categories: 265
# category id|name: 8577.0|Rent of shelter
# ------------------------------------------------------------------
# num categories: 266
# category id|name: 172.0|Sporting goods
# ------------------------------------------------------------------
# num categories: 267
# category id|name: 7995.0|Sugar and sweets
# ------------------------------------------------------------------
# num categories: 268
# category id|name: 949.0|Tobacco and smoking products
# ------------------------------------------------------------------
# num categories: 269
# category id|name: 6044.0|Tools, hardware, outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 270
# category id|name: 6999.0|Transportation services
# ------------------------------------------------------------------
# num categories: 271
# category id|name: 5590.0|Video and audio products
# ------------------------------------------------------------------
# num categories: 272
# category id|name: 3706.0|Water and sewer and trash collection services
# ------------------------------------------------------------------
# num categories: 273
# category id|name: 8669.0|Window and floor coverings and other linens
# ------------------------------------------------------------------
# num categories: 274
# category id|name: 7374.0|Women’s and girls’ apparel
# ------------------------------------------------------------------
# num categories: 275
# category id|name: 7635.0|Alcoholic beverages
# ------------------------------------------------------------------
# num categories: 276
# category id|name: 5516.0|Apparel
# ------------------------------------------------------------------
# num categories: 277
# category id|name: 2948.0|Cereals and bakery products
# ------------------------------------------------------------------
# num categories: 278
# category id|name: 5341.0|Dairy and related products
# ------------------------------------------------------------------
# num categories: 279
# category id|name: 4699.0|Education and communication commodities
# ------------------------------------------------------------------
# num categories: 280
# category id|name: 1202.0|Electricity
# ------------------------------------------------------------------
# num categories: 281
# category id|name: 6369.0|Food from vending machines and mobile vendors
# ------------------------------------------------------------------
# num categories: 282
# category id|name: 9499.0|Fruits and vegetables
# ------------------------------------------------------------------
# num categories: 283
# category id|name: 416.0|Fuel oil and other fuels
# ------------------------------------------------------------------
# num categories: 284
# category id|name: 3598.0|Full service meals and snacks
# ------------------------------------------------------------------
# num categories: 285
# category id|name: 5562.0|Household furnishings and supplies
# ------------------------------------------------------------------
# num categories: 286
# category id|name: 8625.0|Information and information processing
# ------------------------------------------------------------------
# num categories: 287
# category id|name: 5358.0|Information technology, hardware and services
# ------------------------------------------------------------------
# num categories: 288
# category id|name: 8446.0|Limited service meals and snacks
# ------------------------------------------------------------------
# num categories: 289
# category id|name: 8516.0|Meats, poultry, fish, and eggs
# ------------------------------------------------------------------
# num categories: 290
# category id|name: 5635.0|Medical care commodities
# ------------------------------------------------------------------
# num categories: 291
# category id|name: 3840.0|Motor fuel
# ------------------------------------------------------------------
# num categories: 292
# category id|name: 2973.0|New and used motor vehicles
# ------------------------------------------------------------------
# num categories: 293
# category id|name: 6387.0|Nonalcoholic beverages and beverage materials
# ------------------------------------------------------------------
# num categories: 294
# category id|name: 4196.0|Other food at home
# ------------------------------------------------------------------
# num categories: 295
# category id|name: 1346.0|Other food away from home
# ------------------------------------------------------------------
# num categories: 296
# category id|name: 5557.0|Other goods
# ------------------------------------------------------------------
# num categories: 297
# category id|name: 6582.0|Recreation commodities
# ------------------------------------------------------------------
# num categories: 298
# category id|name: 8742.0|Shelter
# ------------------------------------------------------------------
# num categories: 299
# category id|name: 690.0|Transportation commodities less motor fuel
# ------------------------------------------------------------------
# num categories: 300
# category id|name: 5867.0|Commodities less food
# ------------------------------------------------------------------
# num categories: 301
# category id|name: 3891.0|Commodities less food and beverages
# ------------------------------------------------------------------
# num categories: 302
# category id|name: 4935.0|Commodities less food and energy commodities
# ------------------------------------------------------------------
# num categories: 303
# category id|name: 9826.0|Commodities less food, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 304
# category id|name: 5970.0|Communication
# ------------------------------------------------------------------
# num categories: 305
# category id|name: 612.0|Domestically produced farm food
# ------------------------------------------------------------------
# num categories: 306
# category id|name: 314.0|Education
# ------------------------------------------------------------------
# num categories: 307
# category id|name: 8995.0|Energy commodities
# ------------------------------------------------------------------
# num categories: 308
# category id|name: 4748.0|Energy services
# ------------------------------------------------------------------
# num categories: 309
# category id|name: 4200.0|Food at home
# ------------------------------------------------------------------
# num categories: 310
# category id|name: 1345.0|Food away from home
# ------------------------------------------------------------------
# num categories: 311
# category id|name: 396.0|Household energy
# ------------------------------------------------------------------
# num categories: 312
# category id|name: 6247.0|Nondurables less food
# ------------------------------------------------------------------
# num categories: 313
# category id|name: 5488.0|Nondurables less food and apparel
# ------------------------------------------------------------------
# num categories: 314
# category id|name: 7080.0|Nondurables less food and beverages
# ------------------------------------------------------------------
# num categories: 315
# category id|name: 1465.0|Nondurables less food, beverages, and apparel
# ------------------------------------------------------------------
# num categories: 316
# category id|name: 6986.0|Personal care
# ------------------------------------------------------------------
# num categories: 317
# category id|name: 9321.0|Pets, pet products and services
# ------------------------------------------------------------------
# num categories: 318
# category id|name: 9325.0|Photography
# ------------------------------------------------------------------
# num categories: 319
# category id|name: 3815.0|Private transportation
# ------------------------------------------------------------------
# num categories: 320
# category id|name: 1033.0|Services less energy services
# ------------------------------------------------------------------
# num categories: 321
# category id|name: 5145.0|Services less medical care services
# ------------------------------------------------------------------
# num categories: 322
# category id|name: 9058.0|Services less rent of shelter
# ------------------------------------------------------------------
# num categories: 323
# category id|name: 5618.0|Video and audio
# ------------------------------------------------------------------
# num categories: 324
# category id|name: 4604.0|All items less energy
# ------------------------------------------------------------------
# num categories: 325
# category id|name: 3531.0|All items less food
# ------------------------------------------------------------------
# num categories: 326
# category id|name: 5306.0|All items less food and energy
# ------------------------------------------------------------------
# num categories: 327
# category id|name: 4114.0|All items less food and shelter
# ------------------------------------------------------------------
# num categories: 328
# category id|name: 5789.0|All items less food, shelter, and energy
# ------------------------------------------------------------------
# num categories: 329
# category id|name: 2208.0|All items less food, shelter, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 330
# category id|name: 2047.0|All items less medical care
# ------------------------------------------------------------------
# num categories: 331
# category id|name: 7199.0|All items less shelter
# ------------------------------------------------------------------
# num categories: 332
# category id|name: 3242.0|Apparel less footwear
# ------------------------------------------------------------------
# num categories: 333
# category id|name: 704.0|Commodities
# ------------------------------------------------------------------
# num categories: 334
# category id|name: 2665.0|Durables
# ------------------------------------------------------------------
# num categories: 335
# category id|name: 1868.0|Education and communication
# ------------------------------------------------------------------
# num categories: 336
# category id|name: 7558.0|Energy
# ------------------------------------------------------------------
# num categories: 337
# category id|name: 4934.0|Food
# ------------------------------------------------------------------
# num categories: 338
# category id|name: 9257.0|Food and beverages
# ------------------------------------------------------------------
# num categories: 339
# category id|name: 5463.0|Fuels and utilities
# ------------------------------------------------------------------
# num categories: 340
# category id|name: 9339.0|Household furnishings and operations
# ------------------------------------------------------------------
# num categories: 341
# category id|name: 6803.0|Housing
# ------------------------------------------------------------------
# num categories: 342
# category id|name: 3411.0|Medical care
# ------------------------------------------------------------------
# num categories: 343
# category id|name: 818.0|Nondurables
# ------------------------------------------------------------------
# num categories: 344
# category id|name: 8488.0|Other goods and services
# ------------------------------------------------------------------
# num categories: 345
# category id|name: 6741.0|Other services
# ------------------------------------------------------------------
# num categories: 346
# category id|name: 8575.0|Recreation
# ------------------------------------------------------------------
# num categories: 347
# category id|name: 9735.0|Services
# ------------------------------------------------------------------
# num categories: 348
# category id|name: 6812.0|Transportation
# ------------------------------------------------------------------
# num categories: 349
# category id|name: 7939.0|Utilities and public transportation
# ------------------------------------------------------------------
# num categories: 350
# category id|name: 8106.0|All items
# ------------------------------------------------------------------

# %%
predictions_dict_2 = get_results_on_test_set(weightspath_2, train_dataset_dict, test_dataset_dict, categories = categories)
with open(test_predictions_path_2, 'wb') as handle:
    pickle.dump(predictions_dict_2, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Admission to movies, theaters, and concerts
# Bacon, breakfast sausage, and related products
# Bread other than white
# Canned fruits
# Canned vegetables
# Checking account and other bank services
# Chicken
# Cookies
# Crackers, bread, and cracker products
# Dried beans, peas, and lentils
# Frankfurters
# Fresh cakes and cupcakes
# Fresh fish and seafood
# Fresh sweetrolls, coffeecakes, doughnuts
# Frozen and refrigerated bakery products, pies, tarts, turnovers
# Frozen vegetables
# Ham
# Intracity mass transit
# Lunchmeats
# Oranges, including tangerines
# Other condiments
# Other pork including roasts and picnics
# Other uncooked poultry including turkey
# Parking fees and tolls
# Pork chops
# Prepared salads
# Processed fish and seafood
# Salt and other seasonings and spices
# Sauces and gravies
# Ship fare
# Uncooked beef roasts
# Uncooked beef steaks
# Uncooked ground beef
# Uncooked other beef and veal
# Video discs and other media
# White bread
# Admissions
# Airline fare
# Apparel services other than laundry and dry cleaning
# Apples
# Bananas
# Beef and veal
# Bread
# Butter
# Cakes, cupcakes, and cookies
# Canned fruits and vegetables
# Child care and nursery school
# Citrus fruits
# College tuition and fees
# Delivery services
# Dental services
# Distilled spirits, excluding whiskey, at home
# Elementary and high school tuition and fees
# Eyeglasses and eye care
# Financial services
# Fish and seafood
# Fresh biscuits, rolls, muffins
# Frozen and freeze dried prepared foods
# Frozen fruits and vegetables
# Funeral expenses
# Haircuts and other personal care services
# Housing at school, excluding board
# Instant and freeze dried coffee
# Intracity transportation
# Land-line telephone services
# Laundry and dry cleaning services
# Laundry equipment
# Lettuce
# Margarine
# Men’s pants and shorts
# Men’s shirts and sweaters
# Men’s suits, sport coats, and outerwear
# Motor oil, coolant, and fluids
# Motor vehicle maintenance and servicing
# Motor vehicle repair
# Nursing homes and adult day services
# Other bakery products
# Other fresh fruits
# Other fresh vegetables
# Other intercity transportation
# Other lodging away from home including hotels and motels
# Other meats
# Other miscellaneous foods
# Other processed fruits and vegetables including dried
# Owners’ equivalent rent of primary residence
# Parking and other fees
# Physicians’ services
# Pork
# Postage
# Potatoes
# Poultry
# Rice
# Roasted coffee
# Services by other medical professionals
# Snacks
# Soups
# Spices, seasonings, condiments, sauces
# State motor vehicle registration and license fees
# Technical and business school tuition and fees
# Tomatoes
# Toys, games, hobbies and playground equipment
# Vehicle parts and equipment other than tires
# Veterinarian services
# Whiskey at home
# Wireless telephone services
# Women’s dresses
# Women’s outerwear
# Women’s suits and separates
# Women’s underwear, nightwear, sportswear and accessories
# Alcoholic beverages
# Apparel
# Cereals and bakery products
# Dairy and related products
# Education and communication commodities
# Electricity
# Food from vending machines and mobile vendors
# Fruits and vegetables
# Fuel oil and other fuels
# Full service meals and snacks
# Household furnishings and supplies
# Information and information processing
# Information technology, hardware and services
# Limited service meals and snacks
# Meats, poultry, fish, and eggs
# Medical care commodities
# Motor fuel
# New and used motor vehicles
# Nonalcoholic beverages and beverage materials
# Other food at home
# Other food away from home
# Other goods
# Recreation commodities
# Shelter
# Transportation commodities less motor fuel
# Alcoholic beverages at home
# Alcoholic beverages away from home
# Appliances
# Beverage materials including coffee and tea
# Cereals and cereal products
# Cheese and related products
# Education and communication services
# Educational books and supplies
# Fats and oils
# Footwear
# Fresh fruits and vegetables
# Fuel oil
# Furniture and bedding
# Gasoline all types
# Housekeeping supplies
# Ice cream and related products
# Infants’ and toddlers’ apparel
# Information technology commodities
# Jewelry and watches
# Juices and nonalcoholic drinks
# Medical care services
# Medical equipment and supplies
# Medicinal drugs
# Men’s and boys’ apparel
# Milk
# Miscellaneous personal goods
# New vehicles
# Other dairy and related products
# Other household equipment and furnishings
# Other motor fuels
# Other personal services
# Other recreational goods
# Personal care products
# Pets and pet products
# Photographic equipment and supplies
# Propane, kerosene, and firewood
# Recreation services
# Recreational reading materials
# Rent of shelter
# Sporting goods
# Sugar and sweets
# Tobacco and smoking products
# Tools, hardware, outdoor equipment and supplies
# Transportation services
# Video and audio products
# Water and sewer and trash collection services
# Window and floor coverings and other linens
# Women’s and girls’ apparel
# All items
# All items less energy
# All items less food
# All items less food and energy
# All items less food and shelter
# All items less food, shelter, and energy
# All items less food, shelter, energy, and used cars and trucks
# All items less medical care
# All items less shelter
# Apparel less footwear
# Commodities
# Durables
# Education and communication
# Energy
# Food
# Fuels and utilities
# Household furnishings and operations
# Housing
# Medical care
# Nondurables
# Other goods and services
# Other services
# Recreation
# Services
# Transportation
# Utilities and public transportation
# Audio equipment
# Bakery products
# Bedroom furniture
# Beer, ale, and other malt beverages at home
# Beer, ale, and other malt beverages away from home
# Boys’ and girls’ footwear
# Boys’ apparel
# Breakfast cereal
# Butter and margarine
# Candy and chewing gum
# Car and truck rental
# Carbonated drinks
# Cigarettes
# Clocks, lamps, and decorator items
# Coffee
# College textbooks
# Computer software and accessories
# Cosmetics, perfume, bath, nail preparations and implements
# Dishes and flatware
# Distilled spirits at home
# Eggs
# Floor coverings
# Flour and prepared flour mixes
# Fresh fruits
# Fresh milk other than whole
# Fresh vegetables
# Fresh whole milk
# Frozen noncarbonated juices and drinks
# Garbage and trash collection
# Gasoline, unleaded midgrade
# Gasoline, unleaded premium
# Gasoline, unleaded regular
# Girls’ apparel
# Hair, dental, shaving, and miscellaneous personal care products
# Health insurance
# Hospital and related services
# Household cleaning products
# Household paper products
# Indoor plants and flowers
# Internet services and electronic information providers
# Jewelry
# Living room, kitchen, and dining room furniture
# Lodging away from home
# Major appliances
# Meats
# Men’s apparel
# Men’s footwear
# Miscellaneous household products
# Miscellaneous personal services
# Motor vehicle fees
# Motor vehicle insurance
# Motor vehicle maintenance and repair
# Moving, storage, freight expense
# Music instruments and accessories
# New cars
# New trucks
# Newspapers and magazines
# Nonelectric cookware and tableware
# Nonfrozen noncarbonated juices and drinks
# Nonprescription drugs
# Other appliances
# Other beverage materials including tea
# Other fats and oils including peanut butter
# Other foods
# Other furniture
# Other linens
# Other recreation services
# Other sweets
# Other video equipment
# Outdoor equipment and supplies
# Personal care services
# Personal computers and peripheral equipment
# Pet food
# Pet services including veterinary
# Photographers and film processing
# Photographic equipment
# Postage and delivery services
# Prescription drugs
# Processed fruits and vegetables
# Professional services
# Public transportation
# Purchase of pets, pet supplies, accessories
# Recorded music and music subscriptions
# Recreational books
# Rent of primary residence
# Rice, pasta, cornmeal
# Salad dressing
# Sewing machines, fabric and supplies
# Sports equipment
# Sports vehicles including bicycles
# Stationery, stationery supplies, gift wrap
# Sugar and artificial sweeteners
# Telephone hardware, calculators, and other consumer information items
# Telephone services
# Televisions
# Tenants’ and household insurance
# Tires
# Tobacco products other than cigarettes
# Tools, hardware and supplies
# Toys
# Tuition, other school fees, and childcare
# Vehicle accessories other than tires
# Video and audio services
# Watches
# Water and sewerage maintenance
# Window coverings
# Wine at home
# Wine away from home
# Women’s apparel
# Women’s footwear
# Bacon and related products
# Breakfast sausage and related products
# Fresh and frozen chicken parts
# Fresh whole chicken
# Frozen fish and seafood
# Ham, excluding canned
# Shelf stable fish and seafood
# Commodities less food
# Commodities less food and beverages
# Commodities less food and energy commodities
# Commodities less food, energy, and used cars and trucks
# Communication
# Domestically produced farm food
# Education
# Energy commodities
# Energy services
# Food at home
# Food away from home
# Household energy
# Nondurables less food
# Nondurables less food and apparel
# Nondurables less food and beverages
# Nondurables less food, beverages, and apparel
# Personal care
# Pets, pet products and services
# Photography
# Private transportation
# Services less energy services
# Services less medical care services
# Services less rent of shelter
# Video and audio

# %% [markdown]
# # Loss Analysis 3:

# %% [markdown]
# No Loss Term 3:

# %%
weightspath_3
# Out:
# '/Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_3/'

# %%
def bi_directional_model_3(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weights_path, hgru_weight_dict, coefficient_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha):
    # deleting files in models_weights folder
    path = os.getcwd()
    desired_path = path + '/models_weights_3/'
    is_empty = not any(Path(desired_path).iterdir())

    if is_empty==False:
        rmdir(Path(desired_path))
    
    # deleting empty folder
    try:
        os.rmdir(desired_path)
    except OSError:
        print ("Deletion of the directory %s failed" % desired_path)
    else:
        print ("Successfully deleted the directory %s" % desired_path)

    # creating new folder
    try:
        os.mkdir(desired_path)
    except OSError:
        print ("Creation of the directory %s failed" % desired_path)
    else:
        print ("Successfully created the directory %s" % desired_path)
    #----------------------------------------------------------------------------------------------------------------------------------------------#
    loss_coef_1= 8.092430201147471*np.exp(-7)
    loss_coef_2= 0.0001
    loss_coef_3= 0
    num_categories = 0
    bidrectional_models = {}

    for indent in sorted(list(categories_per_indent_dict.keys()),reverse=True):
        for category in categories_per_indent_dict[indent]:
            num_categories +=1
            print(f'num categories: {num_categories}')
            category_name = category_id_to_name_dict[category]
            print(f'category id|name: {category}|{category_name}')

            if int(indent) == 0 or son_parent_dict[category] not in categories_per_indent_dict[indent-1]: 
                loss_coef_1 = 0


            if (category not in list(parent_to_son_list_dict.keys())) or (set(parent_to_son_list_dict[category]['sons']).issubset(set(categories_per_indent_dict[indent+1]))):
                loss_coef_2 = 0

            
            print('------------------------------------------------------------------')
            
            train_dataloader, test_dataloader = create_dataloader(train_dataset_dict[category_name], test_dataset_dict[category_name])
            model = Model
            optimizer = Optimizer
            model.to(Device)
            saving_param_path = weights_path+category_name+'.pt'
            
            bidrectional_models[category_name] = training_and_evaluation(model, indent, train_dataloader, test_dataloader, optimizer, category, hgru_weight_dict, coefficient_dict, son_parent_dict, parent_to_son_list_dict, category_id_to_name_dict, loss_coef_1, loss_coef_2, loss_coef_3, alpha, saving_param_path)
            
    return bidrectional_models

# %%
bidrectional_models_3 = bi_directional_model_3(son_parent_dict, parent_to_son_list_dict, train_dataset_dict, test_dataset_dict, categories_per_indent_dict, category_id_to_name_dict, weightspath_3, hgru_weight_dict, coefficient_dict, loss_coef_1, loss_coef_2, 0, alpha)
# Out:
# Deletion of the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_3/ failed
# Successfully created the directory /Users/mvilenko/Library/CloudStorage/OneDrive-PayPal/hgru_clean/US/bidirectional/models_weights_3/
# num categories: 1
# category id|name: 9540.0|Bacon and related products
# ------------------------------------------------------------------
# num categories: 2
# category id|name: 8302.0|Breakfast sausage and related products
# ------------------------------------------------------------------
# num categories: 3
# category id|name: 2135.0|Fresh and frozen chicken parts
# ------------------------------------------------------------------
# num categories: 4
# category id|name: 3415.0|Fresh whole chicken
# ------------------------------------------------------------------
# num categories: 5
# category id|name: 4850.0|Frozen fish and seafood
# ------------------------------------------------------------------
# num categories: 6
# category id|name: 9972.0|Ham, excluding canned
# ------------------------------------------------------------------
# num categories: 7
# category id|name: 5846.0|Shelf stable fish and seafood
# ------------------------------------------------------------------
# num categories: 8
# category id|name: 290.0|Admission to movies, theaters, and concerts
# ------------------------------------------------------------------
# num categories: 9
# category id|name: 9102.0|Bacon, breakfast sausage, and related products
# ------------------------------------------------------------------
# num categories: 10
# category id|name: 4542.0|Bread other than white
# ------------------------------------------------------------------
# num categories: 11
# category id|name: 8257.0|Canned fruits
# ------------------------------------------------------------------
# num categories: 12
# category id|name: 2158.0|Canned vegetables
# ------------------------------------------------------------------
# num categories: 13
# category id|name: 9594.0|Checking account and other bank services
# ------------------------------------------------------------------
# num categories: 14
# category id|name: 1270.0|Chicken
# ------------------------------------------------------------------
# num categories: 15
# category id|name: 4182.0|Cookies
# ------------------------------------------------------------------
# num categories: 16
# category id|name: 9136.0|Crackers, bread, and cracker products
# ------------------------------------------------------------------
# num categories: 17
# category id|name: 5319.0|Dried beans, peas, and lentils
# ------------------------------------------------------------------
# num categories: 18
# category id|name: 4003.0|Frankfurters
# ------------------------------------------------------------------
# num categories: 19
# category id|name: 597.0|Fresh cakes and cupcakes
# ------------------------------------------------------------------
# num categories: 20
# category id|name: 7000.0|Fresh fish and seafood
# ------------------------------------------------------------------
# num categories: 21
# category id|name: 4288.0|Fresh sweetrolls, coffeecakes, doughnuts
# ------------------------------------------------------------------
# num categories: 22
# category id|name: 3655.0|Frozen and refrigerated bakery products, pies, tarts, turnovers
# ------------------------------------------------------------------
# num categories: 23
# category id|name: 8965.0|Frozen vegetables
# ------------------------------------------------------------------
# num categories: 24
# category id|name: 3234.0|Ham
# ------------------------------------------------------------------
# num categories: 25
# category id|name: 17.0|Intracity mass transit
# ------------------------------------------------------------------
# num categories: 26
# category id|name: 3829.0|Lunchmeats
# ------------------------------------------------------------------
# num categories: 27
# category id|name: 8352.0|Oranges, including tangerines
# ------------------------------------------------------------------
# num categories: 28
# category id|name: 2190.0|Other condiments
# ------------------------------------------------------------------
# num categories: 29
# category id|name: 8666.0|Other pork including roasts and picnics
# ------------------------------------------------------------------
# num categories: 30
# category id|name: 6263.0|Other uncooked poultry including turkey
# ------------------------------------------------------------------
# num categories: 31
# category id|name: 6375.0|Parking fees and tolls
# ------------------------------------------------------------------
# num categories: 32
# category id|name: 4791.0|Pork chops
# ------------------------------------------------------------------
# num categories: 33
# category id|name: 2722.0|Prepared salads
# ------------------------------------------------------------------
# num categories: 34
# category id|name: 8830.0|Processed fish and seafood
# ------------------------------------------------------------------
# num categories: 35
# category id|name: 5517.0|Salt and other seasonings and spices
# ------------------------------------------------------------------
# num categories: 36
# category id|name: 8728.0|Sauces and gravies
# ------------------------------------------------------------------
# num categories: 37
# category id|name: 5148.0|Ship fare
# ------------------------------------------------------------------
# num categories: 38
# category id|name: 2136.0|Uncooked beef roasts
# ------------------------------------------------------------------
# num categories: 39
# category id|name: 1842.0|Uncooked beef steaks
# ------------------------------------------------------------------
# num categories: 40
# category id|name: 5192.0|Uncooked ground beef
# ------------------------------------------------------------------
# num categories: 41
# category id|name: 7339.0|Uncooked other beef and veal
# ------------------------------------------------------------------
# num categories: 42
# category id|name: 6541.0|Video discs and other media
# ------------------------------------------------------------------
# num categories: 43
# category id|name: 4282.0|White bread
# ------------------------------------------------------------------
# num categories: 44
# category id|name: 9746.0|Admissions
# ------------------------------------------------------------------
# num categories: 45
# category id|name: 935.0|Airline fare
# ------------------------------------------------------------------
# num categories: 46
# category id|name: 7034.0|Apparel services other than laundry and dry cleaning
# ------------------------------------------------------------------
# num categories: 47
# category id|name: 4999.0|Apples
# ------------------------------------------------------------------
# num categories: 48
# category id|name: 3997.0|Bananas
# ------------------------------------------------------------------
# num categories: 49
# category id|name: 207.0|Beef and veal
# ------------------------------------------------------------------
# num categories: 50
# category id|name: 975.0|Bread
# ------------------------------------------------------------------
# num categories: 51
# category id|name: 4789.0|Butter
# ------------------------------------------------------------------
# num categories: 52
# category id|name: 8034.0|Cakes, cupcakes, and cookies
# ------------------------------------------------------------------
# num categories: 53
# category id|name: 2361.0|Canned fruits and vegetables
# ------------------------------------------------------------------
# num categories: 54
# category id|name: 7798.0|Child care and nursery school
# ------------------------------------------------------------------
# num categories: 55
# category id|name: 379.0|Citrus fruits
# ------------------------------------------------------------------
# num categories: 56
# category id|name: 3878.0|College tuition and fees
# ------------------------------------------------------------------
# num categories: 57
# category id|name: 3028.0|Delivery services
# ------------------------------------------------------------------
# num categories: 58
# category id|name: 9008.0|Dental services
# ------------------------------------------------------------------
# num categories: 59
# category id|name: 2863.0|Distilled spirits, excluding whiskey, at home
# ------------------------------------------------------------------
# num categories: 60
# category id|name: 4671.0|Elementary and high school tuition and fees
# ------------------------------------------------------------------
# num categories: 61
# category id|name: 7622.0|Eyeglasses and eye care
# ------------------------------------------------------------------
# num categories: 62
# category id|name: 7291.0|Financial services
# ------------------------------------------------------------------
# num categories: 63
# category id|name: 9469.0|Fish and seafood
# ------------------------------------------------------------------
# num categories: 64
# category id|name: 922.0|Fresh biscuits, rolls, muffins
# ------------------------------------------------------------------
# num categories: 65
# category id|name: 1434.0|Frozen and freeze dried prepared foods
# ------------------------------------------------------------------
# num categories: 66
# category id|name: 92.0|Frozen fruits and vegetables
# ------------------------------------------------------------------
# num categories: 67
# category id|name: 2175.0|Funeral expenses
# ------------------------------------------------------------------
# num categories: 68
# category id|name: 9359.0|Haircuts and other personal care services
# ------------------------------------------------------------------
# num categories: 69
# category id|name: 9153.0|Housing at school, excluding board
# ------------------------------------------------------------------
# num categories: 70
# category id|name: 4343.0|Instant and freeze dried coffee
# ------------------------------------------------------------------
# num categories: 71
# category id|name: 2740.0|Intracity transportation
# ------------------------------------------------------------------
# num categories: 72
# category id|name: 7646.0|Land-line telephone services
# ------------------------------------------------------------------
# num categories: 73
# category id|name: 4.0|Laundry and dry cleaning services
# ------------------------------------------------------------------
# num categories: 74
# category id|name: 8105.0|Laundry equipment
# ------------------------------------------------------------------
# num categories: 75
# category id|name: 3380.0|Lettuce
# ------------------------------------------------------------------
# num categories: 76
# category id|name: 1265.0|Margarine
# ------------------------------------------------------------------
# num categories: 77
# category id|name: 6934.0|Men’s pants and shorts
# ------------------------------------------------------------------
# num categories: 78
# category id|name: 7018.0|Men’s shirts and sweaters
# ------------------------------------------------------------------
# num categories: 79
# category id|name: 2606.0|Men’s suits, sport coats, and outerwear
# ------------------------------------------------------------------
# num categories: 80
# category id|name: 9435.0|Motor oil, coolant, and fluids
# ------------------------------------------------------------------
# num categories: 81
# category id|name: 7497.0|Motor vehicle maintenance and servicing
# ------------------------------------------------------------------
# num categories: 82
# category id|name: 1809.0|Motor vehicle repair
# ------------------------------------------------------------------
# num categories: 83
# category id|name: 1344.0|Nursing homes and adult day services
# ------------------------------------------------------------------
# num categories: 84
# category id|name: 8497.0|Other bakery products
# ------------------------------------------------------------------
# num categories: 85
# category id|name: 3215.0|Other fresh fruits
# ------------------------------------------------------------------
# num categories: 86
# category id|name: 1494.0|Other fresh vegetables
# ------------------------------------------------------------------
# num categories: 87
# category id|name: 9574.0|Other intercity transportation
# ------------------------------------------------------------------
# num categories: 88
# category id|name: 4418.0|Other lodging away from home including hotels and motels
# ------------------------------------------------------------------
# num categories: 89
# category id|name: 4535.0|Other meats
# ------------------------------------------------------------------
# num categories: 90
# category id|name: 5930.0|Other miscellaneous foods
# ------------------------------------------------------------------
# num categories: 91
# category id|name: 3337.0|Other processed fruits and vegetables including dried
# ------------------------------------------------------------------
# num categories: 92
# category id|name: 2972.0|Owners’ equivalent rent of primary residence
# ------------------------------------------------------------------
# num categories: 93
# category id|name: 759.0|Parking and other fees
# ------------------------------------------------------------------
# num categories: 94
# category id|name: 3292.0|Physicians’ services
# ------------------------------------------------------------------
# num categories: 95
# category id|name: 5855.0|Pork
# ------------------------------------------------------------------
# num categories: 96
# category id|name: 8784.0|Postage
# ------------------------------------------------------------------
# num categories: 97
# category id|name: 8287.0|Potatoes
# ------------------------------------------------------------------
# num categories: 98
# category id|name: 9948.0|Poultry
# ------------------------------------------------------------------
# num categories: 99
# category id|name: 7147.0|Rice
# ------------------------------------------------------------------
# num categories: 100
# category id|name: 1986.0|Roasted coffee
# ------------------------------------------------------------------
# num categories: 101
# category id|name: 1206.0|Services by other medical professionals
# ------------------------------------------------------------------
# num categories: 102
# category id|name: 7570.0|Snacks
# ------------------------------------------------------------------
# num categories: 103
# category id|name: 1351.0|Soups
# ------------------------------------------------------------------
# num categories: 104
# category id|name: 4846.0|Spices, seasonings, condiments, sauces
# ------------------------------------------------------------------
# num categories: 105
# category id|name: 1183.0|State motor vehicle registration and license fees
# ------------------------------------------------------------------
# num categories: 106
# category id|name: 3162.0|Technical and business school tuition and fees
# ------------------------------------------------------------------
# num categories: 107
# category id|name: 5692.0|Tomatoes
# ------------------------------------------------------------------
# num categories: 108
# category id|name: 8350.0|Toys, games, hobbies and playground equipment
# ------------------------------------------------------------------
# num categories: 109
# category id|name: 307.0|Vehicle parts and equipment other than tires
# ------------------------------------------------------------------
# num categories: 110
# category id|name: 9003.0|Veterinarian services
# ------------------------------------------------------------------
# num categories: 111
# category id|name: 2132.0|Whiskey at home
# ------------------------------------------------------------------
# num categories: 112
# category id|name: 655.0|Wireless telephone services
# ------------------------------------------------------------------
# num categories: 113
# category id|name: 452.0|Women’s dresses
# ------------------------------------------------------------------
# num categories: 114
# category id|name: 7718.0|Women’s outerwear
# ------------------------------------------------------------------
# num categories: 115
# category id|name: 9350.0|Women’s suits and separates
# ------------------------------------------------------------------
# num categories: 116
# category id|name: 9498.0|Women’s underwear, nightwear, sportswear and accessories
# ------------------------------------------------------------------
# num categories: 117
# category id|name: 7859.0|Audio equipment
# ------------------------------------------------------------------
# num categories: 118
# category id|name: 8566.0|Bakery products
# ------------------------------------------------------------------
# num categories: 119
# category id|name: 6797.0|Bedroom furniture
# ------------------------------------------------------------------
# num categories: 120
# category id|name: 2456.0|Beer, ale, and other malt beverages at home
# ------------------------------------------------------------------
# num categories: 121
# category id|name: 9333.0|Beer, ale, and other malt beverages away from home
# ------------------------------------------------------------------
# num categories: 122
# category id|name: 9448.0|Boys’ and girls’ footwear
# ------------------------------------------------------------------
# num categories: 123
# category id|name: 3935.0|Boys’ apparel
# ------------------------------------------------------------------
# num categories: 124
# category id|name: 6944.0|Breakfast cereal
# ------------------------------------------------------------------
# num categories: 125
# category id|name: 3369.0|Butter and margarine
# ------------------------------------------------------------------
# num categories: 126
# category id|name: 741.0|Candy and chewing gum
# ------------------------------------------------------------------
# num categories: 127
# category id|name: 1556.0|Car and truck rental
# ------------------------------------------------------------------
# num categories: 128
# category id|name: 6104.0|Carbonated drinks
# ------------------------------------------------------------------
# num categories: 129
# category id|name: 4451.0|Cigarettes
# ------------------------------------------------------------------
# num categories: 130
# category id|name: 4790.0|Clocks, lamps, and decorator items
# ------------------------------------------------------------------
# num categories: 131
# category id|name: 6082.0|Coffee
# ------------------------------------------------------------------
# num categories: 132
# category id|name: 7979.0|College textbooks
# ------------------------------------------------------------------
# num categories: 133
# category id|name: 6021.0|Computer software and accessories
# ------------------------------------------------------------------
# num categories: 134
# category id|name: 9308.0|Cosmetics, perfume, bath, nail preparations and implements
# ------------------------------------------------------------------
# num categories: 135
# category id|name: 3747.0|Dishes and flatware
# ------------------------------------------------------------------
# num categories: 136
# category id|name: 6418.0|Distilled spirits at home
# ------------------------------------------------------------------
# num categories: 137
# category id|name: 5556.0|Eggs
# ------------------------------------------------------------------
# num categories: 138
# category id|name: 7171.0|Floor coverings
# ------------------------------------------------------------------
# num categories: 139
# category id|name: 5489.0|Flour and prepared flour mixes
# ------------------------------------------------------------------
# num categories: 140
# category id|name: 8524.0|Fresh fruits
# ------------------------------------------------------------------
# num categories: 141
# category id|name: 1223.0|Fresh milk other than whole
# ------------------------------------------------------------------
# num categories: 142
# category id|name: 6147.0|Fresh vegetables
# ------------------------------------------------------------------
# num categories: 143
# category id|name: 2000.0|Fresh whole milk
# ------------------------------------------------------------------
# num categories: 144
# category id|name: 8552.0|Frozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 145
# category id|name: 5291.0|Garbage and trash collection
# ------------------------------------------------------------------
# num categories: 146
# category id|name: 5687.0|Gasoline, unleaded midgrade
# ------------------------------------------------------------------
# num categories: 147
# category id|name: 6324.0|Gasoline, unleaded premium
# ------------------------------------------------------------------
# num categories: 148
# category id|name: 4879.0|Gasoline, unleaded regular
# ------------------------------------------------------------------
# num categories: 149
# category id|name: 7561.0|Girls’ apparel
# ------------------------------------------------------------------
# num categories: 150
# category id|name: 6501.0|Hair, dental, shaving, and miscellaneous personal care products
# ------------------------------------------------------------------
# num categories: 151
# category id|name: 4532.0|Health insurance
# ------------------------------------------------------------------
# num categories: 152
# category id|name: 2710.0|Hospital and related services
# ------------------------------------------------------------------
# num categories: 153
# category id|name: 6610.0|Household cleaning products
# ------------------------------------------------------------------
# num categories: 154
# category id|name: 5202.0|Household paper products
# ------------------------------------------------------------------
# num categories: 155
# category id|name: 6096.0|Indoor plants and flowers
# ------------------------------------------------------------------
# num categories: 156
# category id|name: 4310.0|Internet services and electronic information providers
# ------------------------------------------------------------------
# num categories: 157
# category id|name: 3237.0|Jewelry
# ------------------------------------------------------------------
# num categories: 158
# category id|name: 2452.0|Living room, kitchen, and dining room furniture
# ------------------------------------------------------------------
# num categories: 159
# category id|name: 5762.0|Lodging away from home
# ------------------------------------------------------------------
# num categories: 160
# category id|name: 5082.0|Major appliances
# ------------------------------------------------------------------
# num categories: 161
# category id|name: 5354.0|Meats
# ------------------------------------------------------------------
# num categories: 162
# category id|name: 7821.0|Men’s apparel
# ------------------------------------------------------------------
# num categories: 163
# category id|name: 369.0|Men’s footwear
# ------------------------------------------------------------------
# num categories: 164
# category id|name: 8293.0|Miscellaneous household products
# ------------------------------------------------------------------
# num categories: 165
# category id|name: 6567.0|Miscellaneous personal services
# ------------------------------------------------------------------
# num categories: 166
# category id|name: 505.0|Motor vehicle fees
# ------------------------------------------------------------------
# num categories: 167
# category id|name: 6978.0|Motor vehicle insurance
# ------------------------------------------------------------------
# num categories: 168
# category id|name: 9790.0|Motor vehicle maintenance and repair
# ------------------------------------------------------------------
# num categories: 169
# category id|name: 133.0|Moving, storage, freight expense
# ------------------------------------------------------------------
# num categories: 170
# category id|name: 3628.0|Music instruments and accessories
# ------------------------------------------------------------------
# num categories: 171
# category id|name: 5782.0|New cars
# ------------------------------------------------------------------
# num categories: 172
# category id|name: 9870.0|New trucks
# ------------------------------------------------------------------
# num categories: 173
# category id|name: 7582.0|Newspapers and magazines
# ------------------------------------------------------------------
# num categories: 174
# category id|name: 9874.0|Nonelectric cookware and tableware
# ------------------------------------------------------------------
# num categories: 175
# category id|name: 7335.0|Nonfrozen noncarbonated juices and drinks
# ------------------------------------------------------------------
# num categories: 176
# category id|name: 8558.0|Nonprescription drugs
# ------------------------------------------------------------------
# num categories: 177
# category id|name: 1467.0|Other appliances
# ------------------------------------------------------------------
# num categories: 178
# category id|name: 7028.0|Other beverage materials including tea
# ------------------------------------------------------------------
# num categories: 179
# category id|name: 6039.0|Other fats and oils including peanut butter
# ------------------------------------------------------------------
# num categories: 180
# category id|name: 9728.0|Other foods
# ------------------------------------------------------------------
# num categories: 181
# category id|name: 7326.0|Other furniture
# ------------------------------------------------------------------
# num categories: 182
# category id|name: 5777.0|Other linens
# ------------------------------------------------------------------
# num categories: 183
# category id|name: 9744.0|Other recreation services
# ------------------------------------------------------------------
# num categories: 184
# category id|name: 315.0|Other sweets
# ------------------------------------------------------------------
# num categories: 185
# category id|name: 4138.0|Other video equipment
# ------------------------------------------------------------------
# num categories: 186
# category id|name: 4623.0|Outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 187
# category id|name: 1191.0|Personal care services
# ------------------------------------------------------------------
# num categories: 188
# category id|name: 980.0|Personal computers and peripheral equipment
# ------------------------------------------------------------------
# num categories: 189
# category id|name: 4226.0|Pet food
# ------------------------------------------------------------------
# num categories: 190
# category id|name: 1219.0|Pet services including veterinary
# ------------------------------------------------------------------
# num categories: 191
# category id|name: 2424.0|Photographers and film processing
# ------------------------------------------------------------------
# num categories: 192
# category id|name: 6539.0|Photographic equipment
# ------------------------------------------------------------------
# num categories: 193
# category id|name: 594.0|Postage and delivery services
# ------------------------------------------------------------------
# num categories: 194
# category id|name: 1369.0|Prescription drugs
# ------------------------------------------------------------------
# num categories: 195
# category id|name: 9100.0|Processed fruits and vegetables
# ------------------------------------------------------------------
# num categories: 196
# category id|name: 3965.0|Professional services
# ------------------------------------------------------------------
# num categories: 197
# category id|name: 4134.0|Public transportation
# ------------------------------------------------------------------
# num categories: 198
# category id|name: 8808.0|Purchase of pets, pet supplies, accessories
# ------------------------------------------------------------------
# num categories: 199
# category id|name: 737.0|Recorded music and music subscriptions
# ------------------------------------------------------------------
# num categories: 200
# category id|name: 3331.0|Recreational books
# ------------------------------------------------------------------
# num categories: 201
# category id|name: 4363.0|Rent of primary residence
# ------------------------------------------------------------------
# num categories: 202
# category id|name: 3008.0|Rice, pasta, cornmeal
# ------------------------------------------------------------------
# num categories: 203
# category id|name: 7.0|Salad dressing
# ------------------------------------------------------------------
# num categories: 204
# category id|name: 8663.0|Sewing machines, fabric and supplies
# ------------------------------------------------------------------
# num categories: 205
# category id|name: 2216.0|Sports equipment
# ------------------------------------------------------------------
# num categories: 206
# category id|name: 4414.0|Sports vehicles including bicycles
# ------------------------------------------------------------------
# num categories: 207
# category id|name: 8917.0|Stationery, stationery supplies, gift wrap
# ------------------------------------------------------------------
# num categories: 208
# category id|name: 3199.0|Sugar and artificial sweeteners
# ------------------------------------------------------------------
# num categories: 209
# category id|name: 2940.0|Telephone hardware, calculators, and other consumer information items
# ------------------------------------------------------------------
# num categories: 210
# category id|name: 2405.0|Telephone services
# ------------------------------------------------------------------
# num categories: 211
# category id|name: 5433.0|Televisions
# ------------------------------------------------------------------
# num categories: 212
# category id|name: 7981.0|Tenants’ and household insurance
# ------------------------------------------------------------------
# num categories: 213
# category id|name: 6900.0|Tires
# ------------------------------------------------------------------
# num categories: 214
# category id|name: 620.0|Tobacco products other than cigarettes
# ------------------------------------------------------------------
# num categories: 215
# category id|name: 5668.0|Tools, hardware and supplies
# ------------------------------------------------------------------
# num categories: 216
# category id|name: 3103.0|Toys
# ------------------------------------------------------------------
# num categories: 217
# category id|name: 2308.0|Tuition, other school fees, and childcare
# ------------------------------------------------------------------
# num categories: 218
# category id|name: 1564.0|Vehicle accessories other than tires
# ------------------------------------------------------------------
# num categories: 219
# category id|name: 4757.0|Video and audio services
# ------------------------------------------------------------------
# num categories: 220
# category id|name: 6459.0|Watches
# ------------------------------------------------------------------
# num categories: 221
# category id|name: 6884.0|Water and sewerage maintenance
# ------------------------------------------------------------------
# num categories: 222
# category id|name: 6848.0|Window coverings
# ------------------------------------------------------------------
# num categories: 223
# category id|name: 9946.0|Wine at home
# ------------------------------------------------------------------
# num categories: 224
# category id|name: 2743.0|Wine away from home
# ------------------------------------------------------------------
# num categories: 225
# category id|name: 8387.0|Women’s apparel
# ------------------------------------------------------------------
# num categories: 226
# category id|name: 4044.0|Women’s footwear
# ------------------------------------------------------------------
# num categories: 227
# category id|name: 2422.0|Alcoholic beverages at home
# ------------------------------------------------------------------
# num categories: 228
# category id|name: 5080.0|Alcoholic beverages away from home
# ------------------------------------------------------------------
# num categories: 229
# category id|name: 3958.0|Appliances
# ------------------------------------------------------------------
# num categories: 230
# category id|name: 7177.0|Beverage materials including coffee and tea
# ------------------------------------------------------------------
# num categories: 231
# category id|name: 232.0|Cereals and cereal products
# ------------------------------------------------------------------
# num categories: 232
# category id|name: 1043.0|Cheese and related products
# ------------------------------------------------------------------
# num categories: 233
# category id|name: 3707.0|Education and communication services
# ------------------------------------------------------------------
# num categories: 234
# category id|name: 5985.0|Educational books and supplies
# ------------------------------------------------------------------
# num categories: 235
# category id|name: 3612.0|Fats and oils
# ------------------------------------------------------------------
# num categories: 236
# category id|name: 7182.0|Footwear
# ------------------------------------------------------------------
# num categories: 237
# category id|name: 4607.0|Fresh fruits and vegetables
# ------------------------------------------------------------------
# num categories: 238
# category id|name: 5177.0|Fuel oil
# ------------------------------------------------------------------
# num categories: 239
# category id|name: 730.0|Furniture and bedding
# ------------------------------------------------------------------
# num categories: 240
# category id|name: 789.0|Gasoline all types
# ------------------------------------------------------------------
# num categories: 241
# category id|name: 2307.0|Housekeeping supplies
# ------------------------------------------------------------------
# num categories: 242
# category id|name: 6801.0|Ice cream and related products
# ------------------------------------------------------------------
# num categories: 243
# category id|name: 2101.0|Infants’ and toddlers’ apparel
# ------------------------------------------------------------------
# num categories: 244
# category id|name: 7569.0|Information technology commodities
# ------------------------------------------------------------------
# num categories: 245
# category id|name: 546.0|Jewelry and watches
# ------------------------------------------------------------------
# num categories: 246
# category id|name: 8886.0|Juices and nonalcoholic drinks
# ------------------------------------------------------------------
# num categories: 247
# category id|name: 7803.0|Medical care services
# ------------------------------------------------------------------
# num categories: 248
# category id|name: 3514.0|Medical equipment and supplies
# ------------------------------------------------------------------
# num categories: 249
# category id|name: 5658.0|Medicinal drugs
# ------------------------------------------------------------------
# num categories: 250
# category id|name: 2395.0|Men’s and boys’ apparel
# ------------------------------------------------------------------
# num categories: 251
# category id|name: 4634.0|Milk
# ------------------------------------------------------------------
# num categories: 252
# category id|name: 1381.0|Miscellaneous personal goods
# ------------------------------------------------------------------
# num categories: 253
# category id|name: 4291.0|New vehicles
# ------------------------------------------------------------------
# num categories: 254
# category id|name: 5142.0|Other dairy and related products
# ------------------------------------------------------------------
# num categories: 255
# category id|name: 6715.0|Other household equipment and furnishings
# ------------------------------------------------------------------
# num categories: 256
# category id|name: 8206.0|Other motor fuels
# ------------------------------------------------------------------
# num categories: 257
# category id|name: 2259.0|Other personal services
# ------------------------------------------------------------------
# num categories: 258
# category id|name: 4278.0|Other recreational goods
# ------------------------------------------------------------------
# num categories: 259
# category id|name: 1231.0|Personal care products
# ------------------------------------------------------------------
# num categories: 260
# category id|name: 7156.0|Pets and pet products
# ------------------------------------------------------------------
# num categories: 261
# category id|name: 8921.0|Photographic equipment and supplies
# ------------------------------------------------------------------
# num categories: 262
# category id|name: 2320.0|Propane, kerosene, and firewood
# ------------------------------------------------------------------
# num categories: 263
# category id|name: 8585.0|Recreation services
# ------------------------------------------------------------------
# num categories: 264
# category id|name: 7963.0|Recreational reading materials
# ------------------------------------------------------------------
# num categories: 265
# category id|name: 8577.0|Rent of shelter
# ------------------------------------------------------------------
# num categories: 266
# category id|name: 172.0|Sporting goods
# ------------------------------------------------------------------
# num categories: 267
# category id|name: 7995.0|Sugar and sweets
# ------------------------------------------------------------------
# num categories: 268
# category id|name: 949.0|Tobacco and smoking products
# ------------------------------------------------------------------
# num categories: 269
# category id|name: 6044.0|Tools, hardware, outdoor equipment and supplies
# ------------------------------------------------------------------
# num categories: 270
# category id|name: 6999.0|Transportation services
# ------------------------------------------------------------------
# num categories: 271
# category id|name: 5590.0|Video and audio products
# ------------------------------------------------------------------
# num categories: 272
# category id|name: 3706.0|Water and sewer and trash collection services
# ------------------------------------------------------------------
# num categories: 273
# category id|name: 8669.0|Window and floor coverings and other linens
# ------------------------------------------------------------------
# num categories: 274
# category id|name: 7374.0|Women’s and girls’ apparel
# ------------------------------------------------------------------
# num categories: 275
# category id|name: 7635.0|Alcoholic beverages
# ------------------------------------------------------------------
# num categories: 276
# category id|name: 5516.0|Apparel
# ------------------------------------------------------------------
# num categories: 277
# category id|name: 2948.0|Cereals and bakery products
# ------------------------------------------------------------------
# num categories: 278
# category id|name: 5341.0|Dairy and related products
# ------------------------------------------------------------------
# num categories: 279
# category id|name: 4699.0|Education and communication commodities
# ------------------------------------------------------------------
# num categories: 280
# category id|name: 1202.0|Electricity
# ------------------------------------------------------------------
# num categories: 281
# category id|name: 6369.0|Food from vending machines and mobile vendors
# ------------------------------------------------------------------
# num categories: 282
# category id|name: 9499.0|Fruits and vegetables
# ------------------------------------------------------------------
# num categories: 283
# category id|name: 416.0|Fuel oil and other fuels
# ------------------------------------------------------------------
# num categories: 284
# category id|name: 3598.0|Full service meals and snacks
# ------------------------------------------------------------------
# num categories: 285
# category id|name: 5562.0|Household furnishings and supplies
# ------------------------------------------------------------------
# num categories: 286
# category id|name: 8625.0|Information and information processing
# ------------------------------------------------------------------
# num categories: 287
# category id|name: 5358.0|Information technology, hardware and services
# ------------------------------------------------------------------
# num categories: 288
# category id|name: 8446.0|Limited service meals and snacks
# ------------------------------------------------------------------
# num categories: 289
# category id|name: 8516.0|Meats, poultry, fish, and eggs
# ------------------------------------------------------------------
# num categories: 290
# category id|name: 5635.0|Medical care commodities
# ------------------------------------------------------------------
# num categories: 291
# category id|name: 3840.0|Motor fuel
# ------------------------------------------------------------------
# num categories: 292
# category id|name: 2973.0|New and used motor vehicles
# ------------------------------------------------------------------
# num categories: 293
# category id|name: 6387.0|Nonalcoholic beverages and beverage materials
# ------------------------------------------------------------------
# num categories: 294
# category id|name: 4196.0|Other food at home
# ------------------------------------------------------------------
# num categories: 295
# category id|name: 1346.0|Other food away from home
# ------------------------------------------------------------------
# num categories: 296
# category id|name: 5557.0|Other goods
# ------------------------------------------------------------------
# num categories: 297
# category id|name: 6582.0|Recreation commodities
# ------------------------------------------------------------------
# num categories: 298
# category id|name: 8742.0|Shelter
# ------------------------------------------------------------------
# num categories: 299
# category id|name: 690.0|Transportation commodities less motor fuel
# ------------------------------------------------------------------
# num categories: 300
# category id|name: 5867.0|Commodities less food
# ------------------------------------------------------------------
# num categories: 301
# category id|name: 3891.0|Commodities less food and beverages
# ------------------------------------------------------------------
# num categories: 302
# category id|name: 4935.0|Commodities less food and energy commodities
# ------------------------------------------------------------------
# num categories: 303
# category id|name: 9826.0|Commodities less food, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 304
# category id|name: 5970.0|Communication
# ------------------------------------------------------------------
# num categories: 305
# category id|name: 612.0|Domestically produced farm food
# ------------------------------------------------------------------
# num categories: 306
# category id|name: 314.0|Education
# ------------------------------------------------------------------
# num categories: 307
# category id|name: 8995.0|Energy commodities
# ------------------------------------------------------------------
# num categories: 308
# category id|name: 4748.0|Energy services
# ------------------------------------------------------------------
# num categories: 309
# category id|name: 4200.0|Food at home
# ------------------------------------------------------------------
# num categories: 310
# category id|name: 1345.0|Food away from home
# ------------------------------------------------------------------
# num categories: 311
# category id|name: 396.0|Household energy
# ------------------------------------------------------------------
# num categories: 312
# category id|name: 6247.0|Nondurables less food
# ------------------------------------------------------------------
# num categories: 313
# category id|name: 5488.0|Nondurables less food and apparel
# ------------------------------------------------------------------
# num categories: 314
# category id|name: 7080.0|Nondurables less food and beverages
# ------------------------------------------------------------------
# num categories: 315
# category id|name: 1465.0|Nondurables less food, beverages, and apparel
# ------------------------------------------------------------------
# num categories: 316
# category id|name: 6986.0|Personal care
# ------------------------------------------------------------------
# num categories: 317
# category id|name: 9321.0|Pets, pet products and services
# ------------------------------------------------------------------
# num categories: 318
# category id|name: 9325.0|Photography
# ------------------------------------------------------------------
# num categories: 319
# category id|name: 3815.0|Private transportation
# ------------------------------------------------------------------
# num categories: 320
# category id|name: 1033.0|Services less energy services
# ------------------------------------------------------------------
# num categories: 321
# category id|name: 5145.0|Services less medical care services
# ------------------------------------------------------------------
# num categories: 322
# category id|name: 9058.0|Services less rent of shelter
# ------------------------------------------------------------------
# num categories: 323
# category id|name: 5618.0|Video and audio
# ------------------------------------------------------------------
# num categories: 324
# category id|name: 4604.0|All items less energy
# ------------------------------------------------------------------
# num categories: 325
# category id|name: 3531.0|All items less food
# ------------------------------------------------------------------
# num categories: 326
# category id|name: 5306.0|All items less food and energy
# ------------------------------------------------------------------
# num categories: 327
# category id|name: 4114.0|All items less food and shelter
# ------------------------------------------------------------------
# num categories: 328
# category id|name: 5789.0|All items less food, shelter, and energy
# ------------------------------------------------------------------
# num categories: 329
# category id|name: 2208.0|All items less food, shelter, energy, and used cars and trucks
# ------------------------------------------------------------------
# num categories: 330
# category id|name: 2047.0|All items less medical care
# ------------------------------------------------------------------
# num categories: 331
# category id|name: 7199.0|All items less shelter
# ------------------------------------------------------------------
# num categories: 332
# category id|name: 3242.0|Apparel less footwear
# ------------------------------------------------------------------
# num categories: 333
# category id|name: 704.0|Commodities
# ------------------------------------------------------------------
# num categories: 334
# category id|name: 2665.0|Durables
# ------------------------------------------------------------------
# num categories: 335
# category id|name: 1868.0|Education and communication
# ------------------------------------------------------------------
# num categories: 336
# category id|name: 7558.0|Energy
# ------------------------------------------------------------------
# num categories: 337
# category id|name: 4934.0|Food
# ------------------------------------------------------------------
# num categories: 338
# category id|name: 9257.0|Food and beverages
# ------------------------------------------------------------------
# num categories: 339
# category id|name: 5463.0|Fuels and utilities
# ------------------------------------------------------------------
# num categories: 340
# category id|name: 9339.0|Household furnishings and operations
# ------------------------------------------------------------------
# num categories: 341
# category id|name: 6803.0|Housing
# ------------------------------------------------------------------
# num categories: 342
# category id|name: 3411.0|Medical care
# ------------------------------------------------------------------
# num categories: 343
# category id|name: 818.0|Nondurables
# ------------------------------------------------------------------
# num categories: 344
# category id|name: 8488.0|Other goods and services
# ------------------------------------------------------------------
# num categories: 345
# category id|name: 6741.0|Other services
# ------------------------------------------------------------------
# num categories: 346
# category id|name: 8575.0|Recreation
# ------------------------------------------------------------------
# num categories: 347
# category id|name: 9735.0|Services
# ------------------------------------------------------------------
# num categories: 348
# category id|name: 6812.0|Transportation
# ------------------------------------------------------------------
# num categories: 349
# category id|name: 7939.0|Utilities and public transportation
# ------------------------------------------------------------------
# num categories: 350
# category id|name: 8106.0|All items
# ------------------------------------------------------------------

# %%
predictions_dict_3 = get_results_on_test_set(weightspath_3, train_dataset_dict, test_dataset_dict, categories = categories)
with open(test_predictions_path_3, 'wb') as handle:
    pickle.dump(predictions_dict_3, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Admission to movies, theaters, and concerts
# Bacon, breakfast sausage, and related products
# Bread other than white
# Canned fruits
# Canned vegetables
# Checking account and other bank services
# Chicken
# Cookies
# Crackers, bread, and cracker products
# Dried beans, peas, and lentils
# Frankfurters
# Fresh cakes and cupcakes
# Fresh fish and seafood
# Fresh sweetrolls, coffeecakes, doughnuts
# Frozen and refrigerated bakery products, pies, tarts, turnovers
# Frozen vegetables
# Ham
# Intracity mass transit
# Lunchmeats
# Oranges, including tangerines
# Other condiments
# Other pork including roasts and picnics
# Other uncooked poultry including turkey
# Parking fees and tolls
# Pork chops
# Prepared salads
# Processed fish and seafood
# Salt and other seasonings and spices
# Sauces and gravies
# Ship fare
# Uncooked beef roasts
# Uncooked beef steaks
# Uncooked ground beef
# Uncooked other beef and veal
# Video discs and other media
# White bread
# Admissions
# Airline fare
# Apparel services other than laundry and dry cleaning
# Apples
# Bananas
# Beef and veal
# Bread
# Butter
# Cakes, cupcakes, and cookies
# Canned fruits and vegetables
# Child care and nursery school
# Citrus fruits
# College tuition and fees
# Delivery services
# Dental services
# Distilled spirits, excluding whiskey, at home
# Elementary and high school tuition and fees
# Eyeglasses and eye care
# Financial services
# Fish and seafood
# Fresh biscuits, rolls, muffins
# Frozen and freeze dried prepared foods
# Frozen fruits and vegetables
# Funeral expenses
# Haircuts and other personal care services
# Housing at school, excluding board
# Instant and freeze dried coffee
# Intracity transportation
# Land-line telephone services
# Laundry and dry cleaning services
# Laundry equipment
# Lettuce
# Margarine
# Men’s pants and shorts
# Men’s shirts and sweaters
# Men’s suits, sport coats, and outerwear
# Motor oil, coolant, and fluids
# Motor vehicle maintenance and servicing
# Motor vehicle repair
# Nursing homes and adult day services
# Other bakery products
# Other fresh fruits
# Other fresh vegetables
# Other intercity transportation
# Other lodging away from home including hotels and motels
# Other meats
# Other miscellaneous foods
# Other processed fruits and vegetables including dried
# Owners’ equivalent rent of primary residence
# Parking and other fees
# Physicians’ services
# Pork
# Postage
# Potatoes
# Poultry
# Rice
# Roasted coffee
# Services by other medical professionals
# Snacks
# Soups
# Spices, seasonings, condiments, sauces
# State motor vehicle registration and license fees
# Technical and business school tuition and fees
# Tomatoes
# Toys, games, hobbies and playground equipment
# Vehicle parts and equipment other than tires
# Veterinarian services
# Whiskey at home
# Wireless telephone services
# Women’s dresses
# Women’s outerwear
# Women’s suits and separates
# Women’s underwear, nightwear, sportswear and accessories
# Alcoholic beverages
# Apparel
# Cereals and bakery products
# Dairy and related products
# Education and communication commodities
# Electricity
# Food from vending machines and mobile vendors
# Fruits and vegetables
# Fuel oil and other fuels
# Full service meals and snacks
# Household furnishings and supplies
# Information and information processing
# Information technology, hardware and services
# Limited service meals and snacks
# Meats, poultry, fish, and eggs
# Medical care commodities
# Motor fuel
# New and used motor vehicles
# Nonalcoholic beverages and beverage materials
# Other food at home
# Other food away from home
# Other goods
# Recreation commodities
# Shelter
# Transportation commodities less motor fuel
# Alcoholic beverages at home
# Alcoholic beverages away from home
# Appliances
# Beverage materials including coffee and tea
# Cereals and cereal products
# Cheese and related products
# Education and communication services
# Educational books and supplies
# Fats and oils
# Footwear
# Fresh fruits and vegetables
# Fuel oil
# Furniture and bedding
# Gasoline all types
# Housekeeping supplies
# Ice cream and related products
# Infants’ and toddlers’ apparel
# Information technology commodities
# Jewelry and watches
# Juices and nonalcoholic drinks
# Medical care services
# Medical equipment and supplies
# Medicinal drugs
# Men’s and boys’ apparel
# Milk
# Miscellaneous personal goods
# New vehicles
# Other dairy and related products
# Other household equipment and furnishings
# Other motor fuels
# Other personal services
# Other recreational goods
# Personal care products
# Pets and pet products
# Photographic equipment and supplies
# Propane, kerosene, and firewood
# Recreation services
# Recreational reading materials
# Rent of shelter
# Sporting goods
# Sugar and sweets
# Tobacco and smoking products
# Tools, hardware, outdoor equipment and supplies
# Transportation services
# Video and audio products
# Water and sewer and trash collection services
# Window and floor coverings and other linens
# Women’s and girls’ apparel
# All items
# All items less energy
# All items less food
# All items less food and energy
# All items less food and shelter
# All items less food, shelter, and energy
# All items less food, shelter, energy, and used cars and trucks
# All items less medical care
# All items less shelter
# Apparel less footwear
# Commodities
# Durables
# Education and communication
# Energy
# Food
# Fuels and utilities
# Household furnishings and operations
# Housing
# Medical care
# Nondurables
# Other goods and services
# Other services
# Recreation
# Services
# Transportation
# Utilities and public transportation
# Audio equipment
# Bakery products
# Bedroom furniture
# Beer, ale, and other malt beverages at home
# Beer, ale, and other malt beverages away from home
# Boys’ and girls’ footwear
# Boys’ apparel
# Breakfast cereal
# Butter and margarine
# Candy and chewing gum
# Car and truck rental
# Carbonated drinks
# Cigarettes
# Clocks, lamps, and decorator items
# Coffee
# College textbooks
# Computer software and accessories
# Cosmetics, perfume, bath, nail preparations and implements
# Dishes and flatware
# Distilled spirits at home
# Eggs
# Floor coverings
# Flour and prepared flour mixes
# Fresh fruits
# Fresh milk other than whole
# Fresh vegetables
# Fresh whole milk
# Frozen noncarbonated juices and drinks
# Garbage and trash collection
# Gasoline, unleaded midgrade
# Gasoline, unleaded premium
# Gasoline, unleaded regular
# Girls’ apparel
# Hair, dental, shaving, and miscellaneous personal care products
# Health insurance
# Hospital and related services
# Household cleaning products
# Household paper products
# Indoor plants and flowers
# Internet services and electronic information providers
# Jewelry
# Living room, kitchen, and dining room furniture
# Lodging away from home
# Major appliances
# Meats
# Men’s apparel
# Men’s footwear
# Miscellaneous household products
# Miscellaneous personal services
# Motor vehicle fees
# Motor vehicle insurance
# Motor vehicle maintenance and repair
# Moving, storage, freight expense
# Music instruments and accessories
# New cars
# New trucks
# Newspapers and magazines
# Nonelectric cookware and tableware
# Nonfrozen noncarbonated juices and drinks
# Nonprescription drugs
# Other appliances
# Other beverage materials including tea
# Other fats and oils including peanut butter
# Other foods
# Other furniture
# Other linens
# Other recreation services
# Other sweets
# Other video equipment
# Outdoor equipment and supplies
# Personal care services
# Personal computers and peripheral equipment
# Pet food
# Pet services including veterinary
# Photographers and film processing
# Photographic equipment
# Postage and delivery services
# Prescription drugs
# Processed fruits and vegetables
# Professional services
# Public transportation
# Purchase of pets, pet supplies, accessories
# Recorded music and music subscriptions
# Recreational books
# Rent of primary residence
# Rice, pasta, cornmeal
# Salad dressing
# Sewing machines, fabric and supplies
# Sports equipment
# Sports vehicles including bicycles
# Stationery, stationery supplies, gift wrap
# Sugar and artificial sweeteners
# Telephone hardware, calculators, and other consumer information items
# Telephone services
# Televisions
# Tenants’ and household insurance
# Tires
# Tobacco products other than cigarettes
# Tools, hardware and supplies
# Toys
# Tuition, other school fees, and childcare
# Vehicle accessories other than tires
# Video and audio services
# Watches
# Water and sewerage maintenance
# Window coverings
# Wine at home
# Wine away from home
# Women’s apparel
# Women’s footwear
# Bacon and related products
# Breakfast sausage and related products
# Fresh and frozen chicken parts
# Fresh whole chicken
# Frozen fish and seafood
# Ham, excluding canned
# Shelf stable fish and seafood
# Commodities less food
# Commodities less food and beverages
# Commodities less food and energy commodities
# Commodities less food, energy, and used cars and trucks
# Communication
# Domestically produced farm food
# Education
# Energy commodities
# Energy services
# Food at home
# Food away from home
# Household energy
# Nondurables less food
# Nondurables less food and apparel
# Nondurables less food and beverages
# Nondurables less food, beverages, and apparel
# Personal care
# Pets, pet products and services
# Photography
# Private transportation
# Services less energy services
# Services less medical care services
# Services less rent of shelter
# Video and audio

# %%
# Sanity Tests:

# %%
predictions_dict_1['All items']
# Out:
# tensor([[0.3900, 0.4615, 0.6161, 0.6152, 0.4307, 0.4092, 0.3538, 0.3373, 0.4595,
#          0.5726, 0.4603, 0.3940, 0.4518, 0.4131, 0.4598, 0.2798, 0.4238, 0.3821,
#          0.2732, 0.3220, 0.3191, 0.3148, 0.2882, 0.2025, 0.4224, 0.2795, 0.3088,
#          0.2965, 0.1510, 0.2575, 0.4136, 0.4764]])

# %%
predictions_dict_2['All items']
# Out:
# tensor([[ 0.3638,  0.3932,  0.4990,  0.6711,  0.6605,  0.6865,  0.4675,  0.4362,
#           0.5180,  0.6245,  0.5234,  0.1004,  0.5921,  0.6707,  0.7617,  0.1017,
#           0.6314,  0.6481, -0.2398,  0.4161,  0.4824,  0.2463,  0.0879,  0.3401,
#           0.5862,  0.5806,  0.1641,  0.5058,  0.3834,  0.4272,  0.5588,  0.6183]])

# %%
predictions_dict_3['All items']
# Out:
# tensor([[0.1597, 0.2372, 0.3777, 0.4963, 0.5269, 0.5272, 0.3068, 0.1679, 0.2422,
#          0.5261, 0.4435, 0.3552, 0.4830, 0.5401, 0.6028, 0.3517, 0.5528, 0.5039,
#          0.1447, 0.3184, 0.4203, 0.3995, 0.2600, 0.2175, 0.5232, 0.3305, 0.1543,
#          0.4007, 0.1918, 0.0839, 0.2242, 0.4889]])
